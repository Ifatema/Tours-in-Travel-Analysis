# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Marrakech.csv')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  3,000+ places sorted by traveler favorites
# 1                                      49,956
# 2                                      13,288
# 3                                         716
# 4                                       2,968
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                        bUshh  cIVmB  \
# 0                        NaN    NaN
# 1           Jardin Majorelle    1.0
# 2           Palácio da Bahia    2.0
# 3  Anima André Heller Garden    3.0
# 4           Le Jardin Secret    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                     WlYyy 2  \
# 0                                       NaN
# 1                                   Gardens
# 2  Historic Sites • Architectural Buildings
# 3                                   Gardens
# 4                                   Gardens
#
#                                         iPqaD href 3  \
# 0                                                NaN
# 1       https://www.tripadvisor.com/Profile/Mattel89
# 2      https://www.tripadvisor.com/Profile/fabfrench
# 3   https://www.tripadvisor.com/Profile/Jasonernesto
# 4  https://www.tripadvisor.com/Profile/juliabG9395ZP
#
#                                          dugSS src 2 WlYyy 3          iPqaD  \
# 0                                                NaN     NaN            NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By       Mattel89
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      By      fabfrench
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...      By   Jasonernesto
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...      By  juliabG9395ZP
#
#                                         iPqaD href 5  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/ShowUserReviews-g2...
# 2  https://www.tripadvisor.com/ShowUserReviews-g2...
# 3  https://www.tripadvisor.com/ShowUserReviews-g2...
# 4  https://www.tripadvisor.com/ShowUserReviews-g2...
#
#                                WlYyy 4              dkvhj  \
# 0                                  NaN                NaN
# 1  Definitely “must see” in Marrakech,   beautiful garden
# 2                                  The       Bahia Palace
# 3                              Spent a          few hours
# 4                           We visited  the secret garden
#
#                                              WlYyy 5   WlYyy 6
# 0                                                NaN       NaN
# 1  , lots of birds, amazing plants, palms, cactus...       NaN
# 2  is stunning and it is the perfect example of t...  Open now
# 3     here a few days ago and thoroughly enjoyed it.  Open now
# 4  for the first time and were amazed by the peac...  Open now

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         257 non-null    object
#  1   FmrIP href    246 non-null    object
#  2   dugSS src     240 non-null    object
#  3   bUshh         246 non-null    object
#  4   cIVmB         246 non-null    float64
#  5   iPqaD href 2  246 non-null    object
#  6   WlYyy 2       256 non-null    object
#  7   iPqaD href 3  106 non-null    object
#  8   dugSS src 2   106 non-null    object
#  9   WlYyy 3       115 non-null    object
#  10  iPqaD         106 non-null    object
#  11  iPqaD href 5  106 non-null    object
#  12  WlYyy 4       112 non-null    object
#  13  dkvhj         106 non-null    object
#  14  WlYyy 5       92 non-null     object
#  15  WlYyy 6       140 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 32.2+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src', 'cIVmB', 'iPqaD href 2', 'iPqaD href 3', 'dugSS src 2', 'WlYyy 3', 'iPqaD', 'iPqaD href 5', 'WlYyy 4', 'dkvhj', 'WlYyy 5', 'WlYyy 6'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Marrakech'
df['Country'] = 'Morocco'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 14

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                            Attraction Name  \
# 0                                      NaN
# 1                         Jardin Majorelle
# 2                         Palácio da Bahia
# 3                Anima André Heller Garden
# 4                         Le Jardin Secret
# ..                                     ...
# 251                          Atlas Walkers
# 252  Sahara Exploring Expedition Day Tours
# 253              Morocco Private Excursion
# 254                 Marrakech Sweet Travel
# 255                 Marrakech Hidden Sites
#
#                                   Attraction Type       City  Country
# 0                                             NaN  Marrakech  Morocco
# 1                                         Gardens  Marrakech  Morocco
# 2        Historic Sites • Architectural Buildings  Marrakech  Morocco
# 3                                         Gardens  Marrakech  Morocco
# 4                                         Gardens  Marrakech  Morocco
# ..                                            ...        ...      ...
# 251   Multi-day Tours • 4WD, ATV & Off-Road Tours  Marrakech  Morocco
# 252   Multi-day Tours • 4WD, ATV & Off-Road Tours  Marrakech  Morocco
# 253            Multi-day Tours • Taxis & Shuttles  Marrakech  Morocco
# 254                  City Tours • Multi-day Tours  Marrakech  Morocco
# 255  Cultural Tours • Historical & Heritage Tours  Marrakech  Morocco
#
# [243 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    11
# Attraction Type     1
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                            Attraction Name  \
# 0                                      NaN
# 1                         Jardin Majorelle
# 2                         Palácio da Bahia
# 3                Anima André Heller Garden
# 4                         Le Jardin Secret
# ..                                     ...
# 252  Sahara Exploring Expedition Day Tours
# 253              Morocco Private Excursion
# 254                 Marrakech Sweet Travel
# 255                 Marrakech Hidden Sites
# 256                                    NaN
#
#                                   Attraction Type       City  Country
# 0                                             NaN  Marrakech  Morocco
# 1                                         Gardens  Marrakech  Morocco
# 2        Historic Sites • Architectural Buildings  Marrakech  Morocco
# 3                                         Gardens  Marrakech  Morocco
# 4                                         Gardens  Marrakech  Morocco
# ..                                            ...        ...      ...
# 252   Multi-day Tours • 4WD, ATV & Off-Road Tours  Marrakech  Morocco
# 253            Multi-day Tours • Taxis & Shuttles  Marrakech  Morocco
# 254                  City Tours • Multi-day Tours  Marrakech  Morocco
# 255  Cultural Tours • Historical & Heritage Tours  Marrakech  Morocco
# 256                                             1  Marrakech  Morocco
#
# [257 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  246 non-null    object
#  1   Attraction Type  256 non-null    object
#  2   City             257 non-null    object
#  3   Country          257 non-null    object
# dtypes: object(4)
# memory usage: 8.2+ KB

# %%
# Store the clean dataset
df.to_csv('Marrakechclean.csv')
