# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Tokyo.csv')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                          WlYyy  \
# 0  10,000+ places sorted by traveler favorites
# 1                                        8,195
# 2                                        6,156
# 3                                          273
# 4                                        6,106
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                             bUshh  cIVmB  \
# 0                             NaN    NaN
# 1              Meiji Jingu Shrine    1.0
# 2  Shinjuku Gyoen National Garden    2.0
# 3                    Yomiuri Land    3.0
# 4                         Asakusa    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                  WlYyy 2                     WlYyy 3  \
# 0                                    NaN                         NaN
# 1         Points of Interest & Landmarks  Shibuya / Harajuku / Ebisu
# 2                                Gardens                    Shinjuku
# 3  Amusement & Theme Parks • Water Parks                         NaN
# 4                          Neighborhoods               Ueno, Asakusa
#
#                                         iPqaD href 3  \
# 0                                                NaN
# 1        https://www.tripadvisor.com/Profile/507kamc
# 2   https://www.tripadvisor.com/Profile/markpP5371OR
# 3                                                NaN
# 4  https://www.tripadvisor.com/Profile/DayleDavidson
#
#                                          dugSS src 2 WlYyy 4          iPqaD  \
# 0                                                NaN     NaN            NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By        507kamc
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      By   markpP5371OR
# 3                                                NaN     NaN            NaN
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...      By  DayleDavidson
#
#                                         iPqaD href 5  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/ShowUserReviews-g1...
# 2  https://www.tripadvisor.com/ShowUserReviews-g1...
# 3                                                NaN
# 4  https://www.tripadvisor.com/ShowUserReviews-g1...
#
#                                            WlYyy 5        dkvhj  \
# 0                                              NaN          NaN
# 1  Many shrines have become too commercial and the  Meiji Jingu
# 2                         A bonus walk through the  green house
# 3                                              NaN          NaN
# 4      Beautiful temple but can be quite busy with     tourists
#
#                                              WlYyy 6
# 0                                                NaN
# 1  Shrine has retained its elegance and solemn vibe.
# 2  and two separate tea houses to enjoy the vista...
# 3                                                NaN
# 4  during the day so try coming at sunset or nigh...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341 entries, 0 to 340
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         341 non-null    object
#  1   FmrIP href    325 non-null    object
#  2   dugSS src     325 non-null    object
#  3   bUshh         325 non-null    object
#  4   cIVmB         325 non-null    float64
#  5   iPqaD href 2  325 non-null    object
#  6   WlYyy 2       336 non-null    object
#  7   WlYyy 3       290 non-null    object
#  8   iPqaD href 3  85 non-null     object
#  9   dugSS src 2   85 non-null     object
#  10  WlYyy 4       98 non-null     object
#  11  iPqaD         85 non-null     object
#  12  iPqaD href 5  85 non-null     object
#  13  WlYyy 5       85 non-null     object
#  14  dkvhj         85 non-null     object
#  15  WlYyy 6       82 non-null     object
# dtypes: float64(1), object(15)
# memory usage: 42.8+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src', 'cIVmB', 'iPqaD href 2','WlYyy 3', 'iPqaD href 3', 'dugSS src 2', 'WlYyy 4', 'iPqaD','iPqaD href 5', 'WlYyy 5', 'dkvhj', 'WlYyy 6'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Tokyo'
df['Country'] = 'Japan'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 38

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                     Attraction Name  \
# 0                               NaN
# 1                Meiji Jingu Shrine
# 2    Shinjuku Gyoen National Garden
# 3                      Yomiuri Land
# 4                           Asakusa
# ..                              ...
# 329    Tokyo Garden Terrace Kioicho
# 330               Kokyo Otemon Gate
# 331          Nihonbashi Nagasakikan
# 332               Kokufu Bonsai-Ten
# 333                   Joyful Minowa
#
#                                        Attraction Type   City Country
# 0                                                  NaN  Tokyo   Japan
# 1                       Points of Interest & Landmarks  Tokyo   Japan
# 2                                              Gardens  Tokyo   Japan
# 3                Amusement & Theme Parks • Water Parks  Tokyo   Japan
# 4                                        Neighborhoods  Tokyo   Japan
# ..                                                 ...    ...     ...
# 329  Points of Interest & Landmarks • Architectural...  Tokyo   Japan
# 330                                     Historic Sites  Tokyo   Japan
# 331                                    Visitor Centers  Tokyo   Japan
# 332                                    Cultural Events  Tokyo   Japan
# 333                     Points of Interest & Landmarks  Tokyo   Japan
#
# [303 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    16
# Attraction Type     5
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                      Attraction Name                        Attraction Type  \
# 0                                NaN                                    NaN
# 1                 Meiji Jingu Shrine         Points of Interest & Landmarks
# 2     Shinjuku Gyoen National Garden                                Gardens
# 3                       Yomiuri Land  Amusement & Theme Parks • Water Parks
# 4                            Asakusa                          Neighborhoods
# ..                               ...                                    ...
# 336               Coredo Muromachi 1                         Shopping Malls
# 337  Kyu Kaneiji Five-Storied Pagoda                        Religious Sites
# 338              Marunouchi Building                         Shopping Malls
# 339                  Asakusa Ekimise                         Shopping Malls
# 340                              NaN                                      1
#
#       City Country
# 0    Tokyo   Japan
# 1    Tokyo   Japan
# 2    Tokyo   Japan
# 3    Tokyo   Japan
# 4    Tokyo   Japan
# ..     ...     ...
# 336  Tokyo   Japan
# 337  Tokyo   Japan
# 338  Tokyo   Japan
# 339  Tokyo   Japan
# 340  Tokyo   Japan
#
# [341 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341 entries, 0 to 340
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  325 non-null    object
#  1   Attraction Type  336 non-null    object
#  2   City             341 non-null    object
#  3   Country          341 non-null    object
# dtypes: object(4)
# memory usage: 10.8+ KB

# %%
# Store the clean dataset
df.to_csv('Tokyoclean.csv')
