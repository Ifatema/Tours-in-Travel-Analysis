# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Chicago.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'FmrIP href', 'dugSS src', 'bUshh', 'cIVmB', 'iPqaD href 2',
#        'WlYyy 2', 'WlYyy 3', 'iPqaD href 3', 'dugSS src 2', 'WlYyy 4', 'iPqaD',
#        'iPqaD href 5', 'WlYyy 5', 'dkvhj', 'WlYyy 6'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  2,000+ places sorted by traveler favorites
# 1                                      24,172
# 2                                      11,041
# 3                                      10,900
# 4                                      18,085
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                             bUshh  cIVmB  \
# 0                             NaN    NaN
# 1    The Art Institute of Chicago    1.0
# 2  Museum of Science and Industry    2.0
# 3    360 Chicago Observation Deck    3.0
# 4                      Cloud Gate    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                              WlYyy 2          WlYyy 3  \
# 0                                                NaN              NaN
# 1                                        Art Museums       Grant Park
# 2                                    Science Museums        Hyde Park
# 3  Architectural Buildings • Observation Decks & ...  Near North Side
# 4  Points of Interest & Landmarks • Monuments & S...  Millennium Park
#
#                                     iPqaD href 3  \
# 0                                            NaN
# 1    https://www.tripadvisor.com/Profile/Rrrryan
# 2  https://www.tripadvisor.com/Profile/538andrez
# 3      https://www.tripadvisor.com/Profile/dcsae
# 4   https://www.tripadvisor.com/Profile/GailofSB
#
#                                          dugSS src 2 WlYyy 4      iPqaD  \
# 0                                                NaN     NaN        NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By    Rrrryan
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      By  538andrez
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...      By      dcsae
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...      By   GailofSB
#
#                                         iPqaD href 5  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/ShowUserReviews-g3...
# 2  https://www.tripadvisor.com/ShowUserReviews-g3...
# 3  https://www.tripadvisor.com/ShowUserReviews-g3...
# 4  https://www.tripadvisor.com/ShowUserReviews-g3...
#
#                                              WlYyy 5         dkvhj  \
# 0                                                NaN           NaN
# 1                  Renzo Piano, the architect of the   modern wing
# 2  Among the museum's exhibits are a full-size re...     coal mine
# 3  We always take out of town visitors to either ...  Willis tower
# 4           It was dreamy to wander, after exploring      The Bean
#
#                                              WlYyy 6
# 0                                                NaN
# 1  , outdid himself; the new addition is gorgeous...
# 2  , German submarine U-505 captured during World...
# 3              and they are both fantastic at night.
# 4  , to experience the Chicago Symphony rehearsin...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         380 non-null    object
#  1   FmrIP href    365 non-null    object
#  2   dugSS src     355 non-null    object
#  3   bUshh         365 non-null    object
#  4   cIVmB         365 non-null    float64
#  5   iPqaD href 2  365 non-null    object
#  6   WlYyy 2       379 non-null    object
#  7   WlYyy 3       370 non-null    object
#  8   iPqaD href 3  109 non-null    object
#  9   dugSS src 2   109 non-null    object
#  10  WlYyy 4       121 non-null    object
#  11  iPqaD         109 non-null    object
#  12  iPqaD href 5  109 non-null    object
#  13  WlYyy 5       109 non-null    object
#  14  dkvhj         109 non-null    object
#  15  WlYyy 6       103 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 47.6+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src','cIVmB', 'iPqaD href 2', 'WlYyy 3', 'iPqaD href 3', 'dugSS src 2', 'WlYyy 4', 'iPqaD','iPqaD href 5', 'WlYyy 5', 'dkvhj', 'WlYyy 6'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Chicago'
df['Country'] = 'USA'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 18

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                     Attraction Name  \
# 0                               NaN
# 1      The Art Institute of Chicago
# 2    Museum of Science and Industry
# 3      360 Chicago Observation Deck
# 4                        Cloud Gate
# ..                              ...
# 374               Rivendell Theatre
# 375                        XpresSpa
# 376        World War II Submariners
# 377     Holy Family Catholic Church
# 378                           Talie
#
#                                        Attraction Type     City Country
# 0                                                  NaN  Chicago     USA
# 1                                          Art Museums  Chicago     USA
# 2                                      Science Museums  Chicago     USA
# 3    Architectural Buildings • Observation Decks & ...  Chicago     USA
# 4    Points of Interest & Landmarks • Monuments & S...  Chicago     USA
# ..                                                 ...      ...     ...
# 374                                           Theaters  Chicago     USA
# 375                                      Airport Shops  Chicago     USA
# 376                                Monuments & Statues  Chicago     USA
# 377                              Churches & Cathedrals  Chicago     USA
# 378                                      Airport Shops  Chicago     USA
#
# [362 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    15
# Attraction Type     1
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                     Attraction Name  \
# 0                               NaN
# 1      The Art Institute of Chicago
# 2    Museum of Science and Industry
# 3      360 Chicago Observation Deck
# 4                        Cloud Gate
# ..                              ...
# 375                        XpresSpa
# 376        World War II Submariners
# 377     Holy Family Catholic Church
# 378                           Talie
# 379                             NaN
#
#                                        Attraction Type     City Country
# 0                                                  NaN  Chicago     USA
# 1                                          Art Museums  Chicago     USA
# 2                                      Science Museums  Chicago     USA
# 3    Architectural Buildings • Observation Decks & ...  Chicago     USA
# 4    Points of Interest & Landmarks • Monuments & S...  Chicago     USA
# ..                                                 ...      ...     ...
# 375                                      Airport Shops  Chicago     USA
# 376                                Monuments & Statues  Chicago     USA
# 377                              Churches & Cathedrals  Chicago     USA
# 378                                      Airport Shops  Chicago     USA
# 379                                                  1  Chicago     USA
#
# [380 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  365 non-null    object
#  1   Attraction Type  379 non-null    object
#  2   City             380 non-null    object
#  3   Country          380 non-null    object
# dtypes: object(4)
# memory usage: 12.0+ KB

# %%
# Store the clean dataset
df.to_csv('Chicagoclean.csv')
