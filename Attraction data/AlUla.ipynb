# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('AlUla.csv')

# %%
messy_df.columns
# Out:
# Index(['FmrIP href', 'dugSS src', 'bUshh', 'cIVmB', 'iPqaD href', 'WlYyy',
#        'WlYyy 2', 'WlYyy 3', 'iPqaD href 2', 'dugSS src 2', 'WlYyy 4', 'iPqaD',
#        'iPqaD href 4', 'WlYyy 5', 'dkvhj', 'WlYyy 6'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                           FmrIP href  \
# 0  https://www.tripadvisor.com/Attraction_Review-...
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0  https://dynamic-media-cdn.tripadvisor.com/medi...
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                          bUshh  cIVmB  \
# 0                        Hegra    1.0
# 1  Jabal AlFil (Elephant Rock)    2.0
# 2            Old Town of AlUla    3.0
# 3                 AlUla Museum    4.0
# 4        Hijaz Railway Station    5.0
#
#                                           iPqaD href WlYyy  \
# 0  https://www.tripadvisor.com/Attraction_Review-...   275
# 1  https://www.tripadvisor.com/Attraction_Review-...    91
# 2  https://www.tripadvisor.com/Attraction_Review-...    60
# 3  https://www.tripadvisor.com/Attraction_Review-...     2
# 4  https://www.tripadvisor.com/Attraction_Review-...     7
#
#                           WlYyy 2             WlYyy 3  \
# 0  Historic Sites • Ancient Ruins            Open now
# 1             Geologic Formations            Open now
# 2  Points of Interest & Landmarks            Open now
# 3                 History Museums  Temporarily closed
# 4                 History Museums            Open now
#
#                                      iPqaD href 2  \
# 0     https://www.tripadvisor.com/Profile/WKeikes
# 1  https://www.tripadvisor.com/Profile/angeloo388
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#                                          dugSS src 2 WlYyy 4       iPqaD  \
# 0  https://dynamic-media-cdn.tripadvisor.com/medi...      By     WKeikes
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By  angeloo388
# 2                                                NaN     NaN         NaN
# 3                                                NaN     NaN         NaN
# 4                                                NaN     NaN         NaN
#
#                                         iPqaD href 4  \
# 0  https://www.tripadvisor.com/ShowUserReviews-g1...
# 1  https://www.tripadvisor.com/ShowUserReviews-g1...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              WlYyy 5          dkvhj  \
# 0  I've been flying hot air balloon over the Tomb...   Madain Saleh
# 1                        inside an amazing landscape  Amazing place
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
#
#                                              WlYyy 6
# 0  during the Winter in tantora festival, it was ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FmrIP href    19 non-null     object
#  1   dugSS src     19 non-null     object
#  2   bUshh         19 non-null     object
#  3   cIVmB         19 non-null     float64
#  4   iPqaD href    13 non-null     object
#  5   WlYyy         15 non-null     object
#  6   WlYyy 2       19 non-null     object
#  7   WlYyy 3       8 non-null      object
#  8   iPqaD href 2  5 non-null      object
#  9   dugSS src 2   5 non-null      object
#  10  WlYyy 4       5 non-null      object
#  11  iPqaD         5 non-null      object
#  12  iPqaD href 4  5 non-null      object
#  13  WlYyy 5       5 non-null      object
#  14  dkvhj         5 non-null      object
#  15  WlYyy 6       4 non-null      object
# dtypes: float64(1), object(15)
# memory usage: 2.5+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['FmrIP href', 'dugSS src', 'cIVmB', 'iPqaD href', 'WlYyy',  'WlYyy 3', 'iPqaD href 2', 'dugSS src 2', 'WlYyy 4', 'iPqaD', 'iPqaD href 4', 'WlYyy 5', 'dkvhj', 'WlYyy 6'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'bUshh':'Attraction Name',  'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Al Ula'
df['Country'] = 'Saudi Arabia'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    0
# Attraction Type    0
# City               0
# Country            0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                 Attraction Name  \
# 0                         Hegra
# 1   Jabal AlFil (Elephant Rock)
# 2             Old Town of AlUla
# 3                  AlUla Museum
# 4         Hijaz Railway Station
# 5                        Maraya
# 6                      Al Diwan
# 7            Madain Saleh Tours
# 8                  Jabal Ithlib
# 9             Husaak Adventures
# 10                  Jabal Ikmah
# 11                 Al Ula Tours
# 12          Lion Tombs of Dadan
# 13               جاده للمغامرات
# 14                  AlUla Fresh
# 15                Mahfol Makfol
# 16                        PEAKS
# 17            abdullah alsultan
# 18                        dooma
#
#                                       Attraction Type    City       Country
# 0                      Historic Sites • Ancient Ruins  Al Ula  Saudi Arabia
# 1                                 Geologic Formations  Al Ula  Saudi Arabia
# 2                      Points of Interest & Landmarks  Al Ula  Saudi Arabia
# 3                                     History Museums  Al Ula  Saudi Arabia
# 4                                     History Museums  Al Ula  Saudi Arabia
# 5                  Architectural Buildings • Theaters  Al Ula  Saudi Arabia
# 6      Ancient Ruins • Points of Interest & Landmarks  Al Ula  Saudi Arabia
# 7            Multi-day Tours • Hiking & Camping Tours  Al Ula  Saudi Arabia
# 8                      Historic Sites • Ancient Ruins  Al Ula  Saudi Arabia
# 9                        Multi-day Tours • Bike Tours  Al Ula  Saudi Arabia
# 10    Historic Sites • Points of Interest & Landmarks  Al Ula  Saudi Arabia
# 11           Multi-day Tours • Hiking & Camping Tours  Al Ula  Saudi Arabia
# 12                                      Ancient Ruins  Al Ula  Saudi Arabia
# 13   Hiking & Camping Tours • Nature & Wildlife Tours  Al Ula  Saudi Arabia
# 14                            Nature & Wildlife Tours  Al Ula  Saudi Arabia
# 15  Parasailing & Paragliding • River Rafting & Tu...  Al Ula  Saudi Arabia
# 16               City Tours • Paint & Pottery Studios  Al Ula  Saudi Arabia
# 17                         Adrenaline & Extreme Tours  Al Ula  Saudi Arabia
# 18            Private Tours • Nature & Wildlife Tours  Al Ula  Saudi Arabia

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  19 non-null     object
#  1   Attraction Type  19 non-null     object
#  2   City             19 non-null     object
#  3   Country          19 non-null     object
# dtypes: object(4)
# memory usage: 736.0+ bytes

# %%
# Store the clean dataset
df.to_csv('AlUlaclean.csv')
