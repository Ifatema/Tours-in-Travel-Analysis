# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('LV.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'FmrIP href', 'dugSS src', 'bUshh', 'cIVmB', 'iPqaD href 2',
#        'WlYyy 2', 'iPqaD href 3', 'dugSS src 2', 'WlYyy 3', 'iPqaD',
#        'iPqaD href 5', 'WlYyy 4', 'dkvhj', 'WlYyy 5', 'WlYyy 6'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  2,000+ places sorted by traveler favorites
# 1                                      26,170
# 2                                      25,354
# 3                                      34,685
# 4                                      91,518
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                         bUshh  cIVmB  \
# 0                                         NaN    NaN
# 1  Red Rock Canyon National Conservation Area    1.0
# 2                                 High Roller    2.0
# 3                                   The Strip    3.0
# 4                       Fountains of Bellagio    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                              WlYyy 2  \
# 0                                                NaN
# 1                       State Parks • National Parks
# 2                         Observation Decks & Towers
# 3  Points of Interest & Landmarks • Historic Walk...
# 4         Points of Interest & Landmarks • Fountains
#
#                                       iPqaD href 3  \
# 0                                              NaN
# 1     https://www.tripadvisor.com/Profile/kyleg175
# 2     https://www.tripadvisor.com/Profile/aeuhardy
# 3   https://www.tripadvisor.com/Profile/ninandmark
# 4  https://www.tripadvisor.com/Profile/margiepiano
#
#                                          dugSS src 2 WlYyy 3        iPqaD  \
# 0                                                NaN     NaN          NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By     kyleg175
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      By     aeuhardy
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...      By   ninandmark
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...      By  margiepiano
#
#                                         iPqaD href 5  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/ShowUserReviews-g4...
# 2  https://www.tripadvisor.com/ShowUserReviews-g4...
# 3  https://www.tripadvisor.com/ShowUserReviews-g4...
# 4  https://www.tripadvisor.com/ShowUserReviews-g4...
#
#                                              WlYyy 4            dkvhj  \
# 0                                                NaN              NaN
# 1                                                The     scenic drive
# 2  Highly recommend, the sights are breath taking...       happy hour
# 3  ... place you must visit in your lifetime it’s...  people watching
# 4  ... Hollywood the fountains are beautiful but ...    fountain show
#
#                                              WlYyy 5    WlYyy 6
# 0                                                NaN        NaN
# 1  is gorgeous and if you want to stop and hike t...        NaN
# 2                          pod is the best for sure.  The Strip
# 3                              , shows, and eating!!   Paradise
# 4                                        is perfect!   Paradise

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         652 non-null    object
#  1   FmrIP href    630 non-null    object
#  2   dugSS src     594 non-null    object
#  3   bUshh         630 non-null    object
#  4   cIVmB         630 non-null    float64
#  5   iPqaD href 2  630 non-null    object
#  6   WlYyy 2       651 non-null    object
#  7   iPqaD href 3  346 non-null    object
#  8   dugSS src 2   345 non-null    object
#  9   WlYyy 3       366 non-null    object
#  10  iPqaD         346 non-null    object
#  11  iPqaD href 5  346 non-null    object
#  12  WlYyy 4       363 non-null    object
#  13  dkvhj         346 non-null    object
#  14  WlYyy 5       316 non-null    object
#  15  WlYyy 6       313 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 81.6+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src', 'cIVmB', 'iPqaD href 2','iPqaD href 3', 'dugSS src 2', 'WlYyy 3', 'iPqaD','iPqaD href 5', 'WlYyy 4', 'dkvhj', 'WlYyy 5', 'WlYyy 6'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Las Vegas'
df['Country'] = 'USA'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 19

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                 Attraction Name  \
# 0                                           NaN
# 1    Red Rock Canyon National Conservation Area
# 2                                   High Roller
# 3                                     The Strip
# 4                         Fountains of Bellagio
# ..                                          ...
# 646                            Voie Spa & Salon
# 647                                Gordie Brown
# 648                         Frankie's Tiki Room
# 649                   Coca-Cola Store Las Vegas
# 650                 Countdown Live Escape Games
#
#                                        Attraction Type       City Country
# 0                                                  NaN  Las Vegas     USA
# 1                         State Parks • National Parks  Las Vegas     USA
# 2                           Observation Decks & Towers  Las Vegas     USA
# 3    Points of Interest & Landmarks • Historic Walk...  Las Vegas     USA
# 4           Points of Interest & Landmarks • Fountains  Las Vegas     USA
# ..                                                 ...        ...     ...
# 646                                               Spas  Las Vegas     USA
# 647                             Theatre & Performances  Las Vegas     USA
# 648                                       Bars & Clubs  Las Vegas     USA
# 649                            Speciality & Gift Shops  Las Vegas     USA
# 650                                       Escape Games  Las Vegas     USA
#
# [633 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    22
# Attraction Type     1
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                 Attraction Name  \
# 0                                           NaN
# 1    Red Rock Canyon National Conservation Area
# 2                                   High Roller
# 3                                     The Strip
# 4                         Fountains of Bellagio
# ..                                          ...
# 647                                Gordie Brown
# 648                         Frankie's Tiki Room
# 649                   Coca-Cola Store Las Vegas
# 650                 Countdown Live Escape Games
# 651                                         NaN
#
#                                        Attraction Type       City Country
# 0                                                  NaN  Las Vegas     USA
# 1                         State Parks • National Parks  Las Vegas     USA
# 2                           Observation Decks & Towers  Las Vegas     USA
# 3    Points of Interest & Landmarks • Historic Walk...  Las Vegas     USA
# 4           Points of Interest & Landmarks • Fountains  Las Vegas     USA
# ..                                                 ...        ...     ...
# 647                             Theatre & Performances  Las Vegas     USA
# 648                                       Bars & Clubs  Las Vegas     USA
# 649                            Speciality & Gift Shops  Las Vegas     USA
# 650                                       Escape Games  Las Vegas     USA
# 651                                                  1  Las Vegas     USA
#
# [652 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  630 non-null    object
#  1   Attraction Type  651 non-null    object
#  2   City             652 non-null    object
#  3   Country          652 non-null    object
# dtypes: object(4)
# memory usage: 20.5+ KB

# %%
# Store the clean dataset
df.to_csv('LVclean.csv')
