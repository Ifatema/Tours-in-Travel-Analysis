# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Hong Kong.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'FmrIP href', 'dugSS src', 'bUshh', 'cIVmB', 'iPqaD href 2',
#        'WlYyy 2', 'WlYyy 3', 'iPqaD href 3', 'dugSS src 2', 'WlYyy 4', 'iPqaD',
#        'iPqaD href 5', 'WlYyy 5', 'dkvhj', 'WlYyy 6'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  2,000+ places sorted by traveler favorites
# 1                                      14,788
# 2                                      36,141
# 3                                      24,466
# 4                                       7,429
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                           bUshh  cIVmB  \
# 0                           NaN    NaN
# 1  Tian Tan Buddha (Big Buddha)    1.0
# 2      Victoria Peak (The Peak)    2.0
# 3                    Star Ferry    3.0
# 4                Ngong Ping 360    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                              WlYyy 2          WlYyy 3  \
# 0                                                NaN              NaN
# 1  Points of Interest & Landmarks • Architectural...  New Territories
# 2                         Observation Decks & Towers             Peak
# 3                                            Ferries    Tsim Sha Tsui
# 4             Trams • Points of Interest & Landmarks  New Territories
#
#                                         iPqaD href 3  \
# 0                                                NaN
# 1        https://www.tripadvisor.com/Profile/1faithh
# 2  https://www.tripadvisor.com/Profile/RaulEstevez54
# 3  https://www.tripadvisor.com/Profile/Dr_Stephen_So
# 4    https://www.tripadvisor.com/Profile/Flo-floreen
#
#                                          dugSS src 2 WlYyy 4          iPqaD  \
# 0                                                NaN     NaN            NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By        1faithh
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      By  RaulEstevez54
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...      By  Dr_Stephen_So
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...      By    Flo-floreen
#
#                                         iPqaD href 5  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/ShowUserReviews-g2...
# 2  https://www.tripadvisor.com/ShowUserReviews-g2...
# 3  https://www.tripadvisor.com/ShowUserReviews-g2...
# 4  https://www.tripadvisor.com/ShowUserReviews-g2...
#
#                                              WlYyy 5             dkvhj  \
# 0                                                NaN               NaN
# 1   Taking a tour of Lantau - ferry, bus, the amazig         cable car
# 2  Every time we visit Hong Kong is a ritual we m...     Victoria peak
# 3  ... get to experience the breeze across the ha...  Hong Kong island
# 4  is the best choice while you ride Ngong Ping c...     Crystal cabin
#
#                                              WlYyy 6
# 0                                                NaN
# 1  and train in a glorious circuit which included...
# 2    and enjoy the wonderful views of Hong Kong w...
# 3                                                  .
# 4                                                NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         528 non-null    object
#  1   FmrIP href    510 non-null    object
#  2   dugSS src     510 non-null    object
#  3   bUshh         510 non-null    object
#  4   cIVmB         510 non-null    float64
#  5   iPqaD href 2  510 non-null    object
#  6   WlYyy 2       522 non-null    object
#  7   WlYyy 3       497 non-null    object
#  8   iPqaD href 3  133 non-null    object
#  9   dugSS src 2   133 non-null    object
#  10  WlYyy 4       148 non-null    object
#  11  iPqaD         133 non-null    object
#  12  iPqaD href 5  133 non-null    object
#  13  WlYyy 5       132 non-null    object
#  14  dkvhj         133 non-null    object
#  15  WlYyy 6       126 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 66.1+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src', 'cIVmB', 'iPqaD href 2','WlYyy 3', 'iPqaD href 3', 'dugSS src 2', 'WlYyy 4', 'iPqaD','iPqaD href 5', 'WlYyy 5', 'dkvhj', 'WlYyy 6'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Hong Kong'
df['Country'] = 'China'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 16

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                   Attraction Name  \
# 0                             NaN
# 1    Tian Tan Buddha (Big Buddha)
# 2        Victoria Peak (The Peak)
# 3                      Star Ferry
# 4                  Ngong Ping 360
# ..                            ...
# 522            Landmark Alexandra
# 523     Fanling Town Centre Plaza
# 524   Fung Yuen Butterfly Reserve
# 525                  Island Place
# 526          Chinese Goods Centre
#
#                                        Attraction Type       City Country
# 0                                                  NaN  Hong Kong   China
# 1    Points of Interest & Landmarks • Architectural...  Hong Kong   China
# 2                           Observation Decks & Towers  Hong Kong   China
# 3                                              Ferries  Hong Kong   China
# 4               Trams • Points of Interest & Landmarks  Hong Kong   China
# ..                                                 ...        ...     ...
# 522                                     Shopping Malls  Hong Kong   China
# 523                                     Shopping Malls  Hong Kong   China
# 524                            Nature & Wildlife Areas  Hong Kong   China
# 525                                     Shopping Malls  Hong Kong   China
# 526                                     Shopping Malls  Hong Kong   China
#
# [512 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    18
# Attraction Type     6
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                   Attraction Name  \
# 0                             NaN
# 1    Tian Tan Buddha (Big Buddha)
# 2        Victoria Peak (The Peak)
# 3                      Star Ferry
# 4                  Ngong Ping 360
# ..                            ...
# 523     Fanling Town Centre Plaza
# 524   Fung Yuen Butterfly Reserve
# 525                  Island Place
# 526          Chinese Goods Centre
# 527                           NaN
#
#                                        Attraction Type       City Country
# 0                                                  NaN  Hong Kong   China
# 1    Points of Interest & Landmarks • Architectural...  Hong Kong   China
# 2                           Observation Decks & Towers  Hong Kong   China
# 3                                              Ferries  Hong Kong   China
# 4               Trams • Points of Interest & Landmarks  Hong Kong   China
# ..                                                 ...        ...     ...
# 523                                     Shopping Malls  Hong Kong   China
# 524                            Nature & Wildlife Areas  Hong Kong   China
# 525                                     Shopping Malls  Hong Kong   China
# 526                                     Shopping Malls  Hong Kong   China
# 527                                                  1  Hong Kong   China
#
# [528 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  510 non-null    object
#  1   Attraction Type  522 non-null    object
#  2   City             528 non-null    object
#  3   Country          528 non-null    object
# dtypes: object(4)
# memory usage: 16.6+ KB

# %%
# Store the clean dataset
df.to_csv('Hong Kongclean.csv')
