# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('NewYork.csv')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  5,000+ places sorted by traveler favorites
# 1                                      95,552
# 2                                      54,731
# 3                                     133,055
# 4                                      92,293
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                  bUshh  cIVmB  \
# 0                                  NaN    NaN
# 1  The National 9/11 Memorial & Museum    1.0
# 2       The Metropolitan Museum of Art    2.0
# 3                         Central Park    3.0
# 4                Empire State Building    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                              WlYyy 2  \
# 0                                                NaN
# 1                Speciality Museums • Historic Sites
# 2       Points of Interest & Landmarks • Art Museums
# 3             Points of Interest & Landmarks • Parks
# 4  Points of Interest & Landmarks • Architectural...
#
#                          WlYyy 3  \
# 0                            NaN
# 1  Downtown Manhattan (Downtown)
# 2                   Central Park
# 3                   Central Park
# 4                        Midtown
#
#                                         iPqaD href 3  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Profile/teresaanne...
# 2  https://www.tripadvisor.com/Profile/V553GTcaro...
# 3   https://www.tripadvisor.com/Profile/Cindyonthego
# 4   https://www.tripadvisor.com/Profile/brianmeshkin
#
#                                          dugSS src 2 WlYyy 5  \
# 0                                                NaN     NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      By
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...      By
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...      By
#
#               iPqaD                                       iPqaD href 5  \
# 0               NaN                                                NaN
# 1  teresaannemartin  https://www.tripadvisor.com/ShowUserReviews-g6...
# 2    V553GTcarolynh  https://www.tripadvisor.com/ShowUserReviews-g6...
# 3      Cindyonthego  https://www.tripadvisor.com/ShowUserReviews-g6...
# 4      brianmeshkin  https://www.tripadvisor.com/ShowUserReviews-g6...
#
#                                              WlYyy 6                 dkvhj  \
# 0                                                NaN                   NaN
# 1  A wonderful memorial, a very emotional place, ...  who lost their lives
# 2                                         I love the         American wing
# 3                                              Loved     Strawberry Fields
# 4                                      We bought the          Express Pass
#
#                                              WlYyy 7
# 0                                                NaN
# 1                                 and a beautiful...
# 2  , but hey, if all they have is Greek and Roman...
# 3  forever and John Lennon memorial, the views of...
# 4  and when we got up to the observation tower on...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         1354 non-null   object
#  1   FmrIP href    1302 non-null   object
#  2   dugSS src     1207 non-null   object
#  3   bUshh         1302 non-null   object
#  4   cIVmB         1302 non-null   float64
#  5   iPqaD href 2  1298 non-null   object
#  6   WlYyy 2       1357 non-null   object
#  7   WlYyy 3       1267 non-null   object
#  8   iPqaD href 3  436 non-null    object
#  9   dugSS src 2   436 non-null    object
#  10  WlYyy 5       436 non-null    object
#  11  iPqaD         436 non-null    object
#  12  iPqaD href 5  436 non-null    object
#  13  WlYyy 6       432 non-null    object
#  14  dkvhj         436 non-null    object
#  15  WlYyy 7       393 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 170.0+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src', 'cIVmB', 'iPqaD href 2','WlYyy 3', 'iPqaD href 3', 'dugSS src 2', 'WlYyy 5', 'iPqaD','iPqaD href 5', 'WlYyy 6', 'dkvhj', 'WlYyy 7'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'NewYork'
df['Country'] = 'USA'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 187

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                           Attraction Name  \
# 0                                     NaN
# 1     The National 9/11 Memorial & Museum
# 2          The Metropolitan Museum of Art
# 3                            Central Park
# 4                   Empire State Building
# ...                                   ...
# 1353                        NYC Guide Pro
# 1354                   9/11 Walking Tours
# 1355                          Tour Patron
# 1356                            Tomi Jazz
# 1357                               Amtrak
#
#                                         Attraction Type     City Country
# 0                                                   NaN  NewYork     USA
# 1                   Speciality Museums • Historic Sites  NewYork     USA
# 2          Points of Interest & Landmarks • Art Museums  NewYork     USA
# 3                Points of Interest & Landmarks • Parks  NewYork     USA
# 4     Points of Interest & Landmarks • Architectural...  NewYork     USA
# ...                                                 ...      ...     ...
# 1353           City Tours • Historical & Heritage Tours  NewYork     USA
# 1354        Historical & Heritage Tours • Walking Tours  NewYork     USA
# 1355                                          Day Trips  NewYork     USA
# 1356                                          Jazz Bars  NewYork     USA
# 1357                                      Rail Services  NewYork     USA
#
# [1172 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    57
# Attraction Type     2
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                           Attraction Name  \
# 0                                     NaN
# 1     The National 9/11 Memorial & Museum
# 2          The Metropolitan Museum of Art
# 3                            Central Park
# 4                   Empire State Building
# ...                                   ...
# 1354                   9/11 Walking Tours
# 1355                          Tour Patron
# 1356                            Tomi Jazz
# 1357                               Amtrak
# 1358                                  NaN
#
#                                         Attraction Type     City Country
# 0                                                   NaN  NewYork     USA
# 1                   Speciality Museums • Historic Sites  NewYork     USA
# 2          Points of Interest & Landmarks • Art Museums  NewYork     USA
# 3                Points of Interest & Landmarks • Parks  NewYork     USA
# 4     Points of Interest & Landmarks • Architectural...  NewYork     USA
# ...                                                 ...      ...     ...
# 1354        Historical & Heritage Tours • Walking Tours  NewYork     USA
# 1355                                          Day Trips  NewYork     USA
# 1356                                          Jazz Bars  NewYork     USA
# 1357                                      Rail Services  NewYork     USA
# 1358                                                  1  NewYork     USA
#
# [1359 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1359 entries, 0 to 1358
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  1302 non-null   object
#  1   Attraction Type  1357 non-null   object
#  2   City             1359 non-null   object
#  3   Country          1359 non-null   object
# dtypes: object(4)
# memory usage: 42.6+ KB

# %%
# Store the clean dataset
df.to_csv('NewYorkclean.csv')
