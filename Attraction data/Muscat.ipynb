# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Muscat.csv')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                      WlYyy  \
# 0  354 places sorted by traveler favorites
# 1                                    6,025
# 2                                    2,472
# 3                                      825
# 4                                      709
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                         bUshh  cIVmB  \
# 0                         NaN    NaN
# 1  Sultan Qaboos Grand Mosque    1.0
# 2           Royal Opera House    2.0
# 3            Wadi Bani Khalid    3.0
# 4             Bimmah Sinkhole    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                              WlYyy 2  \
# 0                                                NaN
# 1                                    Religious Sites
# 2                 Architectural Buildings • Theaters
# 3                            Nature & Wildlife Areas
# 4  Points of Interest & Landmarks • Geologic Form...
#
#                                         iPqaD href 3  \
# 0                                                NaN
# 1      https://www.tripadvisor.com/Profile/woebetide
# 2  https://www.tripadvisor.com/Profile/Vicky07Mia...
# 3  https://www.tripadvisor.com/Profile/ChicaAdven...
# 4         https://www.tripadvisor.com/Profile/kv2707
#
#                                          dugSS src 2 WlYyy 3            iPqaD  \
# 0                                                NaN     NaN              NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By        woebetide
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      By  Vicky07Miami_FL
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...      By   ChicaAdventura
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...      By           kv2707
#
#                                         iPqaD href 5  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/ShowUserReviews-g1...
# 2  https://www.tripadvisor.com/ShowUserReviews-g1...
# 3  https://www.tripadvisor.com/ShowUserReviews-g1...
# 4  https://www.tripadvisor.com/ShowUserReviews-g1...
#
#                                         WlYyy 4             dkvhj WlYyy 6
# 0                                           NaN               NaN     NaN
# 1          What a truely wonderful building the      grand mosque     NaN
# 2                 Omanis are lucky to have this  amazing building     NaN
# 3  with date palms and ancient watering system.   Beautiful oasis     NaN
# 4                        We visited enroute the         Wadi Shab     NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         247 non-null    object
#  1   FmrIP href    311 non-null    object
#  2   dugSS src     284 non-null    object
#  3   bUshh         311 non-null    object
#  4   cIVmB         311 non-null    float64
#  5   iPqaD href 2  234 non-null    object
#  6   WlYyy 2       323 non-null    object
#  7   iPqaD href 3  65 non-null     object
#  8   dugSS src 2   65 non-null     object
#  9   WlYyy 3       76 non-null     object
#  10  iPqaD         65 non-null     object
#  11  iPqaD href 5  65 non-null     object
#  12  WlYyy 4       74 non-null     object
#  13  dkvhj         65 non-null     object
#  14  WlYyy 6       97 non-null     object
# dtypes: float64(1), object(14)
# memory usage: 38.1+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src', 'cIVmB', 'iPqaD href 2', 'iPqaD href 3', 'dugSS src 2', 'WlYyy 3', 'iPqaD','iPqaD href 5', 'WlYyy 4', 'dkvhj', 'WlYyy 6'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Muscat'
df['Country'] = 'Oman'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 21

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                 Attraction Name  \
# 0                           NaN
# 1    Sultan Qaboos Grand Mosque
# 2             Royal Opera House
# 3              Wadi Bani Khalid
# 4               Bimmah Sinkhole
# ..                          ...
# 318            TRAVEL POINT LLC
# 319                   PST tours
# 320    Inara Travel and Tourism
# 321             Boats and Dhows
# 322          Oman Culture Tours
#
#                                        Attraction Type    City Country
# 0                                                  NaN  Muscat    Oman
# 1                                      Religious Sites  Muscat    Oman
# 2                   Architectural Buildings • Theaters  Muscat    Oman
# 3                              Nature & Wildlife Areas  Muscat    Oman
# 4    Points of Interest & Landmarks • Geologic Form...  Muscat    Oman
# ..                                                 ...     ...     ...
# 318                     Escape Games • Multi-day Tours  Muscat    Oman
# 319                 Multi-day Tours • Taxis & Shuttles  Muscat    Oman
# 320                    Multi-day Tours • Private Tours  Muscat    Oman
# 321                   Scuba & Snorkelling • Boat Tours  Muscat    Oman
# 322        Multi-day Tours • 4WD, ATV & Off-Road Tours  Muscat    Oman
#
# [303 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    13
# Attraction Type     1
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                 Attraction Name  \
# 0                           NaN
# 1    Sultan Qaboos Grand Mosque
# 2             Royal Opera House
# 3              Wadi Bani Khalid
# 4               Bimmah Sinkhole
# ..                          ...
# 319                   PST tours
# 320    Inara Travel and Tourism
# 321             Boats and Dhows
# 322          Oman Culture Tours
# 323                         NaN
#
#                                        Attraction Type    City Country
# 0                                                  NaN  Muscat    Oman
# 1                                      Religious Sites  Muscat    Oman
# 2                   Architectural Buildings • Theaters  Muscat    Oman
# 3                              Nature & Wildlife Areas  Muscat    Oman
# 4    Points of Interest & Landmarks • Geologic Form...  Muscat    Oman
# ..                                                 ...     ...     ...
# 319                 Multi-day Tours • Taxis & Shuttles  Muscat    Oman
# 320                    Multi-day Tours • Private Tours  Muscat    Oman
# 321                   Scuba & Snorkelling • Boat Tours  Muscat    Oman
# 322        Multi-day Tours • 4WD, ATV & Off-Road Tours  Muscat    Oman
# 323                                                  1  Muscat    Oman
#
# [324 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  311 non-null    object
#  1   Attraction Type  323 non-null    object
#  2   City             324 non-null    object
#  3   Country          324 non-null    object
# dtypes: object(4)
# memory usage: 10.2+ KB

# %%
# Store the clean dataset
df.to_csv('Muscatclean.csv')
