# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Orlando.csv')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  1,000+ places sorted by traveler favorites
# 1                                      41,077
# 2                                      51,826
# 3                                      34,372
# 4                                      40,366
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                          dugSS src 2  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2                                                NaN
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4                                                NaN
#
#                                  bUshh  cIVmB  \
# 0                                  NaN    NaN
# 1  The Wizarding World of Harry Potter    1.0
# 2     Universal's Islands of Adventure    2.0
# 3   Disney's Animal Kingdom Theme Park    3.0
# 4            Universal Studios Florida    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                              WlYyy 2         WlYyy 3  \
# 0                                                NaN             NaN
# 1                            Amusement & Theme Parks  Florida Center
# 2                            Amusement & Theme Parks  Florida Center
# 3  Amusement & Theme Parks • Disney Parks & Activ...             NaN
# 4                            Amusement & Theme Parks  Florida Center
#
#                                        iPqaD href 3 WlYyy 5         iPqaD  \
# 0                                               NaN     NaN           NaN
# 1  https://www.tripadvisor.com/Profile/MonikaR_1207      By  MonikaR_1207
# 2  https://www.tripadvisor.com/Profile/snorkler2014      By  snorkler2014
# 3  https://www.tripadvisor.com/Profile/Owenladyvols      By  Owenladyvols
# 4         https://www.tripadvisor.com/Profile/TW987      By         TW987
#
#                                         iPqaD href 5  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/ShowUserReviews-g3...
# 2  https://www.tripadvisor.com/ShowUserReviews-g3...
# 3  https://www.tripadvisor.com/ShowUserReviews-g3...
# 4  https://www.tripadvisor.com/ShowUserReviews-g3...
#
#                                              WlYyy 6          dkvhj  \
# 0                                                NaN            NaN
# 1  Such an amazing adventure to explore..the ride...    butter beer
# 2                                               Also  Jurassic park
# 3           The attractions are just great- from the   safari- ride
# 4     Great trip to Universal - highly recommend the   Express Pass
#
#                                              WlYyy 7
# 0                                                NaN
# 1                                       , delicious.
# 2  Dudley do right and Popeyes raft ride all Amaz...
# 3  early because animals are most active to our f...
# 4  (free when at the on-site hotels), it makes su...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         429 non-null    object
#  1   FmrIP href    412 non-null    object
#  2   dugSS src     363 non-null    object
#  3   dugSS src 2   123 non-null    object
#  4   bUshh         412 non-null    object
#  5   cIVmB         412 non-null    float64
#  6   iPqaD href 2  412 non-null    object
#  7   WlYyy 2       428 non-null    object
#  8   WlYyy 3       95 non-null     object
#  9   iPqaD href 3  165 non-null    object
#  10  WlYyy 5       165 non-null    object
#  11  iPqaD         165 non-null    object
#  12  iPqaD href 5  165 non-null    object
#  13  WlYyy 6       165 non-null    object
#  14  dkvhj         165 non-null    object
#  15  WlYyy 7       150 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 53.8+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src', 'dugSS src 2', 'cIVmB','iPqaD href 2', 'WlYyy 3', 'iPqaD href 3', 'WlYyy 5','iPqaD', 'iPqaD href 5', 'WlYyy 6', 'dkvhj', 'WlYyy 7'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Orlando'
df['Country'] = 'USA'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 66

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                               Attraction Name  \
# 0                                         NaN
# 1         The Wizarding World of Harry Potter
# 2            Universal's Islands of Adventure
# 3          Disney's Animal Kingdom Theme Park
# 4                   Universal Studios Florida
# ..                                        ...
# 417                Skippy Transportation, Inc
# 418  Luxury of Time by Diamonds International
# 419                         The Escape Effect
# 420                  Cortrans Shuttle Service
# 421                            Bob's Balloons
#
#                                        Attraction Type     City Country
# 0                                                  NaN  Orlando     USA
# 1                              Amusement & Theme Parks  Orlando     USA
# 2                              Amusement & Theme Parks  Orlando     USA
# 3    Amusement & Theme Parks • Disney Parks & Activ...  Orlando     USA
# 4                              Amusement & Theme Parks  Orlando     USA
# ..                                                 ...      ...     ...
# 417                                   Taxis & Shuttles  Orlando     USA
# 418                            Speciality & Gift Shops  Orlando     USA
# 419                  Escape Games • Rides & Activities  Orlando     USA
# 420                                   Taxis & Shuttles  Orlando     USA
# 421                                      Balloon Rides  Orlando     USA
#
# [363 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    17
# Attraction Type     1
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                           Attraction Name  \
# 0                                     NaN
# 1     The Wizarding World of Harry Potter
# 2        Universal's Islands of Adventure
# 3      Disney's Animal Kingdom Theme Park
# 4               Universal Studios Florida
# ..                                    ...
# 424                  Devon Transportation
# 425                  Orlando Transfer LLC
# 426               Real Florida Adventures
# 427  Native Bass Fishing Charters Orlando
# 428                                   NaN
#
#                                        Attraction Type     City Country
# 0                                                  NaN  Orlando     USA
# 1                              Amusement & Theme Parks  Orlando     USA
# 2                              Amusement & Theme Parks  Orlando     USA
# 3    Amusement & Theme Parks • Disney Parks & Activ...  Orlando     USA
# 4                              Amusement & Theme Parks  Orlando     USA
# ..                                                 ...      ...     ...
# 424                                   Taxis & Shuttles  Orlando     USA
# 425                                   Taxis & Shuttles  Orlando     USA
# 426                        City Tours • Cultural Tours  Orlando     USA
# 427                           Fishing Charters & Tours  Orlando     USA
# 428                                                  1  Orlando     USA
#
# [429 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  412 non-null    object
#  1   Attraction Type  428 non-null    object
#  2   City             429 non-null    object
#  3   Country          429 non-null    object
# dtypes: object(4)
# memory usage: 13.5+ KB

# %%
# Store the clean dataset
df.to_csv('Orlandoclean.csv')
