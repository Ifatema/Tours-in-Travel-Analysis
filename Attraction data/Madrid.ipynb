# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Madrid.csv')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  3,000+ places sorted by traveler favorites
# 1                                      57,049
# 2                                      55,960
# 3                                      22,715
# 4                                      34,730
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                        bUshh  cIVmB  \
# 0                        NaN    NaN
# 1      Prado National Museum    1.0
# 2          Parque del Retiro    2.0
# 3  Santiago Bernabeu Stadium    3.0
# 4     Royal Palace of Madrid    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                     WlYyy 2    WlYyy 3  \
# 0                                       NaN        NaN
# 1                               Art Museums     Retiro
# 2                                     Parks     Retiro
# 3                         Arenas & Stadiums  Chamartín
# 4  Historic Sites • Architectural Buildings     Centro
#
#                                         iPqaD href 3  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Profile/hernandesf...
# 2    https://www.tripadvisor.com/Profile/johannak656
# 3   https://www.tripadvisor.com/Profile/F4554KUmarch
# 4    https://www.tripadvisor.com/Profile/147summer01
#
#                                          dugSS src 2 WlYyy 5           iPqaD  \
# 0                                                NaN     NaN             NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By  hernandesf2015
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      By     johannak656
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...      By    F4554KUmarch
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...      By     147summer01
#
#                                         iPqaD href 5  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/ShowUserReviews-g1...
# 2  https://www.tripadvisor.com/ShowUserReviews-g1...
# 3  https://www.tripadvisor.com/ShowUserReviews-g1...
# 4  https://www.tripadvisor.com/ShowUserReviews-g1...
#
#                                              WlYyy 6           dkvhj  \
# 0                                                NaN             NaN
# 1  Best artist in the world (including best colle...        El Greco
# 2  A wonderful place to walk, nap, row, snack - b...  crystal palace
# 3  ... tour without a tour guide and it was fanta...     trophy room
# 4  My family and I really enjoyed and appreciated...    Royal Palace
#
#                                       WlYyy 7
# 0                                         NaN
# 1  and Velazquez), everything well organiz...
# 2             , beautiful little lake, rea...
# 3                                           .
# 4                Very relaxing and beautiful.

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387 entries, 0 to 386
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         387 non-null    object
#  1   FmrIP href    371 non-null    object
#  2   dugSS src     371 non-null    object
#  3   bUshh         371 non-null    object
#  4   cIVmB         371 non-null    float64
#  5   iPqaD href 2  371 non-null    object
#  6   WlYyy 2       386 non-null    object
#  7   WlYyy 3       376 non-null    object
#  8   iPqaD href 3  98 non-null     object
#  9   dugSS src 2   98 non-null     object
#  10  WlYyy 5       98 non-null     object
#  11  iPqaD         98 non-null     object
#  12  iPqaD href 5  98 non-null     object
#  13  WlYyy 6       97 non-null     object
#  14  dkvhj         98 non-null     object
#  15  WlYyy 7       92 non-null     object
# dtypes: float64(1), object(15)
# memory usage: 48.5+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src',  'cIVmB', 'iPqaD href 2','WlYyy 3', 'iPqaD href 3', 'dugSS src 2', 'WlYyy 5', 'iPqaD','iPqaD href 5', 'WlYyy 6', 'dkvhj', 'WlYyy 7'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Madrid'
df['Country'] = 'Spain'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 24

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                Attraction Name                           Attraction Type  \
# 0                          NaN                                       NaN
# 1        Prado National Museum                               Art Museums
# 2            Parque del Retiro                                     Parks
# 3    Santiago Bernabeu Stadium                         Arenas & Stadiums
# 4       Royal Palace of Madrid  Historic Sites • Architectural Buildings
# ..                         ...                                       ...
# 381     Ministerio de Justicia            Points of Interest & Landmarks
# 382               Teatro Alfil                                  Theaters
# 383        Galeria Marlborough                             Art Galleries
# 384       Parque Juan Pablo II                                     Parks
# 385        Teatro de las Aguas                                  Theaters
#
#        City Country
# 0    Madrid   Spain
# 1    Madrid   Spain
# 2    Madrid   Spain
# 3    Madrid   Spain
# 4    Madrid   Spain
# ..      ...     ...
# 381  Madrid   Spain
# 382  Madrid   Spain
# 383  Madrid   Spain
# 384  Madrid   Spain
# 385  Madrid   Spain
#
# [363 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    16
# Attraction Type     1
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                Attraction Name                           Attraction Type  \
# 0                          NaN                                       NaN
# 1        Prado National Museum                               Art Museums
# 2            Parque del Retiro                                     Parks
# 3    Santiago Bernabeu Stadium                         Arenas & Stadiums
# 4       Royal Palace of Madrid  Historic Sites • Architectural Buildings
# ..                         ...                                       ...
# 382               Teatro Alfil                                  Theaters
# 383        Galeria Marlborough                             Art Galleries
# 384       Parque Juan Pablo II                                     Parks
# 385        Teatro de las Aguas                                  Theaters
# 386                        NaN                                         1
#
#        City Country
# 0    Madrid   Spain
# 1    Madrid   Spain
# 2    Madrid   Spain
# 3    Madrid   Spain
# 4    Madrid   Spain
# ..      ...     ...
# 382  Madrid   Spain
# 383  Madrid   Spain
# 384  Madrid   Spain
# 385  Madrid   Spain
# 386  Madrid   Spain
#
# [387 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387 entries, 0 to 386
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  371 non-null    object
#  1   Attraction Type  386 non-null    object
#  2   City             387 non-null    object
#  3   Country          387 non-null    object
# dtypes: object(4)
# memory usage: 12.2+ KB

# %%
# Store the clean dataset
df.to_csv('Madridclean.csv')
