# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Rome.csv')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  5,000+ places sorted by traveler favorites
# 1                                      78,703
# 2                                     147,404
# 3                                      24,791
# 4                                      25,069
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src          bUshh  cIVmB  \
# 0                                                NaN            NaN    NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...       Pantheon    1.0
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      Colosseum    2.0
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...    Roman Forum    3.0
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...  Palatine Hill    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            WlYyy 2  \
# 0                                              NaN
# 1          Ancient Ruins • Architectural Buildings
# 2                   Historic Sites • Ancient Ruins
# 3  Historic Sites • Points of Interest & Landmarks
# 4                   Historic Sites • Ancient Ruins
#
#                                WlYyy 3 TCGml   WlYyy 4  \
# 0                                  NaN   NaN       NaN
# 1  Navona / Pantheon / Campo de’ Fiori     •  Open now
# 2                                Celio   NaN       NaN
# 3                           Campitelli     •  Open now
# 4                           Campitelli   NaN       NaN
#
#                                         iPqaD href 3  \
# 0                                                NaN
# 1      https://www.tripadvisor.com/Profile/835SteveD
# 2  https://www.tripadvisor.com/Profile/tRAVellerO...
# 3      https://www.tripadvisor.com/Profile/793LindaC
# 4      https://www.tripadvisor.com/Profile/alisdairt
#
#                                          dugSS src 2 WlYyy 6  \
# 0                                                NaN     NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      By
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...      By
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...      By
#
#                  iPqaD                                       iPqaD href 5  \
# 0                  NaN                                                NaN
# 1            835SteveD  https://www.tripadvisor.com/ShowUserReviews-g1...
# 2  tRAVellerOfTheW0rld  https://www.tripadvisor.com/ShowUserReviews-g1...
# 3            793LindaC  https://www.tripadvisor.com/ShowUserReviews-g1...
# 4            alisdairt  https://www.tripadvisor.com/ShowUserReviews-g1...
#
#                                              WlYyy 7
# 0                                                NaN
# 1  This is an authentic Augustan monument that ha...
# 2  The immense amphitheater was built on a former...
# 3  With centuries of history and neglect until th...
# 4  Part of the vast Roman Forum complex, Palatine...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         444 non-null    object
#  1   FmrIP href    425 non-null    object
#  2   dugSS src     424 non-null    object
#  3   bUshh         425 non-null    object
#  4   cIVmB         425 non-null    float64
#  5   iPqaD href 2  425 non-null    object
#  6   WlYyy 2       443 non-null    object
#  7   WlYyy 3       409 non-null    object
#  8   TCGml         130 non-null    object
#  9   WlYyy 4       148 non-null    object
#  10  iPqaD href 3  106 non-null    object
#  11  dugSS src 2   108 non-null    object
#  12  WlYyy 6       106 non-null    object
#  13  iPqaD         106 non-null    object
#  14  iPqaD href 5  106 non-null    object
#  15  WlYyy 7       106 non-null    object
# dtypes: float64(1), object(15)
# memory usage: 55.6+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src',  'cIVmB', 'iPqaD href 2','WlYyy 3', 'TCGml', 'WlYyy 4', 'iPqaD href 3', 'dugSS src 2','WlYyy 6', 'iPqaD', 'iPqaD href 5', 'WlYyy 7'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Rome'
df['Country'] = 'Itly'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 50

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                       Attraction Name  \
# 0                                                 NaN
# 1                                            Pantheon
# 2                                           Colosseum
# 3                                         Roman Forum
# 4                                       Palatine Hill
# ..                                                ...
# 438                          Quartiere della Vittoria
# 439                               Palazzo Giustiniani
# 440                         Piazza Augusto Imperatore
# 441            Basilica sotterranea di Porta Maggiore
# 442  Chiesa dei Santi Claudio e Andrea dei Borgognoni
#
#                                      Attraction Type  City Country
# 0                                                NaN  Rome    Itly
# 1            Ancient Ruins • Architectural Buildings  Rome    Itly
# 2                     Historic Sites • Ancient Ruins  Rome    Itly
# 3    Historic Sites • Points of Interest & Landmarks  Rome    Itly
# 4                     Historic Sites • Ancient Ruins  Rome    Itly
# ..                                               ...   ...     ...
# 438   Neighborhoods • Points of Interest & Landmarks  Rome    Itly
# 439                   Points of Interest & Landmarks  Rome    Itly
# 440                   Historic Sites • Ancient Ruins  Rome    Itly
# 441                   Historic Sites • Ancient Ruins  Rome    Itly
# 442          Religious Sites • Churches & Cathedrals  Rome    Itly
#
# [394 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    19
# Attraction Type     1
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                       Attraction Name  \
# 0                                                 NaN
# 1                                            Pantheon
# 2                                           Colosseum
# 3                                         Roman Forum
# 4                                       Palatine Hill
# ..                                                ...
# 439                               Palazzo Giustiniani
# 440                         Piazza Augusto Imperatore
# 441            Basilica sotterranea di Porta Maggiore
# 442  Chiesa dei Santi Claudio e Andrea dei Borgognoni
# 443                                               NaN
#
#                                      Attraction Type  City Country
# 0                                                NaN  Rome    Itly
# 1            Ancient Ruins • Architectural Buildings  Rome    Itly
# 2                     Historic Sites • Ancient Ruins  Rome    Itly
# 3    Historic Sites • Points of Interest & Landmarks  Rome    Itly
# 4                     Historic Sites • Ancient Ruins  Rome    Itly
# ..                                               ...   ...     ...
# 439                   Points of Interest & Landmarks  Rome    Itly
# 440                   Historic Sites • Ancient Ruins  Rome    Itly
# 441                   Historic Sites • Ancient Ruins  Rome    Itly
# 442          Religious Sites • Churches & Cathedrals  Rome    Itly
# 443                                                1  Rome    Itly
#
# [444 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 444 entries, 0 to 443
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  425 non-null    object
#  1   Attraction Type  443 non-null    object
#  2   City             444 non-null    object
#  3   Country          444 non-null    object
# dtypes: object(4)
# memory usage: 14.0+ KB

# %%
# Store the clean dataset
df.to_csv('Romeclean.csv')
