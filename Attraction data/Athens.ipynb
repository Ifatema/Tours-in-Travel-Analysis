# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Athens.csv')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  2,000+ places sorted by traveler favorites
# 1                                      35,897
# 2                                      37,044
# 3                                      16,945
# 4                                       7,856
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                             bUshh  cIVmB  \
# 0                             NaN    NaN
# 1                       Acropolis    1.0
# 2                Acropolis Museum    2.0
# 3                       Parthenon    3.0
# 4  National Archaeological Museum    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                           WlYyy 2               WlYyy 3  \
# 0                             NaN                   NaN
# 1  Historic Sites • Ancient Ruins              Open now
# 2                 History Museums  Thissio / Makriyanni
# 3  Historic Sites • Ancient Ruins              Open now
# 4   Art Museums • History Museums              Exarchia
#
#                                         iPqaD href 3  \
# 0                                                NaN
# 1     https://www.tripadvisor.com/Profile/samiam9390
# 2  https://www.tripadvisor.com/Profile/Connector7...
# 3  https://www.tripadvisor.com/Profile/Balkrishna...
# 4  https://www.tripadvisor.com/Profile/Freedom195335
#
#                                          dugSS src 2 WlYyy 5  \
# 0                                                NaN     NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      By
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...      By
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...      By
#
#               iPqaD                                       iPqaD href 5  \
# 0               NaN                                                NaN
# 1        samiam9390  https://www.tripadvisor.com/ShowUserReviews-g1...
# 2   Connector789612  https://www.tripadvisor.com/ShowUserReviews-g1...
# 3  BalkrishnaShroff  https://www.tripadvisor.com/ShowUserReviews-g1...
# 4     Freedom195335  https://www.tripadvisor.com/ShowUserReviews-g1...
#
#                                              WlYyy 6                  dkvhj  \
# 0                                                NaN                    NaN
# 1                                         Be sure to            bring water
# 2  A must for your visit to Athens, a world class...              top floor
# 3  Parthenon is a former temple on the Athenian A...         goddess Athena
# 4                            I loved seeing the real  Antikythera Mechanism
#
#                                              WlYyy 7 TCGml   WlYyy 8
# 0                                                NaN   NaN       NaN
# 1  and wear comfortable and supportive shoes, as ...   NaN       NaN
# 2                                          of the...     •  Open now
# 3                          , whom the people of A...   NaN       NaN
# 4  - a truly amazing ancient computer, whose gear...     •  Open now

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         287 non-null    object
#  1   FmrIP href    276 non-null    object
#  2   dugSS src     247 non-null    object
#  3   bUshh         276 non-null    object
#  4   cIVmB         276 non-null    float64
#  5   iPqaD href 2  275 non-null    object
#  6   WlYyy 2       287 non-null    object
#  7   WlYyy 3       231 non-null    object
#  8   iPqaD href 3  78 non-null     object
#  9   dugSS src 2   78 non-null     object
#  10  WlYyy 5       78 non-null     object
#  11  iPqaD         78 non-null     object
#  12  iPqaD href 5  78 non-null     object
#  13  WlYyy 6       77 non-null     object
#  14  dkvhj         78 non-null     object
#  15  WlYyy 7       72 non-null     object
#  16  TCGml         61 non-null     object
#  17  WlYyy 8       62 non-null     object
# dtypes: float64(1), object(17)
# memory usage: 40.6+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src', 'cIVmB', 'iPqaD href 2', 'WlYyy 3', 'iPqaD href 3', 'dugSS src 2', 'WlYyy 5', 'iPqaD','iPqaD href 5', 'WlYyy 6', 'dkvhj', 'WlYyy 7', 'TCGml', 'WlYyy 8'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Athens'
df['Country'] = 'Greece'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 15

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                     Attraction Name                      Attraction Type  \
# 0                               NaN                                  NaN
# 1                         Acropolis       Historic Sites • Ancient Ruins
# 2                  Acropolis Museum                      History Museums
# 3                         Parthenon       Historic Sites • Ancient Ruins
# 4    National Archaeological Museum        Art Museums • History Museums
# ..                              ...                                  ...
# 282              Food Around Athens       Cultural Tours • Walking Tours
# 283                Olive Sea Travel         City Tours • Multi-day Tours
# 284                     Greeking.me          City Tours • Cultural Tours
# 285         Michael's Amazing Tours  Multi-day Tours • Sightseeing Tours
# 286               Athens Limo Tours   Multi-day Tours • Taxis & Shuttles
#
#        City Country
# 0    Athens  Greece
# 1    Athens  Greece
# 2    Athens  Greece
# 3    Athens  Greece
# 4    Athens  Greece
# ..      ...     ...
# 282  Athens  Greece
# 283  Athens  Greece
# 284  Athens  Greece
# 285  Athens  Greece
# 286  Athens  Greece
#
# [273 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    12
# Attraction Type     1
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                     Attraction Name                      Attraction Type  \
# 0                               NaN                                  NaN
# 1                         Acropolis       Historic Sites • Ancient Ruins
# 2                  Acropolis Museum                      History Museums
# 3                         Parthenon       Historic Sites • Ancient Ruins
# 4    National Archaeological Museum        Art Museums • History Museums
# ..                              ...                                  ...
# 283                Olive Sea Travel         City Tours • Multi-day Tours
# 284                     Greeking.me          City Tours • Cultural Tours
# 285         Michael's Amazing Tours  Multi-day Tours • Sightseeing Tours
# 286               Athens Limo Tours   Multi-day Tours • Taxis & Shuttles
# 287                             NaN                                    1
#
#        City Country
# 0    Athens  Greece
# 1    Athens  Greece
# 2    Athens  Greece
# 3    Athens  Greece
# 4    Athens  Greece
# ..      ...     ...
# 283  Athens  Greece
# 284  Athens  Greece
# 285  Athens  Greece
# 286  Athens  Greece
# 287  Athens  Greece
#
# [288 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  276 non-null    object
#  1   Attraction Type  287 non-null    object
#  2   City             288 non-null    object
#  3   Country          288 non-null    object
# dtypes: object(4)
# memory usage: 9.1+ KB

# %%
# Store the clean dataset
df.to_csv('Athensclean.csv')
