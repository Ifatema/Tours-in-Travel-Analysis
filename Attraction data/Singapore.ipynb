# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Singapore.csv')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  3,000+ places sorted by traveler favorites
# 1                                      59,526
# 2                                      19,820
# 3                                      22,366
# 4                                      13,823
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                        bUshh  cIVmB  \
# 0                        NaN    NaN
# 1         Gardens by the Bay    1.0
# 2  Singapore Botanic Gardens    2.0
# 3              Singapore Zoo    3.0
# 4     National Orchid Garden    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                     WlYyy 2                  WlYyy 3  \
# 0                                       NaN                      NaN
# 1  Points of Interest & Landmarks • Gardens   Central Area/City Area
# 2                           Parks • Gardens                  Tanglin
# 3                                      Zoos  Central Water Catchment
# 4                                   Gardens                  Tanglin
#
#     WlYyy 4                                       iPqaD href 3  \
# 0       NaN                                                NaN
# 1  Open now    https://www.tripadvisor.com/Profile/sharmaamiF1
# 2  Open now        https://www.tripadvisor.com/Profile/Gisadom
# 3       NaN  https://www.tripadvisor.com/Profile/Hayton-family
# 4       NaN       https://www.tripadvisor.com/Profile/jv145294
#
#                                          dugSS src 2 WlYyy 6          iPqaD  \
# 0                                                NaN     NaN            NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By    sharmaamiF1
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      By        Gisadom
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...      By  Hayton-family
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...      By       jv145294
#
#                                         iPqaD href 5  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/ShowUserReviews-g2...
# 2  https://www.tripadvisor.com/ShowUserReviews-g2...
# 3  https://www.tripadvisor.com/ShowUserReviews-g2...
# 4  https://www.tripadvisor.com/ShowUserReviews-g2...
#
#                                              WlYyy 7              dkvhj  \
# 0                                                NaN                NaN
# 1                                      You can visit        Flower Dome
# 2                Amazing gardens with an spectacular      orchid garden
# 3  A must see!! All of the animals are very well ...         Polar bear
# 4  You will find lots of extremely well maintaine...  beautiful orchids
#
#                                              WlYyy 8
# 0                                                NaN
# 1  , Cloud Forest, Serene Garden and OCBC SkyWay ...
# 2  and beautiful spots to relax, have a picnic or...
# 3                              during our visit (...
# 4  , vegetation, trees and some unique orchids de...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872 entries, 0 to 871
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         871 non-null    object
#  1   FmrIP href    837 non-null    object
#  2   dugSS src     771 non-null    object
#  3   bUshh         837 non-null    object
#  4   cIVmB         837 non-null    float64
#  5   iPqaD href 2  836 non-null    object
#  6   WlYyy 2       870 non-null    object
#  7   WlYyy 3       826 non-null    object
#  8   WlYyy 4       191 non-null    object
#  9   iPqaD href 3  234 non-null    object
#  10  dugSS src 2   234 non-null    object
#  11  WlYyy 6       234 non-null    object
#  12  iPqaD         234 non-null    object
#  13  iPqaD href 5  234 non-null    object
#  14  WlYyy 7       233 non-null    object
#  15  dkvhj         234 non-null    object
#  16  WlYyy 8       211 non-null    object
# dtypes: float64(1), object(16)
# memory usage: 115.9+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src', 'cIVmB', 'iPqaD href 2','WlYyy 3', 'WlYyy 4', 'iPqaD href 3', 'dugSS src 2','WlYyy 6', 'iPqaD', 'iPqaD href 5', 'WlYyy 7', 'dkvhj', 'WlYyy 8'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Singapore'
df['Country'] = 'Singapore'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 66

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                Attraction Name                           Attraction Type  \
# 0                          NaN                                       NaN
# 1           Gardens by the Bay  Points of Interest & Landmarks • Gardens
# 2    Singapore Botanic Gardens                           Parks • Gardens
# 3                Singapore Zoo                                      Zoos
# 4       National Orchid Garden                                   Gardens
# ..                         ...                                       ...
# 866            City Unscripted               City Tours • Cultural Tours
# 867       Prime Aces Limousine                          Taxis & Shuttles
# 868     The Bar at 15 Stamford                              Bars & Clubs
# 869       Good Luck Beer House                              Bars & Clubs
# 870            Livin' Da Local     Walking Tours • Beer Tastings & Tours
#
#           City    Country
# 0    Singapore  Singapore
# 1    Singapore  Singapore
# 2    Singapore  Singapore
# 3    Singapore  Singapore
# 4    Singapore  Singapore
# ..         ...        ...
# 866  Singapore  Singapore
# 867  Singapore  Singapore
# 868  Singapore  Singapore
# 869  Singapore  Singapore
# 870  Singapore  Singapore
#
# [806 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    35
# Attraction Type     2
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                Attraction Name                           Attraction Type  \
# 0                          NaN                                       NaN
# 1           Gardens by the Bay  Points of Interest & Landmarks • Gardens
# 2    Singapore Botanic Gardens                           Parks • Gardens
# 3                Singapore Zoo                                      Zoos
# 4       National Orchid Garden                                   Gardens
# ..                         ...                                       ...
# 867       Prime Aces Limousine                          Taxis & Shuttles
# 868     The Bar at 15 Stamford                              Bars & Clubs
# 869       Good Luck Beer House                              Bars & Clubs
# 870            Livin' Da Local     Walking Tours • Beer Tastings & Tours
# 871                        NaN                                         1
#
#           City    Country
# 0    Singapore  Singapore
# 1    Singapore  Singapore
# 2    Singapore  Singapore
# 3    Singapore  Singapore
# 4    Singapore  Singapore
# ..         ...        ...
# 867  Singapore  Singapore
# 868  Singapore  Singapore
# 869  Singapore  Singapore
# 870  Singapore  Singapore
# 871  Singapore  Singapore
#
# [872 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872 entries, 0 to 871
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  837 non-null    object
#  1   Attraction Type  870 non-null    object
#  2   City             872 non-null    object
#  3   Country          872 non-null    object
# dtypes: object(4)
# memory usage: 27.4+ KB

# %%
# Store the clean dataset
df.to_csv('Singaporeclean.csv')
