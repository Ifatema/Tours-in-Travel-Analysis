# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Berlin.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'FmrIP href', 'dugSS src', 'bUshh', 'cIVmB', 'iPqaD href 2',
#        'WlYyy 2', 'WlYyy 3', 'TCGml', 'WlYyy 4', 'iPqaD href 3', 'dugSS src 2',
#        'WlYyy 5', 'iPqaD', 'iPqaD href 5', 'WlYyy 6', 'dkvhj', 'WlYyy 7'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  3,000+ places sorted by traveler favorites
# 1                                      35,153
# 2                                      17,894
# 3                                      20,536
# 4                                       8,941
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                          bUshh  cIVmB  \
# 0                          NaN    NaN
# 1           Reichstag Building    1.0
# 2  Memorial of the Berlin Wall    2.0
# 3               Pergamonmuseum    3.0
# 4                Museum Island    4.0
#
#                                         iPqaD href 2  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...
# 2  https://www.tripadvisor.com/Attraction_Review-...
# 3  https://www.tripadvisor.com/Attraction_Review-...
# 4  https://www.tripadvisor.com/Attraction_Review-...
#
#                                              WlYyy 2          WlYyy 3 TCGml  \
# 0                                                NaN              NaN   NaN
# 1  Points of Interest & Landmarks • Architectural...  Mitte (Borough)     •
# 2                                     Historic Sites  Mitte (Borough)     •
# 3                                        Art Museums  Mitte (Borough)     •
# 4  Speciality Museums • Points of Interest & Land...  Mitte (Borough)     •
#
#               WlYyy 4                                       iPqaD href 3  \
# 0                 NaN                                                NaN
# 1            Open now  https://www.tripadvisor.com/Profile/martinvG91...
# 2            Open now  https://www.tripadvisor.com/Profile/Globetrott...
# 3  Temporarily closed           https://www.tripadvisor.com/Profile/KDF4
# 4            Open now           https://www.tripadvisor.com/Profile/KTGP
#
#                                          dugSS src 2 WlYyy 5            iPqaD  \
# 0                                                NaN     NaN              NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...      By   martinvG9146KA
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...      By  GlobetrotterTwo
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...      By             KDF4
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...      By             KTGP
#
#                                         iPqaD href 5  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/ShowUserReviews-g1...
# 2  https://www.tripadvisor.com/ShowUserReviews-g1...
# 3  https://www.tripadvisor.com/ShowUserReviews-g1...
# 4  https://www.tripadvisor.com/ShowUserReviews-g1...
#
#                                              WlYyy 6            dkvhj  \
# 0                                                NaN              NaN
# 1  It is great to go up and enjoy the view of Ber...  book in advance
# 2  Large piece of wall kept intact vividly showin...      Berlin Wall
# 3  ... of our trip and I highly recommend also vi...   Pergamon Altar
# 4  Museum Island is made up of five museums, Alte...     Neues Museum
#
#                                              WlYyy 7
# 0                                                NaN
# 1                                            to s...
# 2  divided communities and memorial to those who ...
# 3                                                  .
# 4                                   and the Perga...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         248 non-null    object
#  1   FmrIP href    238 non-null    object
#  2   dugSS src     238 non-null    object
#  3   bUshh         238 non-null    object
#  4   cIVmB         238 non-null    float64
#  5   iPqaD href 2  238 non-null    object
#  6   WlYyy 2       246 non-null    object
#  7   WlYyy 3       244 non-null    object
#  8   TCGml         115 non-null    object
#  9   WlYyy 4       122 non-null    object
#  10  iPqaD href 3  114 non-null    object
#  11  dugSS src 2   114 non-null    object
#  12  WlYyy 5       114 non-null    object
#  13  iPqaD         114 non-null    object
#  14  iPqaD href 5  114 non-null    object
#  15  WlYyy 6       113 non-null    object
#  16  dkvhj         114 non-null    object
#  17  WlYyy 7       109 non-null    object
# dtypes: float64(1), object(17)
# memory usage: 35.0+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'FmrIP href', 'dugSS src', 'cIVmB', 'iPqaD href 2','WlYyy 3', 'TCGml', 'WlYyy 4', 'iPqaD href 3', 'dugSS src 2','WlYyy 5', 'iPqaD', 'iPqaD href 5', 'WlYyy 6', 'dkvhj', 'WlYyy 7'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'bUshh':'Attraction Name', 'WlYyy 2':'Attraction Type'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Berlin'
df['Country'] = 'Germany'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 35

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                          Attraction Name  \
# 0                                    NaN
# 1                     Reichstag Building
# 2            Memorial of the Berlin Wall
# 3                         Pergamonmuseum
# 4                          Museum Island
# ..                                   ...
# 242                        Domäne Dahlem
# 243  Book Burning Memorial at Bebelplatz
# 244                            Alt Tegel
# 245              Mercedes - Benz Gallery
# 246                     Monbijou Theater
#
#                                        Attraction Type    City  Country
# 0                                                  NaN  Berlin  Germany
# 1    Points of Interest & Landmarks • Architectural...  Berlin  Germany
# 2                                       Historic Sites  Berlin  Germany
# 3                                          Art Museums  Berlin  Germany
# 4    Speciality Museums • Points of Interest & Land...  Berlin  Germany
# ..                                                 ...     ...      ...
# 242                                 Speciality Museums  Berlin  Germany
# 243    Historic Sites • Points of Interest & Landmarks  Berlin  Germany
# 244                                      Neighborhoods  Berlin  Germany
# 245                                 Speciality Museums  Berlin  Germany
# 246                                           Theaters  Berlin  Germany
#
# [213 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['Attraction Name', 'Attraction Type', 'City', 'Country'], dtype='object')

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Attraction Name    10
# Attraction Type     2
# City                0
# Country             0
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                          Attraction Name  \
# 0                                    NaN
# 1                     Reichstag Building
# 2            Memorial of the Berlin Wall
# 3                         Pergamonmuseum
# 4                          Museum Island
# ..                                   ...
# 243  Book Burning Memorial at Bebelplatz
# 244                            Alt Tegel
# 245              Mercedes - Benz Gallery
# 246                     Monbijou Theater
# 247                                  NaN
#
#                                        Attraction Type    City  Country
# 0                                                  NaN  Berlin  Germany
# 1    Points of Interest & Landmarks • Architectural...  Berlin  Germany
# 2                                       Historic Sites  Berlin  Germany
# 3                                          Art Museums  Berlin  Germany
# 4    Speciality Museums • Points of Interest & Land...  Berlin  Germany
# ..                                                 ...     ...      ...
# 243    Historic Sites • Points of Interest & Landmarks  Berlin  Germany
# 244                                      Neighborhoods  Berlin  Germany
# 245                                 Speciality Museums  Berlin  Germany
# 246                                           Theaters  Berlin  Germany
# 247                                                  1  Berlin  Germany
#
# [248 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Attraction Name  238 non-null    object
#  1   Attraction Type  246 non-null    object
#  2   City             248 non-null    object
#  3   Country          248 non-null    object
# dtypes: object(4)
# memory usage: 7.9+ KB

# %%
# Store the clean dataset
df.to_csv('Berlinclean.csv')
