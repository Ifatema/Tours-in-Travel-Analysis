# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('LV.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 6', 'ccVGl 2',
#        'WlYyy 7', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                      WlYyy  \
# 0  862 places sorted by traveler favorites
# 1                                      264
# 2                                      133
# 3                                      173
# 4                                      113
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                             iPqaD  \
# 0               Clear all filters
# 1           By Coexist West Coast
# 2  By Secret Food Tours Las Vegas
# 3                  By High Roller
# 4  By Mystère by Cirque du Soleil
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=b...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1  Lower or X Antelope Canyon & Horseshoe Bend Sm...   31.0
# 2  Secret Food Tours Las Vegas w/ Private Tour Op...   32.0
# 3          Happy Hour on The High Roller at The LINQ   33.0
# 4  Mystère by Cirque du Soleil at Treasure Island...   34.0
#
#                                         iPqaD href 2               WlYyy 2  \
# 0                                                NaN                   NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...             Bus Tours
# 2  https://www.tripadvisor.com/Attraction_Review-...         Walking Tours
# 3  https://www.tripadvisor.com/Attraction_Review-...  Skyscrapers & Towers
# 4  https://www.tripadvisor.com/Attraction_Review-...      Cirque du Soleil
#
#       WlYyy 3                                              ySnDE  \
# 0         NaN                                                NaN
# 1    6+ hours  Choose between Lower Antelope Canyon or Antelo...
# 2     3 hours  Las Vegas is known for its rich culinary lands...
# 3  30 minutes  Lift your spirits on the High Roller, the worl...
# 4   1–2 hours  ** LIMITED OFFER - Receive up to 40% off selec...
#
#              WlYyy 4                                     WlYyy 5  \
# 0                NaN                                         NaN
# 1  Free cancellation  95% of travelers recommend this experience
# 2                NaN  97% of travelers recommend this experience
# 3                NaN                                         NaN
# 4                NaN                                         NaN
#
#                                              cctrW 2 ccVGl  WlYyy 6  \
# 0                                                NaN   NaN      NaN
# 1  This number is based on the percentage of all ...  from  $299.99
# 2  This number is based on the percentage of all ...  from  $138.03
# 3                                                NaN  from   $65.25
# 4                                                NaN  from   $74.99
#
#      ccVGl 2    WlYyy 7                   dXxty
# 0        NaN        NaN                     NaN
# 1  per adult  More info                     NaN
# 2  per adult  More info  Taking safety measures
# 3  per adult  More info  Taking safety measures
# 4  per adult  More info  Taking safety measures

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         383 non-null    object
#  1   cctrW         313 non-null    object
#  2   iPqaD         407 non-null    object
#  3   iPqaD href    369 non-null    object
#  4   FmrIP href    396 non-null    object
#  5   dugSS src     396 non-null    object
#  6   bUshh         396 non-null    object
#  7   cIVmB         396 non-null    float64
#  8   iPqaD href 2  394 non-null    object
#  9   WlYyy 2       346 non-null    object
#  10  WlYyy 3       410 non-null    object
#  11  ySnDE         394 non-null    object
#  12  WlYyy 4       315 non-null    object
#  13  WlYyy 5       173 non-null    object
#  14  cctrW 2       171 non-null    object
#  15  ccVGl         396 non-null    object
#  16  WlYyy 6       396 non-null    object
#  17  ccVGl 2       396 non-null    object
#  18  WlYyy 7       396 non-null    object
#  19  dXxty         210 non-null    object
# dtypes: float64(1), object(19)
# memory usage: 66.2+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'dugSS src', 'cIVmB', 'ySnDE', 'WlYyy 5', 'cctrW 2', 'ccVGl','WlYyy 7', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Las Vegas'
df['Country'] = 'USA'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 18

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                      Tour By  \
# 0                          Clear all filters
# 1                      By Coexist West Coast
# 2             By Secret Food Tours Las Vegas
# 3                             By High Roller
# 4             By Mystère by Cirque du Soleil
# ..                                       ...
# 412     By Atomic Scooters Rentals and Tours
# 413                    By Rockstar Las Vegas
# 414  By Mears Las Vegas Chauffeured Services
# 415                                      NaN
# 422                                      NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    Lower or X Antelope Canyon & Horseshoe Bend Sm...
# 2    Secret Food Tours Las Vegas w/ Private Tour Op...
# 3            Happy Hour on The High Roller at The LINQ
# 4    Mystère by Cirque du Soleil at Treasure Island...
# ..                                                 ...
# 412       Rent Electric Scooters in Downtown Las Vegas
# 413                  Epic Pool Party Tour by Party Bus
# 414      Private Departure Transfer: Las Vegas Airport
# 415                                                NaN
# 422                                                NaN
#
#                                                   Link             Tour Type  \
# 0                                                  NaN                   NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...             Bus Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...         Walking Tours
# 3    https://www.tripadvisor.com/Attraction_Review-...  Skyscrapers & Towers
# 4    https://www.tripadvisor.com/Attraction_Review-...      Cirque du Soleil
# ..                                                 ...                   ...
# 412  https://www.tripadvisor.com/Attraction_Review-...               Rentals
# 413  https://www.tripadvisor.com/Attraction_Review-...    Private and Luxury
# 414  https://www.tripadvisor.com/Attraction_Review-...                   NaN
# 415                                                NaN                    14
# 422                                                NaN                    15
#
#     Tour Duration       Cancellation Tour Price  Price Per       City Country
# 0             NaN                NaN        NaN        NaN  Las Vegas     USA
# 1        6+ hours  Free cancellation    $299.99  per adult  Las Vegas     USA
# 2         3 hours                NaN    $138.03  per adult  Las Vegas     USA
# 3      30 minutes                NaN     $65.25  per adult  Las Vegas     USA
# 4       1–2 hours                NaN     $74.99  per adult  Las Vegas     USA
# ..            ...                ...        ...        ...        ...     ...
# 412    4–10 hours                NaN     $25.00  per adult  Las Vegas     USA
# 413       5 hours                NaN     $59.00  per adult  Las Vegas     USA
# 414    20 minutes  Free cancellation     $97.90  per group  Las Vegas     USA
# 415            13                 15        NaN        NaN  Las Vegas     USA
# 422            14                 16        NaN        NaN  Las Vegas     USA
#
# [405 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Tour Name         27
# Tour Type         77
# Tour Duration     13
# Tour Price        27
# Price Per         27
# Cancellation     108
# Tour By           16
# City               0
# Country            0
# Link              29
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                              Tour Name             Tour Type  \
# 0                                                  NaN                   NaN
# 1    Lower or X Antelope Canyon & Horseshoe Bend Sm...             Bus Tours
# 2    Secret Food Tours Las Vegas w/ Private Tour Op...         Walking Tours
# 3            Happy Hour on The High Roller at The LINQ  Skyscrapers & Towers
# 4    Mystère by Cirque du Soleil at Treasure Island...      Cirque du Soleil
# ..                                                 ...                   ...
# 418  Grand Canyon, Monument Valley and Zion Nationa...             Bus Tours
# 419                          Polaris Slingshot Rentals               Rentals
# 420                      Bachelorette Party Club Crawl             Bus Tours
# 421         1 Day Tour at Valley of Fire and Zion Park        Full-day Tours
# 422                                                NaN                    15
#
#     Tour Duration Tour Price  Price Per       Cancellation  \
# 0             NaN        NaN        NaN                NaN
# 1        6+ hours    $299.99  per adult  Free cancellation
# 2         3 hours    $138.03  per adult                NaN
# 3      30 minutes     $65.25  per adult                NaN
# 4       1–2 hours     $74.99  per adult                NaN
# ..            ...        ...        ...                ...
# 418        3 days    $675.00  per adult  Free cancellation
# 419    4–24 hours    $249.00  per group  Free cancellation
# 420     5–6 hours     $30.13  per adult  Free cancellation
# 421   11–12 hours    $189.00  per adult  Free cancellation
# 422            14        NaN        NaN                 16
#
#                             Tour By       City Country  \
# 0                 Clear all filters  Las Vegas     USA
# 1             By Coexist West Coast  Las Vegas     USA
# 2    By Secret Food Tours Las Vegas  Las Vegas     USA
# 3                    By High Roller  Las Vegas     USA
# 4    By Mystère by Cirque du Soleil  Las Vegas     USA
# ..                              ...        ...     ...
# 418            By Bindlestiff Tours  Las Vegas     USA
# 419                 By SinCity Moto  Las Vegas     USA
# 420                By Club Crawl Co  Las Vegas     USA
# 421   By Empire Vacations Day Tours  Las Vegas     USA
# 422                             NaN  Las Vegas     USA
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3    https://www.tripadvisor.com/Attraction_Review-...
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 418  https://www.tripadvisor.com/Attraction_Review-...
# 419  https://www.tripadvisor.com/Attraction_Review-...
# 420  https://www.tripadvisor.com/Attraction_Review-...
# 421  https://www.tripadvisor.com/Attraction_Review-...
# 422                                                NaN
#
# [423 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tour Name      396 non-null    object
#  1   Tour Type      346 non-null    object
#  2   Tour Duration  410 non-null    object
#  3   Tour Price     396 non-null    object
#  4   Price Per      396 non-null    object
#  5   Cancellation   315 non-null    object
#  6   Tour By        407 non-null    object
#  7   City           423 non-null    object
#  8   Country        423 non-null    object
#  9   Link           394 non-null    object
# dtypes: object(10)
# memory usage: 33.2+ KB

# %% [markdown]
# **For the Cleaning:**
# - by: REMOVE Clear all filters
# - type: REMOVE
# - duration: REMOVE
# - canel: REMOVE other
# - price:$ --> float

# %%
# Store the clean dataset
df.to_csv('LVclean.csv')
