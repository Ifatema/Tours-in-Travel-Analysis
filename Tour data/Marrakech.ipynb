# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Marrakech.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 6', 'ccVGl 2',
#        'WlYyy 7', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                                WlYyy  \
# 0         4,000+ places sorted by traveler favorites
# 1                                              3,604
# 2                                                283
# 3  Book risk-free with free cancellations on most...
# 4                                                374
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3                                                NaN
# 4  Not sure? You can cancel this reservation up t...
#
#                            iPqaD  \
# 0              Clear all filters
# 1     By Amzil Marrakech Tickets
# 2         By Marrakech City Life
# 3                            NaN
# 4  By Marrakech Dream Ballooning
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=Y...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3                                                NaN
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3                                                NaN
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                NaN
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1  Atlas Mountains and Three Valleys & Waterfalls...    1.0
# 2  Marrakech to Fez via Merzouga Desert 3-Days Mo...    2.0
# 3                                                NaN    NaN
# 4  Hot Air Balloon Flight over Marrakech with Tra...    3.0
#
#                                         iPqaD href 2             WlYyy 2  \
# 0                                                NaN                 NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...  Private and Luxury
# 2  https://www.tripadvisor.com/Attraction_Review-...     Adventure Tours
# 3                                                NaN          Cold feet?
# 4  https://www.tripadvisor.com/Attraction_Review-...     Adventure Tours
#
#      WlYyy 3                                              ySnDE  \
# 0        NaN                                                NaN
# 1   6+ hours  This day-long excursion from Marrakech provide...
# 2     3 days  Marrakech and Fes are the major cities everyon...
# 3        NaN                                                NaN
# 4  4–5 hours  “Join us for a lifetime experience in Marrakec...
#
#              WlYyy 4                                     WlYyy 5  \
# 0                NaN                                         NaN
# 1  Free cancellation  97% of travelers recommend this experience
# 2  Free cancellation  97% of travelers recommend this experience
# 3                NaN                                         NaN
# 4  Free cancellation  99% of travelers recommend this experience
#
#                                              cctrW 2 ccVGl  WlYyy 6  \
# 0                                                NaN   NaN      NaN
# 1  This number is based on the percentage of all ...  from   $36.20
# 2  This number is based on the percentage of all ...  from  $203.65
# 3                                                NaN   NaN      NaN
# 4  This number is based on the percentage of all ...  from  $201.38
#
#      ccVGl 2    WlYyy 7 dXxty
# 0        NaN        NaN   NaN
# 1  per adult  More info   NaN
# 2  per adult  More info   NaN
# 3        NaN        NaN   NaN
# 4  per adult  More info   NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         726 non-null    object
#  1   cctrW         730 non-null    object
#  2   iPqaD         739 non-null    object
#  3   iPqaD href    698 non-null    object
#  4   FmrIP href    725 non-null    object
#  5   dugSS src     725 non-null    object
#  6   bUshh         725 non-null    object
#  7   cIVmB         725 non-null    float64
#  8   iPqaD href 2  715 non-null    object
#  9   WlYyy 2       619 non-null    object
#  10  WlYyy 3       750 non-null    object
#  11  ySnDE         710 non-null    object
#  12  WlYyy 4       731 non-null    object
#  13  WlYyy 5       369 non-null    object
#  14  cctrW 2       368 non-null    object
#  15  ccVGl         725 non-null    object
#  16  WlYyy 6       726 non-null    object
#  17  ccVGl 2       725 non-null    object
#  18  WlYyy 7       726 non-null    object
#  19  dXxty         236 non-null    object
# dtypes: float64(1), object(19)
# memory usage: 121.5+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'dugSS src', 'cIVmB', 'ySnDE','WlYyy 5', 'cctrW 2', 'ccVGl','WlYyy 7', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Marrakech'
df['Country'] = 'Morocco'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 28

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                            Tour By  \
# 0                Clear all filters
# 1       By Amzil Marrakech Tickets
# 2           By Marrakech City Life
# 3                              NaN
# 4    By Marrakech Dream Ballooning
# ..                             ...
# 772          By Said Morocco Tours
# 773               By Tilila Travel
# 774     By Atlas Mountain Trekking
# 775          By CharlieTheTraveler
# 776                            NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    Atlas Mountains and Three Valleys & Waterfalls...
# 2    Marrakech to Fez via Merzouga Desert 3-Days Mo...
# 3                                                  NaN
# 4    Hot Air Balloon Flight over Marrakech with Tra...
# ..                                                 ...
# 772  Agafay Marrakech desert tour with romantic din...
# 773         9-Day Private Morocco Tour From Casablanca
# 774  Atlas Mountains And Toubkal Massif & Waterfall...
# 775  Morocco: See & Do it ALL in 12 Days, 1st Class...
# 776                                                NaN
#
#                                                   Link           Tour Type  \
# 0                                                  NaN                 NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...  Private and Luxury
# 2    https://www.tripadvisor.com/Attraction_Review-...     Adventure Tours
# 3                                                  NaN          Cold feet?
# 4    https://www.tripadvisor.com/Attraction_Review-...     Adventure Tours
# ..                                                 ...                 ...
# 772  https://www.tripadvisor.com/Attraction_Review-...           Bus Tours
# 773  https://www.tripadvisor.com/Attraction_Review-...           Bus Tours
# 774  https://www.tripadvisor.com/Attraction_Review-...           Bus Tours
# 775  https://www.tripadvisor.com/Attraction_Review-...           Bus Tours
# 776                                                NaN                   1
#
#     Tour Duration       Cancellation Tour Price  Price Per       City  Country
# 0             NaN                NaN        NaN        NaN  Marrakech  Morocco
# 1        6+ hours  Free cancellation     $36.20  per adult  Marrakech  Morocco
# 2          3 days  Free cancellation    $203.65  per adult  Marrakech  Morocco
# 3             NaN                NaN        NaN        NaN  Marrakech  Morocco
# 4       4–5 hours  Free cancellation    $201.38  per adult  Marrakech  Morocco
# ..            ...                ...        ...        ...        ...      ...
# 772       6 hours  Free cancellation    $107.48  per adult  Marrakech  Morocco
# 773       3+ days  Free cancellation  $1,583.91  per adult  Marrakech  Morocco
# 774      6+ hours  Free cancellation     $67.88  per adult  Marrakech  Morocco
# 775       3+ days  Free cancellation  $2,156.54  per adult  Marrakech  Morocco
# 776            25                 27        NaN        NaN  Marrakech  Morocco
#
# [749 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Tour Name         52
# Tour Type        158
# Tour Duration     27
# Tour Price        51
# Price Per         52
# Cancellation      46
# Tour By           38
# City               0
# Country            0
# Link              62
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                              Tour Name           Tour Type  \
# 0                                                  NaN                 NaN
# 1    Atlas Mountains and Three Valleys & Waterfalls...  Private and Luxury
# 2    Marrakech to Fez via Merzouga Desert 3-Days Mo...     Adventure Tours
# 3                                                  NaN          Cold feet?
# 4    Hot Air Balloon Flight over Marrakech with Tra...     Adventure Tours
# ..                                                 ...                 ...
# 772  Agafay Marrakech desert tour with romantic din...           Bus Tours
# 773         9-Day Private Morocco Tour From Casablanca           Bus Tours
# 774  Atlas Mountains And Toubkal Massif & Waterfall...           Bus Tours
# 775  Morocco: See & Do it ALL in 12 Days, 1st Class...           Bus Tours
# 776                                                NaN                   1
#
#     Tour Duration Tour Price  Price Per       Cancellation  \
# 0             NaN        NaN        NaN                NaN
# 1        6+ hours     $36.20  per adult  Free cancellation
# 2          3 days    $203.65  per adult  Free cancellation
# 3             NaN        NaN        NaN                NaN
# 4       4–5 hours    $201.38  per adult  Free cancellation
# ..            ...        ...        ...                ...
# 772       6 hours    $107.48  per adult  Free cancellation
# 773       3+ days  $1,583.91  per adult  Free cancellation
# 774      6+ hours     $67.88  per adult  Free cancellation
# 775       3+ days  $2,156.54  per adult  Free cancellation
# 776            25        NaN        NaN                 27
#
#                            Tour By       City  Country  \
# 0                Clear all filters  Marrakech  Morocco
# 1       By Amzil Marrakech Tickets  Marrakech  Morocco
# 2           By Marrakech City Life  Marrakech  Morocco
# 3                              NaN  Marrakech  Morocco
# 4    By Marrakech Dream Ballooning  Marrakech  Morocco
# ..                             ...        ...      ...
# 772          By Said Morocco Tours  Marrakech  Morocco
# 773               By Tilila Travel  Marrakech  Morocco
# 774     By Atlas Mountain Trekking  Marrakech  Morocco
# 775          By CharlieTheTraveler  Marrakech  Morocco
# 776                            NaN  Marrakech  Morocco
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3                                                  NaN
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 772  https://www.tripadvisor.com/Attraction_Review-...
# 773  https://www.tripadvisor.com/Attraction_Review-...
# 774  https://www.tripadvisor.com/Attraction_Review-...
# 775  https://www.tripadvisor.com/Attraction_Review-...
# 776                                                NaN
#
# [777 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tour Name      725 non-null    object
#  1   Tour Type      619 non-null    object
#  2   Tour Duration  750 non-null    object
#  3   Tour Price     726 non-null    object
#  4   Price Per      725 non-null    object
#  5   Cancellation   731 non-null    object
#  6   Tour By        739 non-null    object
#  7   City           777 non-null    object
#  8   Country        777 non-null    object
#  9   Link           715 non-null    object
# dtypes: object(10)
# memory usage: 60.8+ KB

# %% [markdown]
# **For the Cleaning:**
# - by: REMOVE Clear all filters
# - type: REMOVE Q? & num
# - duration: REMOVE num &+
# - canel: REMOVE other
# - price:$ --> float

# %%
# Store the clean dataset
df.to_csv('Marrakechclean.csv')
