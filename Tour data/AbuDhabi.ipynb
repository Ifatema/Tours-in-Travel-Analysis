# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('AbuDhabi.csv')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                                WlYyy  \
# 0            742 places sorted by traveler favorites
# 1                                                375
# 2                                              1,318
# 3  Book risk-free with free cancellations on most...
# 4                                              1,227
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3                                                NaN
# 4  Not sure? You can cancel this reservation up t...
#
#                            iPqaD  \
# 0              Clear all filters
# 1                 By RAH Tourism
# 2  By Emirates Tours and Safaris
# 3                            NaN
# 4            By OceanAir Travels
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=R...
# ...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627 entries, 0 to 626
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         371 non-null    object
#  1   cctrW         577 non-null    object
#  2   iPqaD         591 non-null    object
#  3   iPqaD href    344 non-null    object
#  4   FmrIP href    581 non-null    object
#  5   dugSS src     579 non-null    object
#  6   bUshh         581 non-null    object
#  7   cIVmB         581 non-null    float64
#  8   iPqaD href 2  572 non-null    object
#  9   WlYyy 2       540 non-null    object
#  10  WlYyy 3       606 non-null    object
#  11  ySnDE         574 non-null    object
#  12  dXxty         348 non-null    object
#  13  WlYyy 4       581 non-null    object
#  14  ccVGl         581 non-null    object
#  15  WlYyy 5       582 non-null    object
#  16  ccVGl 2       581 non-null    object
#  17  WlYyy 6       582 non-null    object
# ...

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW', 'iPqaD href', 'FmrIP href',  'ySnDE', 'dXxty', 'ccVGl', 'WlYyy 6'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 5':'Tour Price', 'ccVGl 2':'Price Per', 'dugSS src':'Image'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Abu Dhabi'
df['Country'] = 'United Arab Emirates'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 29

# %%
# drop the duplicated rows
df.drop_duplicates(subset=['Tour Name'])
# Out:
#                                              Tour By  \
# 0                                  Clear all filters
# 1                                     By RAH Tourism
# 2                      By Emirates Tours and Safaris
# 4                                By OceanAir Travels
# 5                                     By RAH Tourism
# ..                                               ...
# 620  By PROFi DRIVER Abu Dhabi, United Arab Emirates
# 621                             By MY TRANSFER GROUP
# 622                                 By Hosam Mohamed
# 623                           By Let's Explore Dubai
# 624                           By Let's Explore Dubai
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ...

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'cIVmB', 'Link', 'Tour Type',
#        'Tour Duration', 'Cancellation', 'Tour Price', 'Price Per', 'City',
#        'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image', 'Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image            48
# Tour Name        46
# Tour Type        87
# Tour Duration    21
# Tour Price       45
# Price Per        46
# Cancellation     46
# Tour By          36
# City              0
# Country           0
# Link             55
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 622  https://dynamic-media-cdn.tripadvisor.com/medi...
# 623  https://dynamic-media-cdn.tripadvisor.com/medi...
# 624  https://dynamic-media-cdn.tripadvisor.com/medi...
# 625                                                NaN
# 626                                                NaN
#
#                                              Tour Name         Tour Type  \
# 0                                                  NaN               NaN
# 1       Abu Dhabi Full-Day Sightseeing Tour from Dubai         Bus Tours
# 2    Evening Desert Safari With BBQ Dinner, Camel R...  Shore Excursions
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627 entries, 0 to 626
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          579 non-null    object
#  1   Tour Name      581 non-null    object
#  2   Tour Type      540 non-null    object
#  3   Tour Duration  606 non-null    object
#  4   Tour Price     582 non-null    object
#  5   Price Per      581 non-null    object
#  6   Cancellation   581 non-null    object
#  7   Tour By        591 non-null    object
#  8   City           627 non-null    object
#  9   Country        627 non-null    object
#  10  Link           572 non-null    object
# dtypes: object(11)
# memory usage: 54.0+ KB

# %%
# Store the clean dataset
df.to_csv('AbuDhabiclean.csv')
