# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('LA.csv')

# %%
messy_df.columns
# Out:
# Index(['cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src', 'bUshh',
#        'cIVmB', 'WlYyy 3', 'iPqaD href 2', 'WlYyy 4', 'WlYyy 5', 'ySnDE',
#        'WlYyy 6', 'WlYyy 7', 'cctrW 2', 'ccVGl', 'WlYyy 8', 'ccVGl 2',
#        'WlYyy 9', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3  Not sure? You can cancel this reservation up t...
# 4  Not sure? You can cancel this reservation up t...
#
#                                    iPqaD  \
# 0                      Clear all filters
# 1                   By A Day in LA Tours
# 2                By Hollywood City Tours
# 3  By Warner Bros. Studio Tour Hollywood
# 4                    By Golden Ticket LA
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=W...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# ...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cctrW         119 non-null    object
#  1   iPqaD         130 non-null    object
#  2   iPqaD href    116 non-null    object
#  3   FmrIP href    126 non-null    object
#  4   dugSS src     126 non-null    object
#  5   bUshh         126 non-null    object
#  6   cIVmB         126 non-null    float64
#  7   WlYyy 3       117 non-null    object
#  8   iPqaD href 2  126 non-null    object
#  9   WlYyy 4       124 non-null    object
#  10  WlYyy 5       127 non-null    object
#  11  ySnDE         126 non-null    object
#  12  WlYyy 6       116 non-null    object
#  13  WlYyy 7       61 non-null     object
#  14  cctrW 2       60 non-null     object
#  15  ccVGl         126 non-null    object
#  16  WlYyy 8       127 non-null    object
#  17  ccVGl 2       126 non-null    object
# ...

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop( ['cctrW','iPqaD href', 'FmrIP href',  'cIVmB', 'WlYyy 3','ySnDE', 'ccVGl','WlYyy 7', 'cctrW 2', 'ccVGl','WlYyy 9', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 4':'Tour Type', 'WlYyy 5':'Tour Duration', 'WlYyy 6':'Cancellation', 'WlYyy 8':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Los Angeles'
df['Country'] = 'USA'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 10

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                    Tour By  \
# 0                        Clear all filters
# 1                     By A Day in LA Tours
# 2                  By Hollywood City Tours
# 3    By Warner Bros. Studio Tour Hollywood
# 4                      By Golden Ticket LA
# ..                                     ...
# 125                     By ExperienceFirst
# 126                  By I Ride Like a Star
# 127                    By LA Walking Tours
# 128                                    NaN
# 135                                    NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# ...

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image            10
# Tour Name        10
# Tour Type        12
# Tour Duration     9
# Tour Price        9
# Price Per        10
# Cancellation     20
# Tour By           6
# City              0
# Country           0
# Link             10
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 131  https://dynamic-media-cdn.tripadvisor.com/medi...
# 132  https://dynamic-media-cdn.tripadvisor.com/medi...
# 133  https://dynamic-media-cdn.tripadvisor.com/medi...
# 134  https://dynamic-media-cdn.tripadvisor.com/medi...
# 135                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    Full-Day Iconic Sights of LA, Hollywood, Bever...
# 2               Hollywood and Celebrity Homes Bus Tour
# 3                   Warner Bros. Studio Tour Hollywood
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136 entries, 0 to 135
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          126 non-null    object
#  1   Tour Name      126 non-null    object
#  2   Tour Type      124 non-null    object
#  3   Tour Duration  127 non-null    object
#  4   Tour Price     127 non-null    object
#  5   Price Per      126 non-null    object
#  6   Cancellation   116 non-null    object
#  7   Tour By        130 non-null    object
#  8   City           136 non-null    object
#  9   Country        136 non-null    object
#  10  Link           126 non-null    object
# dtypes: object(11)
# memory usage: 11.8+ KB

# %%
# Store the clean dataset
df.to_csv('LAclean.csv')
