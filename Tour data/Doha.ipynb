# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Doha.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 6', 'ccVGl 2',
#        'WlYyy 7', 'dXxty'],
#       dtype='object')

# %% [markdown]
# - by: re Clear all filters
# - type: re Which experiences are best for tours in Doha? & Cold feet?  & num
# - dur: re What are the best places for tours in Doha? & num . values + & D H M
# - canc: re Which places provide the best tours in Doha for kids and families?  & num
# - price: $ --> float

# %%
messy_df['ccVGl 2'].value_counts()
# Out:
# per adult    116
# per group      8
# Name: ccVGl 2, dtype: int64

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                                WlYyy  \
# 0            162 places sorted by traveler favorites
# 1                                              1,253
# 2                                                 33
# 3  Book risk-free with free cancellations on most...
# 4                                                571
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3                                                NaN
# 4  Not sure? You can cancel this reservation up t...
#
#                         iPqaD  \
# 0           Clear all filters
# 1             By Falcon Tours
# 2  By Doha travel and tourism
# 3                         NaN
# 4             By Falcon Tours
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=O...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3                                                NaN
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3                                                NaN
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                NaN
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1  (Private) Half Day Desert Safari, Camel Ride, ...    1.0
# 2  Qatar : Private Half Day Desert Safari | Quad ...    2.0
# 3                                                NaN    NaN
# 4  (Private)Desert Safari Dune Bashing, Camel Rid...    3.0
#
#                                         iPqaD href 2           WlYyy 2  \
# 0                                                NaN               NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...  Shore Excursions
# 2  https://www.tripadvisor.com/Attraction_Review-...   Adventure Tours
# 3                                                NaN        Cold feet?
# 4  https://www.tripadvisor.com/Attraction_Review-...  Shore Excursions
#
#      WlYyy 3                                              ySnDE  \
# 0        NaN                                                NaN
# 1    4 hours  Most popular and number one desert safari tour...
# 2  4–5 hours  Most popular and number one desert safari tour...
# 3        NaN                                                NaN
# 4    4 hours  Enjoy the Most popular desert safari tour in Q...
#
#              WlYyy 4                                      WlYyy 5  \
# 0                NaN                                          NaN
# 1  Free cancellation   99% of travelers recommend this experience
# 2  Free cancellation  100% of travelers recommend this experience
# 3                NaN                                          NaN
# 4  Free cancellation   99% of travelers recommend this experience
#
#                                              cctrW 2 ccVGl  WlYyy 6  \
# 0                                                NaN   NaN      NaN
# 1  This number is based on the percentage of all ...  from  $102.00
# 2  This number is based on the percentage of all ...  from   $97.69
# 3                                                NaN   NaN      NaN
# 4  This number is based on the percentage of all ...  from   $99.00
#
#      ccVGl 2    WlYyy 7 dXxty
# 0        NaN        NaN   NaN
# 1  per adult  More info   NaN
# 2  per adult  More info   NaN
# 3        NaN        NaN   NaN
# 4  per adult  More info   NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         86 non-null     object
#  1   cctrW         124 non-null    object
#  2   iPqaD         127 non-null    object
#  3   iPqaD href    78 non-null     object
#  4   FmrIP href    124 non-null    object
#  5   dugSS src     124 non-null    object
#  6   bUshh         124 non-null    object
#  7   cIVmB         124 non-null    float64
#  8   iPqaD href 2  123 non-null    object
#  9   WlYyy 2       100 non-null    object
#  10  WlYyy 3       130 non-null    object
#  11  ySnDE         121 non-null    object
#  12  WlYyy 4       124 non-null    object
#  13  WlYyy 5       49 non-null     object
#  14  cctrW 2       41 non-null     object
#  15  ccVGl         124 non-null    object
#  16  WlYyy 6       125 non-null    object
#  17  ccVGl 2       124 non-null    object
#  18  WlYyy 7       125 non-null    object
#  19  dXxty         48 non-null     object
# dtypes: float64(1), object(19)
# memory usage: 21.5+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'cIVmB', 'ySnDE','WlYyy 5', 'cctrW 2','ccVGl','WlYyy 7', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Doha'
df['Country'] = 'Qatar'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 7

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                          Tour By  \
# 0              Clear all filters
# 1                By Falcon Tours
# 2     By Doha travel and tourism
# 3                            NaN
# 4                By Falcon Tours
# ..                           ...
# 128  By PROFi DRIVER Doha, Qatar
# 129  By PROFi DRIVER Doha, Qatar
# 130           By Qatar Day Tours
# 131                          NaN
# 136                          NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 128  https://dynamic-media-cdn.tripadvisor.com/medi...
# 129  https://dynamic-media-cdn.tripadvisor.com/medi...
# 130  https://dynamic-media-cdn.tripadvisor.com/medi...
# 131                                                NaN
# 136                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    (Private) Half Day Desert Safari, Camel Ride, ...
# 2    Qatar : Private Half Day Desert Safari | Quad ...
# 3                                                  NaN
# 4    (Private)Desert Safari Dune Bashing, Camel Rid...
# ..                                                 ...
# 128  Doha Airport Transfers : Doha Airport DOH to D...
# 129  Doha Airport Transfers : Doha City to Doha Air...
# 130                        Mall of Qatar shopping tour
# 131                                                NaN
# 136                                                NaN
#
#                                                   Link         Tour Type  \
# 0                                                  NaN               NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...  Shore Excursions
# 2    https://www.tripadvisor.com/Attraction_Review-...   Adventure Tours
# 3                                                  NaN        Cold feet?
# 4    https://www.tripadvisor.com/Attraction_Review-...  Shore Excursions
# ..                                                 ...               ...
# 128  https://www.tripadvisor.com/Attraction_Review-...               NaN
# 129  https://www.tripadvisor.com/Attraction_Review-...               NaN
# 130  https://www.tripadvisor.com/Attraction_Review-...         Bus Tours
# 131                                                NaN                 1
# 136                                                NaN                 1
#
#     Tour Duration       Cancellation Tour Price  Price Per  City Country
# 0             NaN                NaN        NaN        NaN  Doha   Qatar
# 1         4 hours  Free cancellation    $102.00  per adult  Doha   Qatar
# 2       4–5 hours  Free cancellation     $97.69  per adult  Doha   Qatar
# 3             NaN                NaN        NaN        NaN  Doha   Qatar
# 4         4 hours  Free cancellation     $99.00  per adult  Doha   Qatar
# ..            ...                ...        ...        ...   ...     ...
# 128    20 minutes  Free cancellation    $113.14  per adult  Doha   Qatar
# 129    20 minutes  Free cancellation    $113.14  per adult  Doha   Qatar
# 130       4 hours  Free cancellation    $127.00  per adult  Doha   Qatar
# 131             4                  6        NaN        NaN  Doha   Qatar
# 136             5                NaN        NaN        NaN  Doha   Qatar
#
# [130 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image            13
# Tour Name        13
# Tour Type        37
# Tour Duration     7
# Tour Price       12
# Price Per        13
# Cancellation     13
# Tour By          10
# City              0
# Country           0
# Link             14
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 132  https://dynamic-media-cdn.tripadvisor.com/medi...
# 133  https://dynamic-media-cdn.tripadvisor.com/medi...
# 134  https://dynamic-media-cdn.tripadvisor.com/medi...
# 135  https://dynamic-media-cdn.tripadvisor.com/medi...
# 136                                                NaN
#
#                                              Tour Name         Tour Type  \
# 0                                                  NaN               NaN
# 1    (Private) Half Day Desert Safari, Camel Ride, ...  Shore Excursions
# 2    Qatar : Private Half Day Desert Safari | Quad ...   Adventure Tours
# 3                                                  NaN        Cold feet?
# 4    (Private)Desert Safari Dune Bashing, Camel Rid...  Shore Excursions
# ..                                                 ...               ...
# 132                      The Best Of Doha Walking Tour     Walking Tours
# 133  Doha Airport Transfers : Doha City to Doha Air...               NaN
# 134  Doha By Yourself with English Chauffeur by Bus...         Bus Tours
# 135  Departure Private Transfers from Doha City to ...               NaN
# 136                                                NaN                 1
#
#     Tour Duration Tour Price  Price Per       Cancellation  \
# 0             NaN        NaN        NaN                NaN
# 1         4 hours    $102.00  per adult  Free cancellation
# 2       4–5 hours     $97.69  per adult  Free cancellation
# 3             NaN        NaN        NaN                NaN
# 4         4 hours     $99.00  per adult  Free cancellation
# ..            ...        ...        ...                ...
# 132       2 hours    $463.00  per group                NaN
# 133    20 minutes     $90.49  per adult  Free cancellation
# 134      6+ hours    $264.95  per adult  Free cancellation
# 135    20 minutes    $105.22  per adult  Free cancellation
# 136             5        NaN        NaN                NaN
#
#                            Tour By  City Country  \
# 0                Clear all filters  Doha   Qatar
# 1                  By Falcon Tours  Doha   Qatar
# 2       By Doha travel and tourism  Doha   Qatar
# 3                              NaN  Doha   Qatar
# 4                  By Falcon Tours  Doha   Qatar
# ..                             ...   ...     ...
# 132           By Fun Top Fun Qatar  Doha   Qatar
# 133    By PROFi DRIVER Doha, Qatar  Doha   Qatar
# 134  By EUROPE SHUTTLE Doha, Qatar  Doha   Qatar
# 135    By PROFi DRIVER Doha, Qatar  Doha   Qatar
# 136                            NaN  Doha   Qatar
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3                                                  NaN
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 132  https://www.tripadvisor.com/Attraction_Review-...
# 133  https://www.tripadvisor.com/Attraction_Review-...
# 134  https://www.tripadvisor.com/Attraction_Review-...
# 135  https://www.tripadvisor.com/Attraction_Review-...
# 136                                                NaN
#
# [137 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          124 non-null    object
#  1   Tour Name      124 non-null    object
#  2   Tour Type      100 non-null    object
#  3   Tour Duration  130 non-null    object
#  4   Tour Price     125 non-null    object
#  5   Price Per      124 non-null    object
#  6   Cancellation   124 non-null    object
#  7   Tour By        127 non-null    object
#  8   City           137 non-null    object
#  9   Country        137 non-null    object
#  10  Link           123 non-null    object
# dtypes: object(11)
# memory usage: 11.9+ KB

# %%
# Store the clean dataset
df.to_csv('Dohaclean.csv')
