# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Singapore.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'dXxty', 'ccVGl', 'WlYyy 4', 'ccVGl 2', 'WlYyy 5', 'WlYyy 6', 'WlYyy 7',
#        'cctrW 2'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                      WlYyy  \
# 0  617 places sorted by traveler favorites
# 1                                        4
# 2                                      199
# 3                                      285
# 4                                      734
#
#                                                cctrW                   iPqaD  \
# 0  Tours, activities and experiences bookable on ...       Clear all filters
# 1                                                NaN      By Hello Singapore
# 2  This number is based on the percentage of all ...  By The Royal Albatross
# 3  This number is based on the percentage of all ...      By Food Playground
# 4  This number is based on the percentage of all ...     By Bike Around Tour
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=U...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# ...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         147 non-null    object
#  1   cctrW         49 non-null     object
#  2   iPqaD         191 non-null    object
#  3   iPqaD href    138 non-null    object
#  4   FmrIP href    185 non-null    object
#  5   dugSS src     185 non-null    object
#  6   bUshh         185 non-null    object
#  7   cIVmB         185 non-null    float64
#  8   iPqaD href 2  185 non-null    object
#  9   WlYyy 2       160 non-null    object
#  10  WlYyy 3       193 non-null    object
#  11  ySnDE         184 non-null    object
#  12  dXxty         92 non-null     object
#  13  ccVGl         185 non-null    object
#  14  WlYyy 4       192 non-null    object
#  15  ccVGl 2       185 non-null    object
#  16  WlYyy 5       186 non-null    object
#  17  WlYyy 6       44 non-null     object
# ...

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href',  'cIVmB',  'ySnDE', 'dXxty', 'ccVGl','WlYyy 5', 'WlYyy 6','cctrW 2'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 7':'Cancellation', 'WlYyy 4':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Singapore'
df['Country'] = 'Singapore'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 10

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                             Tour By  \
# 0                 Clear all filters
# 1                By Hello Singapore
# 2            By The Royal Albatross
# 3                By Food Playground
# 4               By Bike Around Tour
# ..                              ...
# 195              By The Bicycle Hut
# 196            By My Phuket Holiday
# 197  By Zenith Wholesale Enterprise
# 198    By Resource Travel Pte. Ltd.
# 199                             NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 195  https://dynamic-media-cdn.tripadvisor.com/medi...
# 196  https://dynamic-media-cdn.tripadvisor.com/medi...
# ...

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Tour Price', 'Price Per', 'Cancellation', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image            15
# Tour Name        15
# Tour Type        40
# Tour Duration     7
# Tour Price        8
# Price Per        15
# Cancellation     68
# Tour By           9
# City              0
# Country           0
# Link             15
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 195  https://dynamic-media-cdn.tripadvisor.com/medi...
# 196  https://dynamic-media-cdn.tripadvisor.com/medi...
# 197  https://dynamic-media-cdn.tripadvisor.com/medi...
# 198  https://dynamic-media-cdn.tripadvisor.com/medi...
# 199                                                NaN
#
#                                              Tour Name        Tour Type  \
# 0                                                  NaN              NaN
# 1        Singapore Sunset Cruise On A Luxury Catamaran       City Tours
# 2                          Sunset Sail - Dinner Cruise   Sunset Cruises
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          185 non-null    object
#  1   Tour Name      185 non-null    object
#  2   Tour Type      160 non-null    object
#  3   Tour Duration  193 non-null    object
#  4   Tour Price     192 non-null    object
#  5   Price Per      185 non-null    object
#  6   Cancellation   132 non-null    object
#  7   Tour By        191 non-null    object
#  8   City           200 non-null    object
#  9   Country        200 non-null    object
#  10  Link           185 non-null    object
# dtypes: object(11)
# memory usage: 17.3+ KB

# %%
# Store the clean dataset
df.to_csv('Singaporeclean.csv')
