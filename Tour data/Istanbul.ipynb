# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Istanbul.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'ccVGl', 'WlYyy 6', 'ccVGl 2', 'WlYyy 7', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  2,000+ places sorted by traveler favorites
# 1                                       1,139
# 2                                           1
# 3                                          45
# 4                                           5
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2          Free Cancellation up to 4 days in advance
# 3  Not sure? You can cancel this reservation up t...
# 4  Not sure? You can cancel this reservation up t...
#
#                         iPqaD  \
# 0           Clear all filters
# 1    By Guided Istanbul Tours
# 2   By Cappadocia Dream Tours
# 3  By Bosphorus Tour Istanbul
# 4    By Kusadasi Tour Company
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=b...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1  Best of Istanbul: 1, 2 or 3-Day Private Guided...    1.0
# 2  Cappadocia Dream - 2 Days Cappadocia Travel wi...    2.0
# 3  All in One Day Istanbul - Historical Tour of I...    3.0
# 4             Day Tour to Pamukkale from/to Istanbul    4.0
#
#                                         iPqaD href 2        WlYyy 2   WlYyy 3  \
# 0                                                NaN            NaN       NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...      Bus Tours  6+ hours
# 2  https://www.tripadvisor.com/Attraction_Review-...      Bus Tours    2 days
# 3  https://www.tripadvisor.com/Attraction_Review-...  Lunch Cruises  6+ hours
# 4  https://www.tripadvisor.com/Attraction_Review-...      Bus Tours  6+ hours
#
#                                                ySnDE            WlYyy 4 ccVGl  \
# 0                                                NaN                NaN   NaN
# 1  Visit top-sights of Istanbul with your private...  Free cancellation  from
# 2  Although many cross-country tours in Turkey on...  Free cancellation  from
# 3  HISTORICAL TOUR OF ISTANBUL WITH BOSPHORUS SUN...  Free cancellation  from
# 4  Visit > Hierapaolis, Cleopatra Pool and Swim i...  Free cancellation  from
#
#    WlYyy 6    ccVGl 2    WlYyy 7                   dXxty
# 0      NaN        NaN        NaN                     NaN
# 1  $150.00  per group  More info                     NaN
# 2  $359.77  per adult  More info  Taking safety measures
# 3  $135.76  per adult  More info                     NaN
# 4  $218.00  per adult  More info  Taking safety measures

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         819 non-null    object
#  1   cctrW         881 non-null    object
#  2   iPqaD         929 non-null    object
#  3   iPqaD href    784 non-null    object
#  4   FmrIP href    911 non-null    object
#  5   dugSS src     911 non-null    object
#  6   bUshh         911 non-null    object
#  7   cIVmB         911 non-null    float64
#  8   iPqaD href 2  900 non-null    object
#  9   WlYyy 2       813 non-null    object
#  10  WlYyy 3       943 non-null    object
#  11  ySnDE         900 non-null    object
#  12  WlYyy 4       885 non-null    object
#  13  ccVGl         911 non-null    object
#  14  WlYyy 6       912 non-null    object
#  15  ccVGl 2       911 non-null    object
#  16  WlYyy 7       912 non-null    object
#  17  dXxty         641 non-null    object
# dtypes: float64(1), object(17)
# memory usage: 137.2+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'cIVmB','ySnDE','ccVGl', 'WlYyy 7', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Istanbul'
df['Country'] = 'Turkey'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 69

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                         Tour By  \
# 0             Clear all filters
# 1      By Guided Istanbul Tours
# 2     By Cappadocia Dream Tours
# 3    By Bosphorus Tour Istanbul
# 4      By Kusadasi Tour Company
# ..                          ...
# 970             By Turkey Trips
# 971              By MYSTIC TOUR
# 972     By Unique Ephesus Tours
# 973                         NaN
# 974                         NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 970  https://dynamic-media-cdn.tripadvisor.com/medi...
# 971  https://dynamic-media-cdn.tripadvisor.com/medi...
# 972  https://dynamic-media-cdn.tripadvisor.com/medi...
# 973                                                NaN
# 974                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    Best of Istanbul: 1, 2 or 3-Day Private Guided...
# 2    Cappadocia Dream - 2 Days Cappadocia Travel wi...
# 3    All in One Day Istanbul - Historical Tour of I...
# 4               Day Tour to Pamukkale from/to Istanbul
# ..                                                 ...
# 970                       Shore Excursions of Istanbul
# 971  4 Days 3 Nights Istanbul 5 stars hotel with 2 ...
# 972                  Private Tailor-Made Istanbul Tour
# 973                                                NaN
# 974                                                NaN
#
#                                                   Link      Tour Type  \
# 0                                                  NaN            NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...      Bus Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...      Bus Tours
# 3    https://www.tripadvisor.com/Attraction_Review-...  Lunch Cruises
# 4    https://www.tripadvisor.com/Attraction_Review-...      Bus Tours
# ..                                                 ...            ...
# 970  https://www.tripadvisor.com/Attraction_Review-...      Bus Tours
# 971  https://www.tripadvisor.com/Attraction_Review-...      Bus Tours
# 972  https://www.tripadvisor.com/Attraction_Review-...      Bus Tours
# 973                                                NaN              1
# 974                                                NaN              1
#
#     Tour Duration       Cancellation Tour Price  Price Per      City Country
# 0             NaN                NaN        NaN        NaN  Istanbul  Turkey
# 1        6+ hours  Free cancellation    $150.00  per group  Istanbul  Turkey
# 2          2 days  Free cancellation    $359.77  per adult  Istanbul  Turkey
# 3        6+ hours  Free cancellation    $135.76  per adult  Istanbul  Turkey
# 4        6+ hours  Free cancellation    $218.00  per adult  Istanbul  Turkey
# ..            ...                ...        ...        ...       ...     ...
# 970     6–7 hours  Free cancellation    $362.04  per adult  Istanbul  Turkey
# 971       3+ days  Free cancellation  $1,386.00  per adult  Istanbul  Turkey
# 972      6+ hours  Free cancellation    $105.00  per group  Istanbul  Turkey
# 973            33                 35        NaN        NaN  Istanbul  Turkey
# 974            34                 36        NaN        NaN  Istanbul  Turkey
#
# [906 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image             64
# Tour Name         64
# Tour Type        162
# Tour Duration     32
# Tour Price        63
# Price Per         64
# Cancellation      90
# Tour By           46
# City               0
# Country            0
# Link              75
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 970  https://dynamic-media-cdn.tripadvisor.com/medi...
# 971  https://dynamic-media-cdn.tripadvisor.com/medi...
# 972  https://dynamic-media-cdn.tripadvisor.com/medi...
# 973                                                NaN
# 974                                                NaN
#
#                                              Tour Name      Tour Type  \
# 0                                                  NaN            NaN
# 1    Best of Istanbul: 1, 2 or 3-Day Private Guided...      Bus Tours
# 2    Cappadocia Dream - 2 Days Cappadocia Travel wi...      Bus Tours
# 3    All in One Day Istanbul - Historical Tour of I...  Lunch Cruises
# 4               Day Tour to Pamukkale from/to Istanbul      Bus Tours
# ..                                                 ...            ...
# 970                       Shore Excursions of Istanbul      Bus Tours
# 971  4 Days 3 Nights Istanbul 5 stars hotel with 2 ...      Bus Tours
# 972                  Private Tailor-Made Istanbul Tour      Bus Tours
# 973                                                NaN              1
# 974                                                NaN              1
#
#     Tour Duration Tour Price  Price Per       Cancellation  \
# 0             NaN        NaN        NaN                NaN
# 1        6+ hours    $150.00  per group  Free cancellation
# 2          2 days    $359.77  per adult  Free cancellation
# 3        6+ hours    $135.76  per adult  Free cancellation
# 4        6+ hours    $218.00  per adult  Free cancellation
# ..            ...        ...        ...                ...
# 970     6–7 hours    $362.04  per adult  Free cancellation
# 971       3+ days  $1,386.00  per adult  Free cancellation
# 972      6+ hours    $105.00  per group  Free cancellation
# 973            33        NaN        NaN                 35
# 974            34        NaN        NaN                 36
#
#                         Tour By      City Country  \
# 0             Clear all filters  Istanbul  Turkey
# 1      By Guided Istanbul Tours  Istanbul  Turkey
# 2     By Cappadocia Dream Tours  Istanbul  Turkey
# 3    By Bosphorus Tour Istanbul  Istanbul  Turkey
# 4      By Kusadasi Tour Company  Istanbul  Turkey
# ..                          ...       ...     ...
# 970             By Turkey Trips  Istanbul  Turkey
# 971              By MYSTIC TOUR  Istanbul  Turkey
# 972     By Unique Ephesus Tours  Istanbul  Turkey
# 973                         NaN  Istanbul  Turkey
# 974                         NaN  Istanbul  Turkey
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3    https://www.tripadvisor.com/Attraction_Review-...
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 970  https://www.tripadvisor.com/Attraction_Review-...
# 971  https://www.tripadvisor.com/Attraction_Review-...
# 972  https://www.tripadvisor.com/Attraction_Review-...
# 973                                                NaN
# 974                                                NaN
#
# [975 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 975 entries, 0 to 974
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          911 non-null    object
#  1   Tour Name      911 non-null    object
#  2   Tour Type      813 non-null    object
#  3   Tour Duration  943 non-null    object
#  4   Tour Price     912 non-null    object
#  5   Price Per      911 non-null    object
#  6   Cancellation   885 non-null    object
#  7   Tour By        929 non-null    object
#  8   City           975 non-null    object
#  9   Country        975 non-null    object
#  10  Link           900 non-null    object
# dtypes: object(11)
# memory usage: 83.9+ KB

# %%
# Store the clean dataset
df.to_csv('Istanbulclean.csv')
