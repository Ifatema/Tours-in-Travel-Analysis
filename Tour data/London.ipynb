# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('London.csv')

# %%
messy_df.columns
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'WlYyy 3', 'iPqaD href 2', 'WlYyy 4', 'WlYyy 5',
#        'ySnDE', 'WlYyy 6', 'WlYyy 7', 'cctrW 2', 'ccVGl', 'WlYyy 8', 'ccVGl 2',
#        'WlYyy 9', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  2,000+ places sorted by traveler favorites
# 1                                 BEST SELLER
# 2                                 BEST SELLER
# 3                                 BEST SELLER
# 4                                 BEST SELLER
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3                                                NaN
# 4  Not sure? You can cancel this reservation up t...
#
#                              iPqaD  \
# 0                Clear all filters
# 1              By Evan Evans Tours
# 2  By Premium Tours - London Tours
# 3  By Premium Tours - London Tours
# 4                 By Big Bus Tours
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=S...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB WlYyy 3  \
# 0                                                NaN    NaN     NaN
# 1   Stonehenge, Windsor Castle, and Bath from London    1.0   2,041
# 2  Stonehenge, Windsor Castle and Bath with Pub L...    2.0     434
# 3  Harry Potter Tour of Warner Bros. Studio with ...    3.0     384
# 4  Big Bus London Hop-On Hop-Off Tour and River C...    4.0   5,513
#
#                                         iPqaD href 2  ...    WlYyy 5  \
# 0                                                NaN  ...        NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...  ...   6+ hours
# 2  https://www.tripadvisor.com/Attraction_Review-...  ...   6+ hours
# 3  https://www.tripadvisor.com/Attraction_Review-...  ...   6+ hours
# 4  https://www.tripadvisor.com/Attraction_Review-...  ...  2–3 hours
#
#                                                ySnDE            WlYyy 6  \
# 0                                                NaN                NaN
# 1  See the official residence of The Queen and ho...  Free cancellation
# 2  Explore the beautiful scenery of the English c...  Free cancellation
# 3  Delve into the magical world of Harry Potter™ ...                NaN
# 4  See the sights of London aboard an open-top, d...  Free cancellation
#
#                                       WlYyy 7  \
# 0                                         NaN
# 1  94% of travelers recommend this experience
# 2  90% of travelers recommend this experience
# 3                                         NaN
# 4                                         NaN
#
#                                              cctrW 2 ccVGl  WlYyy 8  \
# 0                                                NaN   NaN      NaN
# 1  This number is based on the percentage of all ...  from  $109.36
# 2  This number is based on the percentage of all ...  from  $103.82
# 3                                                NaN  from  $123.20
# 4                                                NaN  from   $43.19
#
#      ccVGl 2    WlYyy 9                   dXxty
# 0        NaN        NaN                     NaN
# 1  per adult  More info                     NaN
# 2  per adult  More info                     NaN
# 3  per adult  More info  Taking safety measures
# 4  per adult  More info  Taking safety measures
#
# [5 rows x 21 columns]

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         228 non-null    object
#  1   cctrW         790 non-null    object
#  2   iPqaD         930 non-null    object
#  3   iPqaD href    698 non-null    object
#  4   FmrIP href    910 non-null    object
#  5   dugSS src     909 non-null    object
#  6   bUshh         910 non-null    object
#  7   cIVmB         910 non-null    float64
#  8   WlYyy 3       703 non-null    object
#  9   iPqaD href 2  901 non-null    object
#  10  WlYyy 4       831 non-null    object
#  11  WlYyy 5       911 non-null    object
#  12  ySnDE         905 non-null    object
#  13  WlYyy 6       762 non-null    object
#  14  WlYyy 7       279 non-null    object
#  15  cctrW 2       278 non-null    object
#  16  ccVGl         910 non-null    object
#  17  WlYyy 8       911 non-null    object
#  18  ccVGl 2       910 non-null    object
#  19  WlYyy 9       911 non-null    object
#  20  dXxty         528 non-null    object
# dtypes: float64(1), object(20)
# memory usage: 159.9+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href',  'cIVmB','WlYyy 3','ySnDE', 'WlYyy 7', 'cctrW 2', 'ccVGl', 'WlYyy 9', 'dXxty' ], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 4':'Tour Type', 'WlYyy 5':'Tour Duration', 'WlYyy 6':'Cancellation', 'WlYyy 8':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'London'
df['Country'] = 'UK'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 69

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                              Tour By  \
# 0                  Clear all filters
# 1                By Evan Evans Tours
# 2    By Premium Tours - London Tours
# 3    By Premium Tours - London Tours
# 4                   By Big Bus Tours
# ..                               ...
# 939                By Urban Saunters
# 940               By Bespoke Britain
# 941                              NaN
# 955                              NaN
# 973                              NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 939  https://dynamic-media-cdn.tripadvisor.com/medi...
# 940  https://dynamic-media-cdn.tripadvisor.com/medi...
# 941                                                NaN
# 955                                                NaN
# 973                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1     Stonehenge, Windsor Castle, and Bath from London
# 2    Stonehenge, Windsor Castle and Bath with Pub L...
# 3    Harry Potter Tour of Warner Bros. Studio with ...
# 4    Big Bus London Hop-On Hop-Off Tour and River C...
# ..                                                 ...
# 939  Royal Westminster Small-Group Guided Walking Tour
# 940            Private Guided Tour of Historic Chelsea
# 941                                                NaN
# 955                                                NaN
# 973                                                NaN
#
#                                                   Link       Tour Type  \
# 0                                                  NaN             NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...  Full-day Tours
# 3    https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
# 4    https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
# ..                                                 ...             ...
# 939  https://www.tripadvisor.com/Attraction_Review-...   Walking Tours
# 940  https://www.tripadvisor.com/Attraction_Review-...   Walking Tours
# 941                                                NaN              36
# 955                                                NaN              37
# 973                                                NaN              38
#
#     Tour Duration       Cancellation Tour Price  Price Per    City Country
# 0             NaN                NaN        NaN        NaN  London      UK
# 1        6+ hours  Free cancellation    $109.36  per adult  London      UK
# 2        6+ hours  Free cancellation    $103.82  per adult  London      UK
# 3        6+ hours                NaN    $123.20  per adult  London      UK
# 4       2–3 hours  Free cancellation     $43.19  per adult  London      UK
# ..            ...                ...        ...        ...     ...     ...
# 939       2 hours  Free cancellation     $38.76  per adult  London      UK
# 940     2–3 hours  Free cancellation    $283.67  per group  London      UK
# 941           NaN                NaN        NaN        NaN  London      UK
# 955           NaN                NaN        NaN        NaN  London      UK
# 973           NaN                NaN        NaN        NaN  London      UK
#
# [905 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image             65
# Tour Name         64
# Tour Type        143
# Tour Duration     63
# Tour Price        63
# Price Per         64
# Cancellation     212
# Tour By           44
# City               0
# Country            0
# Link              73
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 969  https://dynamic-media-cdn.tripadvisor.com/medi...
# 970  https://dynamic-media-cdn.tripadvisor.com/medi...
# 971  https://dynamic-media-cdn.tripadvisor.com/medi...
# 972  https://dynamic-media-cdn.tripadvisor.com/medi...
# 973                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1     Stonehenge, Windsor Castle, and Bath from London
# 2    Stonehenge, Windsor Castle and Bath with Pub L...
# 3    Harry Potter Tour of Warner Bros. Studio with ...
# 4    Big Bus London Hop-On Hop-Off Tour and River C...
# ..                                                 ...
# 969  London Must-Sees and Hidden Gems - Private Ful...
# 970                    Private Bespoke Scavenger Hunts
# 971  Royal Westminster Small-Group Guided Walking Tour
# 972            Private Guided Tour of Historic Chelsea
# 973                                                NaN
#
#                        Tour Type Tour Duration Tour Price  Price Per  \
# 0                            NaN           NaN        NaN        NaN
# 1                      Bus Tours      6+ hours    $109.36  per adult
# 2                 Full-day Tours      6+ hours    $103.82  per adult
# 3                      Bus Tours      6+ hours    $123.20  per adult
# 4                      Bus Tours     2–3 hours     $43.19  per adult
# ..                           ...           ...        ...        ...
# 969                   City Tours       6 hours    $664.46  per adult
# 970  Self-guided Tours & Rentals       3 hours     $35.51  per adult
# 971                Walking Tours       2 hours     $38.76  per adult
# 972                Walking Tours     2–3 hours    $283.67  per group
# 973                           38           NaN        NaN        NaN
#
#           Cancellation                          Tour By    City Country  \
# 0                  NaN                Clear all filters  London      UK
# 1    Free cancellation              By Evan Evans Tours  London      UK
# 2    Free cancellation  By Premium Tours - London Tours  London      UK
# 3                  NaN  By Premium Tours - London Tours  London      UK
# 4    Free cancellation                 By Big Bus Tours  London      UK
# ..                 ...                              ...     ...     ...
# 969  Free cancellation                  By Fashiontrips  London      UK
# 970  Free cancellation                    By BucketRace  London      UK
# 971  Free cancellation                By Urban Saunters  London      UK
# 972  Free cancellation               By Bespoke Britain  London      UK
# 973                NaN                              NaN  London      UK
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3    https://www.tripadvisor.com/Attraction_Review-...
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 969  https://www.tripadvisor.com/Attraction_Review-...
# 970  https://www.tripadvisor.com/Attraction_Review-...
# 971  https://www.tripadvisor.com/Attraction_Review-...
# 972  https://www.tripadvisor.com/Attraction_Review-...
# 973                                                NaN
#
# [974 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          909 non-null    object
#  1   Tour Name      910 non-null    object
#  2   Tour Type      831 non-null    object
#  3   Tour Duration  911 non-null    object
#  4   Tour Price     911 non-null    object
#  5   Price Per      910 non-null    object
#  6   Cancellation   762 non-null    object
#  7   Tour By        930 non-null    object
#  8   City           974 non-null    object
#  9   Country        974 non-null    object
#  10  Link           901 non-null    object
# dtypes: object(11)
# memory usage: 83.8+ KB

# %%
# Store the clean dataset
df.to_csv('Londonclean.csv')
