# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Amsterdam.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'WlYyy 3', 'iPqaD href 2', 'WlYyy 4', 'WlYyy 5',
#        'WlYyy 6', 'WlYyy 7', 'WlYyy 8', 'ySnDE', 'ccVGl', 'WlYyy 9', 'ccVGl 2',
#        'WlYyy 10'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                                WlYyy  \
# 0         1,000+ places sorted by traveler favorites
# 1                                        BEST SELLER
# 2                                LIKELY TO SELL OUT*
# 3  Book risk-free with free cancellations on most...
# 4                                        BEST SELLER
#
#                                                cctrW                  iPqaD  \
# 0  Tours, activities and experiences bookable on ...      Clear all filters
# 1  This number is based on the percentage of all ...  By Flagship Amsterdam
# 2  This number is based on the percentage of all ...          By Pure Boats
# 3                                                NaN                    NaN
# 4  This number is based on the percentage of all ...  By Flagship Amsterdam
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=S...
# 1  https://www.tripadvisor.com/AttractionProductR...
# ...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         89 non-null     object
#  1   cctrW         143 non-null    object
#  2   iPqaD         376 non-null    object
#  3   iPqaD href    310 non-null    object
#  4   FmrIP href    365 non-null    object
#  5   dugSS src     365 non-null    object
#  6   bUshh         365 non-null    object
#  7   cIVmB         365 non-null    float64
#  8   WlYyy 3       311 non-null    object
#  9   iPqaD href 2  364 non-null    object
#  10  WlYyy 4       354 non-null    object
#  11  WlYyy 5       366 non-null    object
#  12  WlYyy 6       356 non-null    object
#  13  WlYyy 7       254 non-null    object
#  14  WlYyy 8       132 non-null    object
#  15  ySnDE         364 non-null    object
#  16  ccVGl         365 non-null    object
#  17  WlYyy 9       366 non-null    object
# ...

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'dugSS src', 'cIVmB','WlYyy 3', 'WlYyy 6','WlYyy 8', 'ySnDE', 'ccVGl','WlYyy 10'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 4':'Tour Type', 'WlYyy 5':'Tour Duration', 'WlYyy 7':'Cancellation', 'WlYyy 9':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Amsterdam'
df['Country'] = 'Netherlands'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 18

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                           Tour By  \
# 0                               Clear all filters
# 1                           By Flagship Amsterdam
# 2                                   By Pure Boats
# 3                                             NaN
# 4                           By Flagship Amsterdam
# ..                                            ...
# 382  By Trigger Tours, Private tours in Amsterdam
# 383          By Henri Willig Cheese Warmoesstraat
# 384                        By Fun Amsterdam Tours
# 385                                           NaN
# 391                                           NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    Amsterdam Canal Cruise in Classic River Boat W...
# 2    The Ultimate Amsterdam Canal Cruise - 2hr - Sm...
# 3                                                  NaN
# 4    Amsterdam Guided Evening Canal Cruise with Bar...
# ...

# %%
df.columns
# Out:
# Index(['Tour By', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Tour Name         27
# Tour Type         38
# Tour Duration     26
# Tour Price        26
# Price Per         27
# Cancellation     138
# Tour By           16
# City               0
# Country            0
# Link              28
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                              Tour Name           Tour Type  \
# 0                                                  NaN                 NaN
# 1    Amsterdam Canal Cruise in Classic River Boat W...          Wine Tours
# 2    The Ultimate Amsterdam Canal Cruise - 2hr - Sm...       Canal Cruises
# 3                                                  NaN                 NaN
# 4    Amsterdam Guided Evening Canal Cruise with Bar...       Night Cruises
# ..                                                 ...                 ...
# 387                Private 1-hour Amsterdam Canal Tour  Private and Luxury
# 388  Amsterdam: Canal Cruise and Jewish Cultural Qu...       Walking Tours
# 389     Amsterdam by Pedal Boat - Off the Beaten Track             Rentals
# 390                                   Shared Beer Bike     Adventure Tours
# 391                                                NaN                  14
#
#     Tour Duration Tour Price  Price Per       Cancellation  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tour Name      365 non-null    object
#  1   Tour Type      354 non-null    object
#  2   Tour Duration  366 non-null    object
#  3   Tour Price     366 non-null    object
#  4   Price Per      365 non-null    object
#  5   Cancellation   254 non-null    object
#  6   Tour By        376 non-null    object
#  7   City           392 non-null    object
#  8   Country        392 non-null    object
#  9   Link           364 non-null    object
# dtypes: object(10)
# memory usage: 30.8+ KB

# %% [markdown]
# **For the Cleaning:**
#
# - type: REMOVE
# - duration: REMOVE
# - canel: REMOVE other
# - price:$ --> float

# %%
# Store the clean dataset
df.to_csv('Amsterdamclean.csv')
