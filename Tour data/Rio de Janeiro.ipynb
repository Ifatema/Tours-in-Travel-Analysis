# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Rio de Janeiro.csv')

# %%
messy_df.columns
# Out:
# Index(['cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src', 'bUshh',
#        'cIVmB', 'WlYyy 2', 'iPqaD href 2', 'WlYyy 3', 'WlYyy 4', 'ySnDE',
#        'WlYyy 5', 'WlYyy 6', 'cctrW 2', 'ccVGl', 'WlYyy 7', 'ccVGl 2',
#        'WlYyy 8', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                                cctrW                    iPqaD  \
# 0  Tours, activities and experiences bookable on ...        Clear all filters
# 1  Not sure? You can cancel this reservation up t...  By C2Rio Tours & Travel
# 2  Not sure? You can cancel this reservation up t...       By Way to Know Rio
# 3                                                NaN                      NaN
# 4  Not sure? You can cancel this reservation up t...    By Rotorfly Voo Livre
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=Y...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3                                                NaN
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3                                                NaN
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                NaN
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB     WlYyy 2  \
# 0                                                NaN    NaN         NaN
# 1  Full Day in Rio: Christ the Redeemer, Sugarloa...    1.0       1,074
# 2  Private Custom Full-Day in Rio including Chris...    2.0          85
# 3                                                NaN    NaN  Cold feet?
# 4      Hang gliding Hang gliding Experience Rotorfly    3.0         555
#
#                                         iPqaD href 2    WlYyy 3    WlYyy 4  \
# 0                                                NaN        NaN        NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...  Bus Tours   6+ hours
# 2  https://www.tripadvisor.com/Attraction_Review-...  Bus Tours  8–9 hours
# 3                                                NaN        NaN        NaN
# 4  https://www.tripadvisor.com/Attraction_Review-...        NaN  1–2 hours
#
#                                                ySnDE            WlYyy 5  \
# 0                                                NaN                NaN
# 1  Enjoy full-day tour in Rio de Janeiro visiting...  Free cancellation
# 2  The most complete private tour on TripAdvisor!...  Free cancellation
# 3                                                NaN                NaN
# 4  We fly every day with great joy and care, as i...  Free cancellation
#
#                                        WlYyy 6  \
# 0                                          NaN
# 1   98% of travelers recommend this experience
# 2  100% of travelers recommend this experience
# 3                                          NaN
# 4   99% of travelers recommend this experience
#
#                                              cctrW 2 ccVGl  WlYyy 7  \
# 0                                                NaN   NaN      NaN
# 1  This number is based on the percentage of all ...  from   $95.76
# 2  This number is based on the percentage of all ...  from  $230.00
# 3                                                NaN   NaN      NaN
# 4  This number is based on the percentage of all ...  from  $142.34
#
#      ccVGl 2    WlYyy 8 dXxty
# 0        NaN        NaN   NaN
# 1  per adult  More info   NaN
# 2  per group  More info   NaN
# 3        NaN        NaN   NaN
# 4  per adult  More info   NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cctrW         359 non-null    object
#  1   iPqaD         370 non-null    object
#  2   iPqaD href    309 non-null    object
#  3   FmrIP href    360 non-null    object
#  4   dugSS src     360 non-null    object
#  5   bUshh         360 non-null    object
#  6   cIVmB         360 non-null    float64
#  7   WlYyy 2       311 non-null    object
#  8   iPqaD href 2  358 non-null    object
#  9   WlYyy 3       295 non-null    object
#  10  WlYyy 4       371 non-null    object
#  11  ySnDE         356 non-null    object
#  12  WlYyy 5       348 non-null    object
#  13  WlYyy 6       135 non-null    object
#  14  cctrW 2       134 non-null    object
#  15  ccVGl         360 non-null    object
#  16  WlYyy 7       361 non-null    object
#  17  ccVGl 2       360 non-null    object
#  18  WlYyy 8       361 non-null    object
#  19  dXxty         190 non-null    object
# dtypes: float64(1), object(19)
# memory usage: 60.4+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['cctrW','iPqaD href', 'FmrIP href', 'cIVmB','WlYyy 2', 'WlYyy 6', 'cctrW 2', 'ccVGl','WlYyy 8', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 3':'Tour Type', 'WlYyy 4':'Tour Duration', 'WlYyy 5':'Cancellation', 'WlYyy 7':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Rio de Janeiro'
df['Country'] = 'Brazil'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 12

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                      Tour By  \
# 0          Clear all filters
# 1    By C2Rio Tours & Travel
# 2         By Way to Know Rio
# 3                        NaN
# 4      By Rotorfly Voo Livre
# ..                       ...
# 381           By Trip In Rio
# 382   By Gregtur Tourism Rio
# 383     By Rio Carioca Tours
# 384         By Quicktransfer
# 385                      NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 381  https://dynamic-media-cdn.tripadvisor.com/medi...
# 382  https://dynamic-media-cdn.tripadvisor.com/medi...
# 383  https://dynamic-media-cdn.tripadvisor.com/medi...
# 384  https://dynamic-media-cdn.tripadvisor.com/medi...
# 385                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    Full Day in Rio: Christ the Redeemer, Sugarloa...
# 2    Private Custom Full-Day in Rio including Chris...
# 3                                                  NaN
# 4        Hang gliding Hang gliding Experience Rotorfly
# ..                                                 ...
# 381  Petrópolis the Imperial City - The City of the...
# 382  3-hour Boat Tour of Rio in a Shared Group – La...
# 383  Private Tour: Christ the Redeemer & Sugarloaf ...
# 384  Private Departure Transfer from Rio de Janeiro...
# 385                                                NaN
#
#                                                   Link       Tour Type  \
# 0                                                  NaN             NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
# 3                                                  NaN             NaN
# 4    https://www.tripadvisor.com/Attraction_Review-...             NaN
# ..                                                 ...             ...
# 381  https://www.tripadvisor.com/Attraction_Review-...  Full-day Tours
# 382  https://www.tripadvisor.com/Attraction_Review-...         Sailing
# 383  https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
# 384  https://www.tripadvisor.com/Attraction_Review-...             NaN
# 385                                                NaN              14
#
#      Tour Duration                                              ySnDE  \
# 0              NaN                                                NaN
# 1         6+ hours  Enjoy full-day tour in Rio de Janeiro visiting...
# 2        8–9 hours  The most complete private tour on TripAdvisor!...
# 3              NaN                                                NaN
# 4        1–2 hours  We fly every day with great joy and care, as i...
# ..             ...                                                ...
# 381     7–10 hours  Get to know the history and beauty of Petropol...
# 382        3 hours  Join us for a 3-hour sailboat tour to discover...
# 383        4 hours  Enjoy this private 4 to 5-hour tour of Rio de ...
# 384  30–70 minutes  Don't go through all the hassle of waiting in ...
# 385             16                                                NaN
#
#           Cancellation Tour Price  Price Per            City Country
# 0                  NaN        NaN        NaN  Rio de Janeiro  Brazil
# 1    Free cancellation     $95.76  per adult  Rio de Janeiro  Brazil
# 2    Free cancellation    $230.00  per group  Rio de Janeiro  Brazil
# 3                  NaN        NaN        NaN  Rio de Janeiro  Brazil
# 4    Free cancellation    $142.34  per adult  Rio de Janeiro  Brazil
# ..                 ...        ...        ...             ...     ...
# 381  Free cancellation     $89.59  per adult  Rio de Janeiro  Brazil
# 382  Free cancellation     $72.00  per adult  Rio de Janeiro  Brazil
# 383  Free cancellation    $120.00  per adult  Rio de Janeiro  Brazil
# 384  Free cancellation     $22.15  per adult  Rio de Janeiro  Brazil
# 385                NaN        NaN        NaN  Rio de Janeiro  Brazil
#
# [374 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'ySnDE', 'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image            26
# Tour Name        26
# Tour Type        91
# Tour Duration    15
# Tour Price       25
# Price Per        26
# Cancellation     38
# Tour By          16
# City              0
# Country           0
# Link             28
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 381  https://dynamic-media-cdn.tripadvisor.com/medi...
# 382  https://dynamic-media-cdn.tripadvisor.com/medi...
# 383  https://dynamic-media-cdn.tripadvisor.com/medi...
# 384  https://dynamic-media-cdn.tripadvisor.com/medi...
# 385                                                NaN
#
#                                              Tour Name       Tour Type  \
# 0                                                  NaN             NaN
# 1    Full Day in Rio: Christ the Redeemer, Sugarloa...       Bus Tours
# 2    Private Custom Full-Day in Rio including Chris...       Bus Tours
# 3                                                  NaN             NaN
# 4        Hang gliding Hang gliding Experience Rotorfly             NaN
# ..                                                 ...             ...
# 381  Petrópolis the Imperial City - The City of the...  Full-day Tours
# 382  3-hour Boat Tour of Rio in a Shared Group – La...         Sailing
# 383  Private Tour: Christ the Redeemer & Sugarloaf ...       Bus Tours
# 384  Private Departure Transfer from Rio de Janeiro...             NaN
# 385                                                NaN              14
#
#      Tour Duration Tour Price  Price Per       Cancellation  \
# 0              NaN        NaN        NaN                NaN
# 1         6+ hours     $95.76  per adult  Free cancellation
# 2        8–9 hours    $230.00  per group  Free cancellation
# 3              NaN        NaN        NaN                NaN
# 4        1–2 hours    $142.34  per adult  Free cancellation
# ..             ...        ...        ...                ...
# 381     7–10 hours     $89.59  per adult  Free cancellation
# 382        3 hours     $72.00  per adult  Free cancellation
# 383        4 hours    $120.00  per adult  Free cancellation
# 384  30–70 minutes     $22.15  per adult  Free cancellation
# 385             16        NaN        NaN                NaN
#
#                      Tour By            City Country  \
# 0          Clear all filters  Rio de Janeiro  Brazil
# 1    By C2Rio Tours & Travel  Rio de Janeiro  Brazil
# 2         By Way to Know Rio  Rio de Janeiro  Brazil
# 3                        NaN  Rio de Janeiro  Brazil
# 4      By Rotorfly Voo Livre  Rio de Janeiro  Brazil
# ..                       ...             ...     ...
# 381           By Trip In Rio  Rio de Janeiro  Brazil
# 382   By Gregtur Tourism Rio  Rio de Janeiro  Brazil
# 383     By Rio Carioca Tours  Rio de Janeiro  Brazil
# 384         By Quicktransfer  Rio de Janeiro  Brazil
# 385                      NaN  Rio de Janeiro  Brazil
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3                                                  NaN
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 381  https://www.tripadvisor.com/Attraction_Review-...
# 382  https://www.tripadvisor.com/Attraction_Review-...
# 383  https://www.tripadvisor.com/Attraction_Review-...
# 384  https://www.tripadvisor.com/Attraction_Review-...
# 385                                                NaN
#
# [386 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386 entries, 0 to 385
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          360 non-null    object
#  1   Tour Name      360 non-null    object
#  2   Tour Type      295 non-null    object
#  3   Tour Duration  371 non-null    object
#  4   Tour Price     361 non-null    object
#  5   Price Per      360 non-null    object
#  6   Cancellation   348 non-null    object
#  7   Tour By        370 non-null    object
#  8   City           386 non-null    object
#  9   Country        386 non-null    object
#  10  Link           358 non-null    object
# dtypes: object(11)
# memory usage: 33.3+ KB

# %%
# Store the clean dataset
df.to_csv('Rio de Janeiroclean.csv')
