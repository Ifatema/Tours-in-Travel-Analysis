# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Riyadh.csv')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                     WlYyy              iPqaD  \
# 0  58 places sorted by traveler favorites  Clear all filters
# 1                                      11    By riyadh trips
# 2                                      44   By Riyadh Hiking
# 3                                       1     By Vidi Guides
# 4                                       1     By Vidi Guides
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=N...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1                                  Edge Of The World    1.0
# 2                                  Edge of the world    2.0
# 3  Riyadh’s History and Al Masmak - Self-Guided W...    3.0
# 4           Al Masmak Self-Guided Audio Walking Tour    4.0
#
#                                         iPqaD href 2          WlYyy 2  \
# 0                                                NaN              NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...   Full-day Tours
# 2  https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 3  https://www.tripadvisor.com/Attraction_Review-...    Walking Tours
# 4  https://www.tripadvisor.com/Attraction_Review-...    Walking Tours
#
#       WlYyy 3                 WlYyy 4            WlYyy 5  \
# 0         NaN                     NaN                NaN
# 1  7–12 hours  Taking safety measures  Free cancellation
# 2   5–7 hours       Free cancellation                NaN
# 3   1–2 hours  Taking safety measures  Free cancellation
# 4      1 hour  Taking safety measures  Free cancellation
#
#                                                ySnDE ccVGl   WlYyy 7  \
# 0                                                NaN   NaN       NaN
# 1  Edge of the World is an exciting ride from Riy...  from  $150.00
# 2                                                NaN  from  $100.00
# 3  Join a local historian and see Riyadh like you...  from   $17.98
# 4  Discover the secret spots in Al Masmak Fortres...  from    $9.68
#
#      ccVGl 2    WlYyy 8
# 0        NaN        NaN
# 1  per adult  More info
# 2  per adult  More info
# 3  per adult  More info
# 4  per adult  More info

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         30 non-null     object
#  1   iPqaD         78 non-null     object
#  2   iPqaD href    27 non-null     object
#  3   FmrIP href    85 non-null     object
#  4   dugSS src     83 non-null     object
#  5   bUshh         85 non-null     object
#  6   cIVmB         85 non-null     float64
#  7   iPqaD href 2  75 non-null     object
#  8   WlYyy 2       57 non-null     object
#  9   WlYyy 3       86 non-null     object
#  10  WlYyy 4       84 non-null     object
#  11  WlYyy 5       66 non-null     object
#  12  ySnDE         79 non-null     object
#  13  ccVGl         85 non-null     object
#  14  WlYyy 7       85 non-null     object
#  15  ccVGl 2       85 non-null     object
#  16  WlYyy 8       85 non-null     object
# dtypes: float64(1), object(16)
# memory usage: 12.3+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %% [markdown]
# 1. *Unnessary Columns*

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src', 'bUshh',
#        'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'WlYyy 4', 'WlYyy 5',
#        'ySnDE', 'ccVGl', 'WlYyy 7', 'ccVGl 2', 'WlYyy 8'],
#       dtype='object')

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'iPqaD href', 'FmrIP href',  'cIVmB', 'WlYyy 4', 'ySnDE', 'ccVGl', 'WlYyy 8'], axis=1 , inplace=True)

# %% [markdown]
# 2. *Rename Columns*

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 5':'Cancellation', 'WlYyy 7':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %% [markdown]
# 3. *Adding City and Country Columns*

# %%
# adding new columns
df['City'] = 'Riyadh'
df['Country'] = 'Saudi Arabia'

# %% [markdown]
# 4. *Duplicated Rows*

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 29

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                  Tour By                                              Image  \
# 0      Clear all filters                                                NaN
# 1        By riyadh trips  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2       By Riyadh Hiking  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3         By Vidi Guides  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4         By Vidi Guides  https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                   ...                                                ...
# 87    By Saudi Discovery  https://dynamic-media-cdn.tripadvisor.com/medi...
# 88  By basem abushammala  https://dynamic-media-cdn.tripadvisor.com/medi...
# 89    By Saudi Discovery  https://dynamic-media-cdn.tripadvisor.com/medi...
# 90    By Saudi Discovery  https://dynamic-media-cdn.tripadvisor.com/medi...
# 91                   NaN                                                NaN
#
#                                             Tour Name  \
# 0                                                 NaN
# 1                                   Edge Of The World
# 2                                   Edge of the world
# 3   Riyadh’s History and Al Masmak - Self-Guided W...
# 4            Al Masmak Self-Guided Audio Walking Tour
# ..                                                ...
# 87       Morning Desert Safari Experience from Riyadh
# 88                            shuttle from&to airport
# 89                          Half Day Riyadh City Tour
# 90  Day Trip to Edge of the World from Riyadh with...
# 91                                                NaN
#
#                                                  Link        Tour Type  \
# 0                                                 NaN              NaN
# 1   https://www.tripadvisor.com/Attraction_Review-...   Full-day Tours
# 2   https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 3   https://www.tripadvisor.com/Attraction_Review-...    Walking Tours
# 4   https://www.tripadvisor.com/Attraction_Review-...    Walking Tours
# ..                                                ...              ...
# 87  https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 88  https://www.tripadvisor.com/Attraction_Review-...              NaN
# 89  https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
# 90  https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 91                                                NaN                1
#
#    Tour Duration       Cancellation Tour Price  Price Per    City  \
# 0            NaN                NaN        NaN        NaN  Riyadh
# 1     7–12 hours  Free cancellation   $150.00   per adult  Riyadh
# 2      5–7 hours                NaN   $100.00   per adult  Riyadh
# 3      1–2 hours  Free cancellation    $17.98   per adult  Riyadh
# 4         1 hour  Free cancellation     $9.68   per adult  Riyadh
# ..           ...                ...        ...        ...     ...
# 87       4 hours  Free cancellation    $88.00   per adult  Riyadh
# 88     1–2 hours                NaN   $200.00   per group  Riyadh
# 89       4 hours  Free cancellation    $69.00   per adult  Riyadh
# 90      6+ hours  Free cancellation   $119.00   per adult  Riyadh
# 91           NaN                NaN        NaN        NaN  Riyadh
#
#          Country
# 0   Saudi Arabia
# 1   Saudi Arabia
# 2   Saudi Arabia
# 3   Saudi Arabia
# 4   Saudi Arabia
# ..           ...
# 87  Saudi Arabia
# 88  Saudi Arabia
# 89  Saudi Arabia
# 90  Saudi Arabia
# 91  Saudi Arabia
#
# [63 rows x 11 columns]

# %% [markdown]
# 5. *Reorder the Columns*

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link',]]

# %% [markdown]
# 6. *Null Value*

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image             9
# Tour Name         7
# Tour Type        35
# Tour Duration     6
# Tour Price        7
# Price Per         7
# Cancellation     26
# Tour By          14
# City              0
# Country           0
# Link             17
# dtype: int64

# %% [markdown]
# 7. *Reset the Index*

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                 Image  \
# 0                                                 NaN
# 1   https://dynamic-media-cdn.tripadvisor.com/medi...
# 2   https://dynamic-media-cdn.tripadvisor.com/medi...
# 3   https://dynamic-media-cdn.tripadvisor.com/medi...
# 4   https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                ...
# 87  https://dynamic-media-cdn.tripadvisor.com/medi...
# 88  https://dynamic-media-cdn.tripadvisor.com/medi...
# 89  https://dynamic-media-cdn.tripadvisor.com/medi...
# 90  https://dynamic-media-cdn.tripadvisor.com/medi...
# 91                                                NaN
#
#                                             Tour Name        Tour Type  \
# 0                                                 NaN              NaN
# 1                                   Edge Of The World   Full-day Tours
# 2                                   Edge of the world  Adventure Tours
# 3   Riyadh’s History and Al Masmak - Self-Guided W...    Walking Tours
# 4            Al Masmak Self-Guided Audio Walking Tour    Walking Tours
# ..                                                ...              ...
# 87       Morning Desert Safari Experience from Riyadh  Adventure Tours
# 88                            shuttle from&to airport              NaN
# 89                          Half Day Riyadh City Tour        Bus Tours
# 90  Day Trip to Edge of the World from Riyadh with...  Adventure Tours
# 91                                                NaN                1
#
#    Tour Duration Tour Price  Price Per       Cancellation  \
# 0            NaN        NaN        NaN                NaN
# 1     7–12 hours   $150.00   per adult  Free cancellation
# 2      5–7 hours   $100.00   per adult                NaN
# 3      1–2 hours    $17.98   per adult  Free cancellation
# 4         1 hour     $9.68   per adult  Free cancellation
# ..           ...        ...        ...                ...
# 87       4 hours    $88.00   per adult  Free cancellation
# 88     1–2 hours   $200.00   per group                NaN
# 89       4 hours    $69.00   per adult  Free cancellation
# 90      6+ hours   $119.00   per adult  Free cancellation
# 91           NaN        NaN        NaN                NaN
#
#                  Tour By    City       Country  \
# 0      Clear all filters  Riyadh  Saudi Arabia
# 1        By riyadh trips  Riyadh  Saudi Arabia
# 2       By Riyadh Hiking  Riyadh  Saudi Arabia
# 3         By Vidi Guides  Riyadh  Saudi Arabia
# 4         By Vidi Guides  Riyadh  Saudi Arabia
# ..                   ...     ...           ...
# 87    By Saudi Discovery  Riyadh  Saudi Arabia
# 88  By basem abushammala  Riyadh  Saudi Arabia
# 89    By Saudi Discovery  Riyadh  Saudi Arabia
# 90    By Saudi Discovery  Riyadh  Saudi Arabia
# 91                   NaN  Riyadh  Saudi Arabia
#
#                                                  Link
# 0                                                 NaN
# 1   https://www.tripadvisor.com/Attraction_Review-...
# 2   https://www.tripadvisor.com/Attraction_Review-...
# 3   https://www.tripadvisor.com/Attraction_Review-...
# 4   https://www.tripadvisor.com/Attraction_Review-...
# ..                                                ...
# 87  https://www.tripadvisor.com/Attraction_Review-...
# 88  https://www.tripadvisor.com/Attraction_Review-...
# 89  https://www.tripadvisor.com/Attraction_Review-...
# 90  https://www.tripadvisor.com/Attraction_Review-...
# 91                                                NaN
#
# [92 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          83 non-null     object
#  1   Tour Name      85 non-null     object
#  2   Tour Type      57 non-null     object
#  3   Tour Duration  86 non-null     object
#  4   Tour Price     85 non-null     object
#  5   Price Per      85 non-null     object
#  6   Cancellation   66 non-null     object
#  7   Tour By        78 non-null     object
#  8   City           92 non-null     object
#  9   Country        92 non-null     object
#  10  Link           75 non-null     object
# dtypes: object(11)
# memory usage: 8.0+ KB

# %%
# Store the clean dataset
df.to_csv('Riyadhclean.csv')
