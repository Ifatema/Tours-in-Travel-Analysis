# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Hong Kong.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src', 'bUshh',
#        'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'WlYyy 4', 'ySnDE',
#        'ccVGl', 'WlYyy 6', 'ccVGl 2', 'WlYyy 7', 'WlYyy 8'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                      WlYyy  \
# 0  447 places sorted by traveler favorites
# 1                                       14
# 2                                      102
# 3                                      128
# 4                                       15
#
#                                     iPqaD  \
# 0                       Clear all filters
# 1                       By Wild Hong Kong
# 2       By Hong Kong Foodie Tasting Tours
# 3                 By Hong Kong Free Tours
# 4  By This Is Asia Private Tours-Day Tour
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=c...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# ...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         186 non-null    object
#  1   iPqaD         280 non-null    object
#  2   iPqaD href    174 non-null    object
#  3   FmrIP href    276 non-null    object
#  4   dugSS src     276 non-null    object
#  5   bUshh         276 non-null    object
#  6   cIVmB         276 non-null    float64
#  7   iPqaD href 2  271 non-null    object
#  8   WlYyy 2       224 non-null    object
#  9   WlYyy 3       286 non-null    object
#  10  WlYyy 4       235 non-null    object
#  11  ySnDE         274 non-null    object
#  12  ccVGl         276 non-null    object
#  13  WlYyy 6       276 non-null    object
#  14  ccVGl 2       276 non-null    object
#  15  WlYyy 7       276 non-null    object
#  16  WlYyy 8       117 non-null    object
# dtypes: float64(1), object(16)
# ...

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'iPqaD href', 'FmrIP href',  'cIVmB', 'WlYyy 4', 'ySnDE', 'ccVGl','WlYyy 7'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 8':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Hong Kong'
df['Country'] = 'China'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 14

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                     Tour By  \
# 0                         Clear all filters
# 1                         By Wild Hong Kong
# 2         By Hong Kong Foodie Tasting Tours
# 3                   By Hong Kong Free Tours
# 4    By This Is Asia Private Tours-Day Tour
# ..                                      ...
# 284                         By Ka Wai Yeung
# 285                  By Tour East Hong Kong
# 286                  By Goofy Waves Limited
# 287                                     NaN
# 294                                     NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# ...

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Tour Price', 'Price Per', 'Cancellation', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image             19
# Tour Name         19
# Tour Type         71
# Tour Duration      9
# Tour Price        19
# Price Per         19
# Cancellation     178
# Tour By           15
# City               0
# Country            0
# Link              24
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 290  https://dynamic-media-cdn.tripadvisor.com/medi...
# 291  https://dynamic-media-cdn.tripadvisor.com/medi...
# 292  https://dynamic-media-cdn.tripadvisor.com/medi...
# 293  https://dynamic-media-cdn.tripadvisor.com/medi...
# 294                                                NaN
#
#                                              Tour Name        Tour Type  \
# 0                                                  NaN              NaN
# 1             The Dragon's Back Hiking Tour, Hong Kong  Adventure Tours
# 2           Hong Kong Food Tour: Sham Shui Po District       City Tours
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          276 non-null    object
#  1   Tour Name      276 non-null    object
#  2   Tour Type      224 non-null    object
#  3   Tour Duration  286 non-null    object
#  4   Tour Price     276 non-null    object
#  5   Price Per      276 non-null    object
#  6   Cancellation   117 non-null    object
#  7   Tour By        280 non-null    object
#  8   City           295 non-null    object
#  9   Country        295 non-null    object
#  10  Link           271 non-null    object
# dtypes: object(11)
# memory usage: 25.5+ KB

# %%
# Store the clean dataset
df.to_csv('Hong Kongclean.csv')
