# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Mexico City.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'WlYyy 2', 'iPqaD href 2', 'WlYyy 3', 'WlYyy 4',
#        'ySnDE', 'dXxty', 'WlYyy 5', 'ccVGl', 'WlYyy 6', 'ccVGl 2', 'WlYyy 7',
#        'WlYyy 8', 'cctrW 2'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                      WlYyy  \
# 0  730 places sorted by traveler favorites
# 1                              BEST SELLER
# 2                                      NaN
# 3                              BEST SELLER
# 4                                      NaN
#
#                                                cctrW                   iPqaD  \
# 0  Tours, activities and experiences bookable on ...       Clear all filters
# 1  This number is based on the percentage of all ...            By Mexitours
# 2                                                NaN          By TeoTours MX
# 3  This number is based on the percentage of all ...          By Amigo Tours
# 4  This number is based on the percentage of all ...  By Teotihuacan en Bici
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=M...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# ...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         70 non-null     object
#  1   cctrW         97 non-null     object
#  2   iPqaD         303 non-null    object
#  3   iPqaD href    265 non-null    object
#  4   FmrIP href    300 non-null    object
#  5   dugSS src     300 non-null    object
#  6   bUshh         300 non-null    object
#  7   cIVmB         300 non-null    float64
#  8   WlYyy 2       267 non-null    object
#  9   iPqaD href 2  293 non-null    object
#  10  WlYyy 3       287 non-null    object
#  11  WlYyy 4       310 non-null    object
#  12  ySnDE         297 non-null    object
#  13  dXxty         202 non-null    object
#  14  WlYyy 5       88 non-null     object
#  15  ccVGl         300 non-null    object
#  16  WlYyy 6       301 non-null    object
#  17  ccVGl 2       300 non-null    object
# ...

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'dugSS src', 'cIVmB', 'WlYyy 2', 'ySnDE', 'dXxty','WlYyy 5','ccVGl', 'WlYyy 7', 'cctrW 2'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 3':'Tour Type', 'WlYyy 4':'Tour Duration', 'WlYyy 8':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Mexico City'
df['Country'] = 'Mexico'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 9

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                     Tour By  \
# 0         Clear all filters
# 1              By Mexitours
# 2            By TeoTours MX
# 3            By Amigo Tours
# 4    By Teotihuacan en Bici
# ..                      ...
# 317           By Elife Limo
# 318    By MY TRANSFER GROUP
# 319         By Azteca Tours
# 320                     NaN
# 321                     NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1                                   Frida Kahlo Museum
# 2    TEOTIHUACAN BALLOON RIDE (Transportation & bre...
# 3    Teotihuacan, Tlatelolco, Guadalupe Shrine and ...
# 4    Teotihuacan Hot Air Balloon Ride with Optional...
# ..                                                 ...
# 317  Private Arrival Transfer In Mexico City Intern...
# 318  Transfer in Private Minivan from México Airpor...
# 319                          Taxco and Cuernavaca Tour
# 320                                                NaN
# ...

# %%
df.columns
# Out:
# Index(['Tour By', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Tour Price', 'Price Per', 'Cancellation', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Tour Name        22
# Tour Type        35
# Tour Duration    12
# Tour Price       21
# Price Per        22
# Cancellation     62
# Tour By          19
# City              0
# Country           0
# Link             29
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                              Tour Name            Tour Type  \
# 0                                                  NaN                  NaN
# 1                                   Frida Kahlo Museum  Skip-the-Line Tours
# 2    TEOTIHUACAN BALLOON RIDE (Transportation & bre...            Bus Tours
# 3    Teotihuacan, Tlatelolco, Guadalupe Shrine and ...            Bus Tours
# 4    Teotihuacan Hot Air Balloon Ride with Optional...      Adventure Tours
# ..                                                 ...                  ...
# 317  Private Arrival Transfer In Mexico City Intern...                  NaN
# 318  Transfer in Private Minivan from México Airpor...                  NaN
# 319                          Taxco and Cuernavaca Tour       Full-day Tours
# 320                                                NaN                    9
# 321                                                NaN                   10
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tour Name      300 non-null    object
#  1   Tour Type      287 non-null    object
#  2   Tour Duration  310 non-null    object
#  3   Tour Price     301 non-null    object
#  4   Price Per      300 non-null    object
#  5   Cancellation   260 non-null    object
#  6   Tour By        303 non-null    object
#  7   City           322 non-null    object
#  8   Country        322 non-null    object
#  9   Link           293 non-null    object
# dtypes: object(10)
# memory usage: 25.3+ KB

# %% [markdown]
# **For the Cleaning:**
# - by: REMOVE Clear all filters
# - type: REMOVE other
# - duration: REMOVE other
# - canel: REMOVE other
# - price:$ --> float

# %%
# Store the clean dataset
df.to_csv('Mexico Cityclean.csv')
