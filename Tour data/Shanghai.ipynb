# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Shanghai.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 6', 'ccVGl 2',
#        'WlYyy 7', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  1,000+ places sorted by traveler favorites
# 1                                          13
# 2                                          61
# 3                                         118
# 4                                         280
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3  Not sure? You can cancel this reservation up t...
# 4  Not sure? You can cancel this reservation up t...
#
#                       iPqaD  \
# 0         Clear all filters
# 1  By Amazing Shanghai Trip
# 2  By Amazing Shanghai Trip
# 3  By Amazing Shanghai Trip
# 4        By Shanghai Foodie
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=Q...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1  Shanghai Private Tour with River Cruise, Shang...    1.0
# 2  Half Day Private Tour to Zhujiajiao Water Town...    2.0
# 3  Shanghai Night River Cruise Tour with Xinjiang...    3.0
# 4      Authentic Local Food Tour in Central Shanghai    4.0
#
#                                         iPqaD href 2     WlYyy 2    WlYyy 3  \
# 0                                                NaN         NaN        NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...   Bus Tours    5 hours
# 2  https://www.tripadvisor.com/Attraction_Review-...   Bus Tours  4–5 hours
# 3  https://www.tripadvisor.com/Attraction_Review-...   Bus Tours    3 hours
# 4  https://www.tripadvisor.com/Attraction_Review-...  City Tours    3 hours
#
#                                                ySnDE            WlYyy 4  \
# 0                                                NaN                NaN
# 1  Taste Shanghai contains two meanings: first on...  Free cancellation
# 2  Enjoy short get away from Shanghai city to bea...  Free cancellation
# 3  Enjoy a night in Shanghai by starting a 60-min...  Free cancellation
# 4  Taste a dozen traditional Shanghainese dishes ...  Free cancellation
#
#                                        WlYyy 5  \
# 0                                          NaN
# 1  100% of travelers recommend this experience
# 2  100% of travelers recommend this experience
# 3   99% of travelers recommend this experience
# 4   98% of travelers recommend this experience
#
#                                              cctrW 2 ccVGl  WlYyy 6  \
# 0                                                NaN   NaN      NaN
# 1  This number is based on the percentage of all ...  from  $176.50
# 2  This number is based on the percentage of all ...  from  $134.50
# 3  This number is based on the percentage of all ...  from  $138.00
# 4  This number is based on the percentage of all ...  from   $67.00
#
#      ccVGl 2    WlYyy 7 dXxty
# 0        NaN        NaN   NaN
# 1  per adult  More info   NaN
# 2  per adult  More info   NaN
# 3  per adult  More info   NaN
# 4  per adult  More info   NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         277 non-null    object
#  1   cctrW         271 non-null    object
#  2   iPqaD         274 non-null    object
#  3   iPqaD href    265 non-null    object
#  4   FmrIP href    271 non-null    object
#  5   dugSS src     271 non-null    object
#  6   bUshh         271 non-null    object
#  7   cIVmB         271 non-null    float64
#  8   iPqaD href 2  265 non-null    object
#  9   WlYyy 2       231 non-null    object
#  10  WlYyy 3       281 non-null    object
#  11  ySnDE         268 non-null    object
#  12  WlYyy 4       272 non-null    object
#  13  WlYyy 5       69 non-null     object
#  14  cctrW 2       65 non-null     object
#  15  ccVGl         271 non-null    object
#  16  WlYyy 6       272 non-null    object
#  17  ccVGl 2       271 non-null    object
#  18  WlYyy 7       272 non-null    object
#  19  dXxty         123 non-null    object
# dtypes: float64(1), object(19)
# memory usage: 45.8+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'dugSS src', 'cIVmB', 'ySnDE', 'WlYyy 5', 'cctrW 2', 'ccVGl','WlYyy 7', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Shanghai'
df['Country'] = 'China'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 9

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                       Tour By  \
# 0           Clear all filters
# 1    By Amazing Shanghai Trip
# 2    By Amazing Shanghai Trip
# 3    By Amazing Shanghai Trip
# 4          By Shanghai Foodie
# ..                        ...
# 287     By IslamiChina Travel
# 288      By MY TRANSFER GROUP
# 289   By Sunny Tours Shanghai
# 290        By China Xian Tour
# 291                       NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    Shanghai Private Tour with River Cruise, Shang...
# 2    Half Day Private Tour to Zhujiajiao Water Town...
# 3    Shanghai Night River Cruise Tour with Xinjiang...
# 4        Authentic Local Food Tour in Central Shanghai
# ..                                                 ...
# 287  Shanghai Pudong International Airport (PVG) Pr...
# 288  Transfer in Private Minivan from Shanghai Hong...
# 289  Private Tour of Zhujiajiao Ancient Water Town ...
# 290  2-Day Beijing Private Tour from Shanghai by Fl...
# 291                                                NaN
#
#                                                   Link   Tour Type  \
# 0                                                  NaN         NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...   Bus Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...   Bus Tours
# 3    https://www.tripadvisor.com/Attraction_Review-...   Bus Tours
# 4    https://www.tripadvisor.com/Attraction_Review-...  City Tours
# ..                                                 ...         ...
# 287  https://www.tripadvisor.com/Attraction_Review-...         NaN
# 288  https://www.tripadvisor.com/Attraction_Review-...         NaN
# 289  https://www.tripadvisor.com/Attraction_Review-...   Bus Tours
# 290  https://www.tripadvisor.com/Attraction_Review-...   Bus Tours
# 291                                                NaN           1
#
#      Tour Duration       Cancellation Tour Price  Price Per      City Country
# 0              NaN                NaN        NaN        NaN  Shanghai   China
# 1          5 hours  Free cancellation    $176.50  per adult  Shanghai   China
# 2        4–5 hours  Free cancellation    $134.50  per adult  Shanghai   China
# 3          3 hours  Free cancellation    $138.00  per adult  Shanghai   China
# 4          3 hours  Free cancellation     $67.00  per adult  Shanghai   China
# ..             ...                ...        ...        ...       ...     ...
# 287  30–60 minutes  Free cancellation     $37.34  per adult  Shanghai   China
# 288     30 minutes  Free cancellation     $56.67  per adult  Shanghai   China
# 289      6–7 hours  Free cancellation    $165.34  per adult  Shanghai   China
# 290         2 days  Free cancellation    $850.00  per adult  Shanghai   China
# 291             11                 13        NaN        NaN  Shanghai   China
#
# [283 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Tour Name        21
# Tour Type        61
# Tour Duration    11
# Tour Price       20
# Price Per        21
# Cancellation     20
# Tour By          18
# City              0
# Country           0
# Link             27
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                              Tour Name   Tour Type  \
# 0                                                  NaN         NaN
# 1    Shanghai Private Tour with River Cruise, Shang...   Bus Tours
# 2    Half Day Private Tour to Zhujiajiao Water Town...   Bus Tours
# 3    Shanghai Night River Cruise Tour with Xinjiang...   Bus Tours
# 4        Authentic Local Food Tour in Central Shanghai  City Tours
# ..                                                 ...         ...
# 287  Shanghai Pudong International Airport (PVG) Pr...         NaN
# 288  Transfer in Private Minivan from Shanghai Hong...         NaN
# 289  Private Tour of Zhujiajiao Ancient Water Town ...   Bus Tours
# 290  2-Day Beijing Private Tour from Shanghai by Fl...   Bus Tours
# 291                                                NaN           1
#
#      Tour Duration Tour Price  Price Per       Cancellation  \
# 0              NaN        NaN        NaN                NaN
# 1          5 hours    $176.50  per adult  Free cancellation
# 2        4–5 hours    $134.50  per adult  Free cancellation
# 3          3 hours    $138.00  per adult  Free cancellation
# 4          3 hours     $67.00  per adult  Free cancellation
# ..             ...        ...        ...                ...
# 287  30–60 minutes     $37.34  per adult  Free cancellation
# 288     30 minutes     $56.67  per adult  Free cancellation
# 289      6–7 hours    $165.34  per adult  Free cancellation
# 290         2 days    $850.00  per adult  Free cancellation
# 291             11        NaN        NaN                 13
#
#                       Tour By      City Country  \
# 0           Clear all filters  Shanghai   China
# 1    By Amazing Shanghai Trip  Shanghai   China
# 2    By Amazing Shanghai Trip  Shanghai   China
# 3    By Amazing Shanghai Trip  Shanghai   China
# 4          By Shanghai Foodie  Shanghai   China
# ..                        ...       ...     ...
# 287     By IslamiChina Travel  Shanghai   China
# 288      By MY TRANSFER GROUP  Shanghai   China
# 289   By Sunny Tours Shanghai  Shanghai   China
# 290        By China Xian Tour  Shanghai   China
# 291                       NaN  Shanghai   China
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3    https://www.tripadvisor.com/Attraction_Review-...
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 287  https://www.tripadvisor.com/Attraction_Review-...
# 288  https://www.tripadvisor.com/Attraction_Review-...
# 289  https://www.tripadvisor.com/Attraction_Review-...
# 290  https://www.tripadvisor.com/Attraction_Review-...
# 291                                                NaN
#
# [292 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tour Name      271 non-null    object
#  1   Tour Type      231 non-null    object
#  2   Tour Duration  281 non-null    object
#  3   Tour Price     272 non-null    object
#  4   Price Per      271 non-null    object
#  5   Cancellation   272 non-null    object
#  6   Tour By        274 non-null    object
#  7   City           292 non-null    object
#  8   Country        292 non-null    object
#  9   Link           265 non-null    object
# dtypes: object(10)
# memory usage: 22.9+ KB

# %% [markdown]
# **For the Cleaning:**
#
# - type: REMOVE other
# - duration: REMOVE other
# - canel: REMOVE other
# - price:$ --> float

# %%
# Store the clean dataset
df.to_csv('Shanghaiclean.csv')
