# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Tokyo.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'WlYyy 4',
#        'WlYyy 5', 'ySnDE', 'ccVGl', 'WlYyy 7', 'ccVGl 2', 'WlYyy 8'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  1,000+ places sorted by traveler favorites
# 1                                          37
# 2                                          14
# 3                                          16
# 4                                          55
#
#                                                cctrW                  iPqaD  \
# 0  Tours, activities and experiences bookable on ...      Clear all filters
# 1  This number is based on the percentage of all ...            By Dokotrip
# 2  This number is based on the percentage of all ...  By Japan Guide Agency
# 3                                                NaN     By Sanrio Puroland
# 4  This number is based on the percentage of all ...   By Tokyo Grand Tours
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=R...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# ...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         431 non-null    object
#  1   cctrW         126 non-null    object
#  2   iPqaD         590 non-null    object
#  3   iPqaD href    405 non-null    object
#  4   FmrIP href    575 non-null    object
#  5   dugSS src     574 non-null    object
#  6   bUshh         575 non-null    object
#  7   cIVmB         575 non-null    float64
#  8   iPqaD href 2  571 non-null    object
#  9   WlYyy 2       523 non-null    object
#  10  WlYyy 3       596 non-null    object
#  11  WlYyy 4       546 non-null    object
#  12  WlYyy 5       271 non-null    object
#  13  ySnDE         571 non-null    object
#  14  ccVGl         575 non-null    object
#  15  WlYyy 7       576 non-null    object
#  16  ccVGl 2       575 non-null    object
#  17  WlYyy 8       576 non-null    object
# ...

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href',  'cIVmB',  'ccVGl','WlYyy 4','ySnDE', 'ccVGl','WlYyy 8'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 5':'Cancellation', 'WlYyy 7':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Tokyo'
df['Country'] = 'Japan'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 25

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
#                          Tour By  \
# 0              Clear all filters
# 1                    By Dokotrip
# 2          By Japan Guide Agency
# 3             By Sanrio Puroland
# 4           By Tokyo Grand Tours
# ..                           ...
# 611          By True Japan Tours
# 612               By TOKYO SHAMI
# 613                    By Sayuki
# 614  By eight one management co.
# 615                          NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# ...

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image             42
# Tour Name         41
# Tour Type         93
# Tour Duration     20
# Tour Price        40
# Price Per         41
# Cancellation     345
# Tour By           26
# City               0
# Country            0
# Link              45
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 611  https://dynamic-media-cdn.tripadvisor.com/medi...
# 612  https://dynamic-media-cdn.tripadvisor.com/medi...
# 613  https://dynamic-media-cdn.tripadvisor.com/medi...
# 614  https://dynamic-media-cdn.tripadvisor.com/medi...
# 615                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    1 Day Private Mt Fuji Tour (Charter) - English...
# 2    Tokyo Full-Day Private Tour with Nationally-Li...
# 3    Direct to Gate: Sanrio Puroland Advance Passpo...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          574 non-null    object
#  1   Tour Name      575 non-null    object
#  2   Tour Type      523 non-null    object
#  3   Tour Duration  596 non-null    object
#  4   Tour Price     576 non-null    object
#  5   Price Per      575 non-null    object
#  6   Cancellation   271 non-null    object
#  7   Tour By        590 non-null    object
#  8   City           616 non-null    object
#  9   Country        616 non-null    object
#  10  Link           571 non-null    object
# dtypes: object(11)
# memory usage: 53.1+ KB

# %%
# Store the clean dataset
df.to_csv('Tokyoclean.csv')
