# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Rome.csv')

# %%
messy_df.columns
# Out:
# Index(['cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src', 'bUshh',
#        'cIVmB', 'WlYyy 2', 'iPqaD href 2', 'WlYyy 3', 'WlYyy 4', 'WlYyy 5',
#        'WlYyy 6', 'WlYyy 7', 'ySnDE', 'ccVGl', 'WlYyy 8', 'ccVGl 2',
#        'WlYyy 9'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                                cctrW                  iPqaD  \
# 0  Tours, activities and experiences bookable on ...      Clear all filters
# 1  This number is based on the percentage of all ...  By Made in Rome Tours
# 2  This number is based on the percentage of all ...        By City Wonders
# 3  This number is based on the percentage of all ...             By Touriks
# 4  This number is based on the percentage of all ...      By LivItaly Tours
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=e...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# ...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2366 entries, 0 to 2365
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cctrW         661 non-null    object
#  1   iPqaD         2282 non-null   object
#  2   iPqaD href    1811 non-null   object
#  3   FmrIP href    2212 non-null   object
#  4   dugSS src     2205 non-null   object
#  5   bUshh         2212 non-null   object
#  6   cIVmB         2212 non-null   float64
#  7   WlYyy 2       1823 non-null   object
#  8   iPqaD href 2  2211 non-null   object
#  9   WlYyy 3       2057 non-null   object
#  10  WlYyy 4       2292 non-null   object
#  11  WlYyy 5       2172 non-null   object
#  12  WlYyy 6       1684 non-null   object
#  13  WlYyy 7       591 non-null    object
#  14  ySnDE         2195 non-null   object
#  15  ccVGl         2212 non-null   object
#  16  WlYyy 8       2213 non-null   object
#  17  ccVGl 2       2212 non-null   object
# ...

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['cctrW','iPqaD href', 'FmrIP href',  'cIVmB', 'WlYyy 2', 'ccVGl', 'WlYyy 5', 'WlYyy 7','ySnDE', 'ccVGl','WlYyy 9'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 3':'Tour Type', 'WlYyy 4':'Tour Duration', 'WlYyy 6':'Cancellation', 'WlYyy 8':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Rome'
df['Country'] = 'Italy'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 154

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                     Tour By  \
# 0         Clear all filters
# 1     By Made in Rome Tours
# 2           By City Wonders
# 3                By Touriks
# 4         By LivItaly Tours
# ...                     ...
# 2361       By Easitalytours
# 2362    By Roma Travel Tour
# 2363    By Roma Travel Tour
# 2364       By Maximus Tours
# 2365                    NaN
#
#                                                   Image  \
# 0                                                   NaN
# 1     https://dynamic-media-cdn.tripadvisor.com/medi...
# 2     https://dynamic-media-cdn.tripadvisor.com/medi...
# 3     https://dynamic-media-cdn.tripadvisor.com/medi...
# 4     https://dynamic-media-cdn.tripadvisor.com/medi...
# ...                                                 ...
# 2361  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2362  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2363  https://dynamic-media-cdn.tripadvisor.com/medi...
# ...

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image            161
# Tour Name        154
# Tour Type        309
# Tour Duration     74
# Tour Price       153
# Price Per        154
# Cancellation     682
# Tour By           84
# City               0
# Country            0
# Link             155
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                   Image  \
# 0                                                   NaN
# 1     https://dynamic-media-cdn.tripadvisor.com/medi...
# 2     https://dynamic-media-cdn.tripadvisor.com/medi...
# 3     https://dynamic-media-cdn.tripadvisor.com/medi...
# 4     https://dynamic-media-cdn.tripadvisor.com/medi...
# ...                                                 ...
# 2361  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2362  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2363  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2364  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2365                                                NaN
#
#                                               Tour Name            Tour Type  \
# 0                                                   NaN                  NaN
# 1     Skip-the-Line Group Tour of the Vatican, Sisti...  Skip-the-Line Tours
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2366 entries, 0 to 2365
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          2205 non-null   object
#  1   Tour Name      2212 non-null   object
#  2   Tour Type      2057 non-null   object
#  3   Tour Duration  2292 non-null   object
#  4   Tour Price     2213 non-null   object
#  5   Price Per      2212 non-null   object
#  6   Cancellation   1684 non-null   object
#  7   Tour By        2282 non-null   object
#  8   City           2366 non-null   object
#  9   Country        2366 non-null   object
#  10  Link           2211 non-null   object
# dtypes: object(11)
# memory usage: 203.5+ KB

# %%
# Store the clean dataset
df.to_csv('Romeclean.csv')
