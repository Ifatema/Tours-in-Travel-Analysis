# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Mumbai.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 6', 'ccVGl 2',
#        'WlYyy 7', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                      WlYyy  \
# 0  791 places sorted by traveler favorites
# 1                                      215
# 2                                       29
# 3                                       61
# 4                                       58
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3  Not sure? You can cancel this reservation up t...
# 4  Not sure? You can cancel this reservation up t...
#
#                          iPqaD  \
# 0            Clear all filters
# 1      By Magical Mumbai Tours
# 2    By Bombay to Mumbai Tours
# 3  By Reality Tours and Travel
# 4           By Mystical Mumbai
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=U...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1             5-Hour Private Mumbai Sightseeing Tour    1.0
# 2  Elephanta Tour with Mumbai Sightseeing Includi...    2.0
# 3                            Mumbai Street Food Tour    3.0
# 4  Mumbai Elephanta Caves Private Half-Day Tour i...    4.0
#
#                                         iPqaD href 2              WlYyy 2  \
# 0                                                NaN                  NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...            Bus Tours
# 2  https://www.tripadvisor.com/Attraction_Review-...            Bus Tours
# 3  https://www.tripadvisor.com/Attraction_Review-...            Bus Tours
# 4  https://www.tripadvisor.com/Attraction_Review-...  Ports of Call Tours
#
#      WlYyy 3                                              ySnDE  \
# 0        NaN                                                NaN
# 1    5 hours  Our guide & driver will pick you up from your ...
# 2  7–8 hours  Mumbai is considered among India’s must-see ci...
# 3  3–4 hours  Mumbai (Bombay) is a city best experienced thr...
# 4    4 hours  Visit the Elephanta Caves on this 4-hour tour....
#
#              WlYyy 4                                      WlYyy 5  \
# 0                NaN                                          NaN
# 1  Free cancellation   95% of travelers recommend this experience
# 2  Free cancellation  100% of travelers recommend this experience
# 3  Free cancellation   95% of travelers recommend this experience
# 4  Free cancellation   93% of travelers recommend this experience
#
#                                              cctrW 2 ccVGl  WlYyy 6  \
# 0                                                NaN   NaN      NaN
# 1  This number is based on the percentage of all ...  from   $54.71
# 2  This number is based on the percentage of all ...  from  $165.67
# 3  This number is based on the percentage of all ...  from   $41.03
# 4  This number is based on the percentage of all ...  from   $65.00
#
#      ccVGl 2    WlYyy 7 dXxty
# 0        NaN        NaN   NaN
# 1  per adult  More info   NaN
# 2  per adult  More info   NaN
# 3  per adult  More info   NaN
# 4  per adult  More info   NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.<class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         223 non-null    object
#  1   cctrW         212 non-null    object
#  2   iPqaD         221 non-null    object
#  3   iPqaD href    213 non-null    object
#  4   FmrIP href    216 non-null    object
#  5   dugSS src     216 non-null    object
#  6   bUshh         216 non-null    object
#  7   cIVmB         216 non-null    float64
#  8   iPqaD href 2  214 non-null    object
#  9   WlYyy 2       213 non-null    object
#  10  WlYyy 3       224 non-null    object
#  11  ySnDE         216 non-null    object
#  12  WlYyy 4       213 non-null    object
#  13  WlYyy 5       67 non-null     object
#  14  cctrW 2       63 non-null     object
#  15  ccVGl         216 non-null    object
#  16  WlYyy 6       217 non-null    object
#  17  ccVGl 2       216 non-null    object
#  18  WlYyy 7       217 non-null    object
#  19  dXxty         72 non-null     object
# dtypes: float64(1), object(19)
# memory usage: 36.5+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'cIVmB','ySnDE', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 7', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Mumbai'
df['Country'] = 'India'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 12

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                          Tour By  \
# 0              Clear all filters
# 1        By Magical Mumbai Tours
# 2      By Bombay to Mumbai Tours
# 3    By Reality Tours and Travel
# 4             By Mystical Mumbai
# ..                           ...
# 228         By India Magic Tours
# 229            By Dynamic Mumbai
# 230      By Namaste Tours Mumbai
# 231                 By SNK Tours
# 232                          NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 228  https://dynamic-media-cdn.tripadvisor.com/medi...
# 229  https://dynamic-media-cdn.tripadvisor.com/medi...
# 230  https://dynamic-media-cdn.tripadvisor.com/medi...
# 231  https://dynamic-media-cdn.tripadvisor.com/medi...
# 232                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1               5-Hour Private Mumbai Sightseeing Tour
# 2    Elephanta Tour with Mumbai Sightseeing Includi...
# 3                              Mumbai Street Food Tour
# 4    Mumbai Elephanta Caves Private Half-Day Tour i...
# ..                                                 ...
# 228                                     Mumbai by Dawn
# 229                               Mumbai on Motor Bike
# 230            City Tour plus slum Tours Mumbai by car
# 231                Mumbai City Tour 8 Hours - 4 Person
# 232                                                NaN
#
#                                                   Link            Tour Type  \
# 0                                                  NaN                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...            Bus Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...            Bus Tours
# 3    https://www.tripadvisor.com/Attraction_Review-...            Bus Tours
# 4    https://www.tripadvisor.com/Attraction_Review-...  Ports of Call Tours
# ..                                                 ...                  ...
# 228  https://www.tripadvisor.com/Attraction_Review-...            Bus Tours
# 229  https://www.tripadvisor.com/Attraction_Review-...   Private and Luxury
# 230  https://www.tripadvisor.com/Attraction_Review-...           Rail Tours
# 231  https://www.tripadvisor.com/Attraction_Review-...       Full-day Tours
# 232                                                NaN                    1
#
#     Tour Duration       Cancellation Tour Price  Price Per    City Country
# 0             NaN                NaN        NaN        NaN  Mumbai   India
# 1         5 hours  Free cancellation     $54.71  per adult  Mumbai   India
# 2       7–8 hours  Free cancellation    $165.67  per adult  Mumbai   India
# 3       3–4 hours  Free cancellation     $41.03  per adult  Mumbai   India
# 4         4 hours  Free cancellation     $65.00  per adult  Mumbai   India
# ..            ...                ...        ...        ...     ...     ...
# 228     3–4 hours  Free cancellation     $40.00  per adult  Mumbai   India
# 229     4–5 hours  Free cancellation     $87.53  per adult  Mumbai   India
# 230     3–6 hours                NaN    $156.00  per adult  Mumbai   India
# 231      6+ hours                NaN    $213.34  per group  Mumbai   India
# 232             8                 10        NaN        NaN  Mumbai   India
#
# [221 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image            17
# Tour Name        17
# Tour Type        20
# Tour Duration     9
# Tour Price       16
# Price Per        17
# Cancellation     20
# Tour By          12
# City              0
# Country           0
# Link             19
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 228  https://dynamic-media-cdn.tripadvisor.com/medi...
# 229  https://dynamic-media-cdn.tripadvisor.com/medi...
# 230  https://dynamic-media-cdn.tripadvisor.com/medi...
# 231  https://dynamic-media-cdn.tripadvisor.com/medi...
# 232                                                NaN
#
#                                              Tour Name            Tour Type  \
# 0                                                  NaN                  NaN
# 1               5-Hour Private Mumbai Sightseeing Tour            Bus Tours
# 2    Elephanta Tour with Mumbai Sightseeing Includi...            Bus Tours
# 3                              Mumbai Street Food Tour            Bus Tours
# 4    Mumbai Elephanta Caves Private Half-Day Tour i...  Ports of Call Tours
# ..                                                 ...                  ...
# 228                                     Mumbai by Dawn            Bus Tours
# 229                               Mumbai on Motor Bike   Private and Luxury
# 230            City Tour plus slum Tours Mumbai by car           Rail Tours
# 231                Mumbai City Tour 8 Hours - 4 Person       Full-day Tours
# 232                                                NaN                    1
#
#     Tour Duration Tour Price  Price Per       Cancellation  \
# 0             NaN        NaN        NaN                NaN
# 1         5 hours     $54.71  per adult  Free cancellation
# 2       7–8 hours    $165.67  per adult  Free cancellation
# 3       3–4 hours     $41.03  per adult  Free cancellation
# 4         4 hours     $65.00  per adult  Free cancellation
# ..            ...        ...        ...                ...
# 228     3–4 hours     $40.00  per adult  Free cancellation
# 229     4–5 hours     $87.53  per adult  Free cancellation
# 230     3–6 hours    $156.00  per adult                NaN
# 231      6+ hours    $213.34  per group                NaN
# 232             8        NaN        NaN                 10
#
#                          Tour By    City Country  \
# 0              Clear all filters  Mumbai   India
# 1        By Magical Mumbai Tours  Mumbai   India
# 2      By Bombay to Mumbai Tours  Mumbai   India
# 3    By Reality Tours and Travel  Mumbai   India
# 4             By Mystical Mumbai  Mumbai   India
# ..                           ...     ...     ...
# 228         By India Magic Tours  Mumbai   India
# 229            By Dynamic Mumbai  Mumbai   India
# 230      By Namaste Tours Mumbai  Mumbai   India
# 231                 By SNK Tours  Mumbai   India
# 232                          NaN  Mumbai   India
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3    https://www.tripadvisor.com/Attraction_Review-...
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 228  https://www.tripadvisor.com/Attraction_Review-...
# 229  https://www.tripadvisor.com/Attraction_Review-...
# 230  https://www.tripadvisor.com/Attraction_Review-...
# 231  https://www.tripadvisor.com/Attraction_Review-...
# 232                                                NaN
#
# [233 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          216 non-null    object
#  1   Tour Name      216 non-null    object
#  2   Tour Type      213 non-null    object
#  3   Tour Duration  224 non-null    object
#  4   Tour Price     217 non-null    object
#  5   Price Per      216 non-null    object
#  6   Cancellation   213 non-null    object
#  7   Tour By        221 non-null    object
#  8   City           233 non-null    object
#  9   Country        233 non-null    object
#  10  Link           214 non-null    object
# dtypes: object(11)
# memory usage: 20.1+ KB

# %%
# Store the clean dataset
df.to_csv('Mumbaiclean.csv')
