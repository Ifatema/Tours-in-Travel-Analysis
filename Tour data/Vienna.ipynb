# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Vienna.csv')

# %%
messy_df.columns
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# Index(['WlYyy', 'cctrW', 'iPqaD', 'FmrIP href', 'dugSS src', 'bUshh', 'cIVmB',
#        'iPqaD href 2', 'iPqaD href 3', 'WlYyy 2', 'WlYyy 3', 'WlYyy 4',
#        'WlYyy 5', 'WlYyy 6', 'ySnDE', 'ccVGl', 'WlYyy 7', 'ccVGl 2',
#        'WlYyy 8'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                                WlYyy  \
# 0            707 places sorted by traveler favorites
# 1                                                179
# 2                                                102
# 3  Book risk-free with free cancellations on most...
# 4                                                 25
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  This number is based on the percentage of all ...
# 2  This number is based on the percentage of all ...
# 3                                                NaN
# 4  This number is based on the percentage of all ...
#
#                               iPqaD  \
# 0                 Clear all filters
# 1  By Concerts in St. Anne’s Church
# 2        By Classic Ensemble Vienna
# 3                               NaN
# 4     By Concerts at the Mozarthaus
#
#                                           FmrIP href  \
# ...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         235 non-null    object
#  1   cctrW         78 non-null     object
#  2   iPqaD         253 non-null    object
#  3   FmrIP href    245 non-null    object
#  4   dugSS src     244 non-null    object
#  5   bUshh         245 non-null    object
#  6   cIVmB         245 non-null    float64
#  7   iPqaD href 2  216 non-null    object
#  8   iPqaD href 3  245 non-null    object
#  9   WlYyy 2       236 non-null    object
#  10  WlYyy 3       254 non-null    object
#  11  WlYyy 4       251 non-null    object
#  12  WlYyy 5       155 non-null    object
#  13  WlYyy 6       75 non-null     object
#  14  ySnDE         242 non-null    object
#  15  ccVGl         245 non-null    object
#  16  WlYyy 7       246 non-null    object
#  17  ccVGl 2       245 non-null    object
# ...

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW', 'FmrIP href',  'cIVmB','iPqaD href 2', 'WlYyy 4', 'WlYyy 6', 'ySnDE','ccVGl','WlYyy 8'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 3':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 5':'Cancellation', 'WlYyy 7':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Vienna'
df['Country'] = 'Austria'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 13

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                               Tour By  \
# 0                   Clear all filters
# 1    By Concerts in St. Anne’s Church
# 2          By Classic Ensemble Vienna
# 3                                 NaN
# 4       By Concerts at the Mozarthaus
# ..                                ...
# 254             By Tobias Steinmaurer
# 255      By Rosotravel - Vienna Tours
# 256                 By Gems of Vienna
# 257                               NaN
# 263                               NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 254  https://dynamic-media-cdn.tripadvisor.com/medi...
# ...

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image             20
# Tour Name         19
# Tour Type         28
# Tour Duration     10
# Tour Price        18
# Price Per         19
# Cancellation     109
# Tour By           11
# City               0
# Country            0
# Link              19
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 259  https://dynamic-media-cdn.tripadvisor.com/medi...
# 260  https://dynamic-media-cdn.tripadvisor.com/medi...
# 261  https://dynamic-media-cdn.tripadvisor.com/medi...
# 262  https://dynamic-media-cdn.tripadvisor.com/medi...
# 263                                                NaN
#
#                                              Tour Name           Tour Type  \
# 0                                                  NaN                 NaN
# 1    Concert in St. Anne's Church in Vienna: Mozart...  Classical Concerts
# 2       Vienna Classical Concert at St. Peter’s Church  Classical Concerts
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          244 non-null    object
#  1   Tour Name      245 non-null    object
#  2   Tour Type      236 non-null    object
#  3   Tour Duration  254 non-null    object
#  4   Tour Price     246 non-null    object
#  5   Price Per      245 non-null    object
#  6   Cancellation   155 non-null    object
#  7   Tour By        253 non-null    object
#  8   City           264 non-null    object
#  9   Country        264 non-null    object
#  10  Link           245 non-null    object
# dtypes: object(11)
# memory usage: 22.8+ KB

# %%
# Store the clean dataset
df.to_csv('Viennaclean.csv')
