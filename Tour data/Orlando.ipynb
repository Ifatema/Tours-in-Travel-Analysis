# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Orlando.csv')

# %%
messy_df.columns
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'ccVGl', 'WlYyy 6', 'ccVGl 2', 'WlYyy 7', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                                WlYyy  \
# 0            540 places sorted by traveler favorites
# 1                                                441
# 2                                                 40
# 3  Book risk-free with free cancellations on most...
# 4                                                142
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3                                                NaN
# 4  Not sure? You can cancel this reservation up t...
#
#                          iPqaD  \
# 0            Clear all filters
# 1   By Real Florida Adventures
# 2     By MaxFlight Helicopters
# 3                          NaN
# 4  By City Sightseeing Orlando
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=M...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3                                                NaN
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3                                                NaN
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                NaN
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1  Florida Manatee Adventure, Everglades Style Ai...    1.0
# 2  Private Helicopter Tour over Orlando's Theme P...    2.0
# 3                                                NaN    NaN
# 4  Kennedy Space Center Day Trip with Transport f...    3.0
#
#                                         iPqaD href 2          WlYyy 2  \
# 0                                                NaN              NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
# 2  https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 3                                                NaN       Cold feet?
# 4  https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
#
#         WlYyy 3                                              ySnDE  \
# 0           NaN                                                NaN
# 1      6+ hours  Get ready for a slam packed fun filled day on ...
# 2  8–60 minutes  Take an 8-10, 18-20, 25-30 minute or 1 hour he...
# 3           NaN                                                NaN
# 4      6+ hours  Take a virtual flight to the moon and back at ...
#
#              WlYyy 4 ccVGl  WlYyy 6    ccVGl 2    WlYyy 7 dXxty
# 0                NaN   NaN      NaN        NaN        NaN   NaN
# 1  Free cancellation  from  $138.98  per adult  More info   NaN
# 2  Free cancellation  from   $65.00  per adult  More info   NaN
# 3                NaN   NaN      NaN        NaN        NaN   NaN
# 4  Free cancellation  from   $64.99  per adult  More info   NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483 entries, 0 to 482
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         168 non-null    object
#  1   cctrW         440 non-null    object
#  2   iPqaD         462 non-null    object
#  3   iPqaD href    149 non-null    object
#  4   FmrIP href    450 non-null    object
#  5   dugSS src     445 non-null    object
#  6   bUshh         450 non-null    object
#  7   cIVmB         450 non-null    float64
#  8   iPqaD href 2  447 non-null    object
#  9   WlYyy 2       143 non-null    object
#  10  WlYyy 3       466 non-null    object
#  11  ySnDE         440 non-null    object
#  12  WlYyy 4       439 non-null    object
#  13  ccVGl         450 non-null    object
#  14  WlYyy 6       451 non-null    object
#  15  ccVGl 2       450 non-null    object
#  16  WlYyy 7       451 non-null    object
#  17  dXxty         180 non-null    object
# dtypes: float64(1), object(17)
# memory usage: 68.0+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'cIVmB', 'ySnDE',  'ccVGl', 'WlYyy 7', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Orlando'
df['Country'] = 'USA'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 15

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                                Tour By  \
# 0                                    Clear all filters
# 1                           By Real Florida Adventures
# 2                             By MaxFlight Helicopters
# 3                                                  NaN
# 4                          By City Sightseeing Orlando
# ..                                                 ...
# 478  By MCO Luxury Transportation  Orlando & Centra...
# 479  By Orlando International Airport One Way Transfer
# 480                        By Cloud of Goods - Orlando
# 481                                      By Elife Limo
# 482                                                NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 478  https://dynamic-media-cdn.tripadvisor.com/medi...
# 479  https://dynamic-media-cdn.tripadvisor.com/medi...
# 480  https://dynamic-media-cdn.tripadvisor.com/medi...
# 481  https://dynamic-media-cdn.tripadvisor.com/medi...
# 482                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    Florida Manatee Adventure, Everglades Style Ai...
# 2    Private Helicopter Tour over Orlando's Theme P...
# 3                                                  NaN
# 4    Kennedy Space Center Day Trip with Transport f...
# ..                                                 ...
# 478  Transfer Big Group to Port Canaveral Up to 28 ...
# 479  Orlando Sanford International Airport One Way ...
# 480        Orlando Lightweight Mobility Scooter Rental
# 481  Private Round-Trip Transfer In Orlando Interna...
# 482                                                NaN
#
#                                                   Link        Tour Type  \
# 0                                                  NaN              NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 3                                                  NaN       Cold feet?
# 4    https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
# ..                                                 ...              ...
# 478  https://www.tripadvisor.com/Attraction_Review-...              NaN
# 479  https://www.tripadvisor.com/Attraction_Review-...              NaN
# 480  https://www.tripadvisor.com/Attraction_Review-...          Rentals
# 481  https://www.tripadvisor.com/Attraction_Review-...              NaN
# 482                                                NaN                1
#
#      Tour Duration       Cancellation Tour Price  Price Per     City Country
# 0              NaN                NaN        NaN        NaN  Orlando     USA
# 1         6+ hours  Free cancellation    $138.98  per adult  Orlando     USA
# 2     8–60 minutes  Free cancellation     $65.00  per adult  Orlando     USA
# 3              NaN                NaN        NaN        NaN  Orlando     USA
# 4         6+ hours  Free cancellation     $64.99  per adult  Orlando     USA
# ..             ...                ...        ...        ...      ...     ...
# 478        2 hours  Free cancellation    $380.00  per group  Orlando     USA
# 479         1 hour  Free cancellation     $99.00  per group  Orlando     USA
# 480      1–14 days  Free cancellation     $41.03  per adult  Orlando     USA
# 481  30–60 minutes  Free cancellation    $119.00  per group  Orlando     USA
# 482             17                NaN        NaN        NaN  Orlando     USA
#
# [468 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image             38
# Tour Name         33
# Tour Type        340
# Tour Duration     17
# Tour Price        32
# Price Per         33
# Cancellation      44
# Tour By           21
# City               0
# Country            0
# Link              36
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 478  https://dynamic-media-cdn.tripadvisor.com/medi...
# 479  https://dynamic-media-cdn.tripadvisor.com/medi...
# 480  https://dynamic-media-cdn.tripadvisor.com/medi...
# 481  https://dynamic-media-cdn.tripadvisor.com/medi...
# 482                                                NaN
#
#                                              Tour Name        Tour Type  \
# 0                                                  NaN              NaN
# 1    Florida Manatee Adventure, Everglades Style Ai...        Bus Tours
# 2    Private Helicopter Tour over Orlando's Theme P...  Adventure Tours
# 3                                                  NaN       Cold feet?
# 4    Kennedy Space Center Day Trip with Transport f...        Bus Tours
# ..                                                 ...              ...
# 478  Transfer Big Group to Port Canaveral Up to 28 ...              NaN
# 479  Orlando Sanford International Airport One Way ...              NaN
# 480        Orlando Lightweight Mobility Scooter Rental          Rentals
# 481  Private Round-Trip Transfer In Orlando Interna...              NaN
# 482                                                NaN                1
#
#      Tour Duration Tour Price  Price Per       Cancellation  \
# 0              NaN        NaN        NaN                NaN
# 1         6+ hours    $138.98  per adult  Free cancellation
# 2     8–60 minutes     $65.00  per adult  Free cancellation
# 3              NaN        NaN        NaN                NaN
# 4         6+ hours     $64.99  per adult  Free cancellation
# ..             ...        ...        ...                ...
# 478        2 hours    $380.00  per group  Free cancellation
# 479         1 hour     $99.00  per group  Free cancellation
# 480      1–14 days     $41.03  per adult  Free cancellation
# 481  30–60 minutes    $119.00  per group  Free cancellation
# 482             17        NaN        NaN                NaN
#
#                                                Tour By     City Country  \
# 0                                    Clear all filters  Orlando     USA
# 1                           By Real Florida Adventures  Orlando     USA
# 2                             By MaxFlight Helicopters  Orlando     USA
# 3                                                  NaN  Orlando     USA
# 4                          By City Sightseeing Orlando  Orlando     USA
# ..                                                 ...      ...     ...
# 478  By MCO Luxury Transportation  Orlando & Centra...  Orlando     USA
# 479  By Orlando International Airport One Way Transfer  Orlando     USA
# 480                        By Cloud of Goods - Orlando  Orlando     USA
# 481                                      By Elife Limo  Orlando     USA
# 482                                                NaN  Orlando     USA
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3                                                  NaN
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 478  https://www.tripadvisor.com/Attraction_Review-...
# 479  https://www.tripadvisor.com/Attraction_Review-...
# 480  https://www.tripadvisor.com/Attraction_Review-...
# 481  https://www.tripadvisor.com/Attraction_Review-...
# 482                                                NaN
#
# [483 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 483 entries, 0 to 482
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          445 non-null    object
#  1   Tour Name      450 non-null    object
#  2   Tour Type      143 non-null    object
#  3   Tour Duration  466 non-null    object
#  4   Tour Price     451 non-null    object
#  5   Price Per      450 non-null    object
#  6   Cancellation   439 non-null    object
#  7   Tour By        462 non-null    object
#  8   City           483 non-null    object
#  9   Country        483 non-null    object
#  10  Link           447 non-null    object
# dtypes: object(11)
# memory usage: 41.6+ KB

# %%
# Store the clean dataset
df.to_csv('Orlandoclean.csv')
