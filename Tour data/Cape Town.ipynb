# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Cape Town.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 6', 'ccVGl 2',
#        'WlYyy 7', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  1,000+ places sorted by traveler favorites
# 1                                          13
# 2                                         231
# 3                                         130
# 4                                         104
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3  Not sure? You can cancel this reservation up t...
# 4  Not sure? You can cancel this reservation up t...
#
#                                                iPqaD  \
# 0                                  Clear all filters
# 1  By BokBus Garden Route Adventure Tours - Day T...
# 2                                 By Marine Dynamics
# 3                             By Kabura Travel Tours
# 4                             By Cape Archives Tours
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=b...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1             2 Day Safari Experience from Cape Town    1.0
# 2       Shark Cage Diving and Viewing from Cape Town    2.0
# 3  Cape of Good Hope-Cape Point & Penguins Privat...    3.0
# 4  Cape of Good Hope and Penguins Full-Day Tour F...    4.0
#
#                                         iPqaD href 2          WlYyy 2  \
# 0                                                NaN              NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 2  https://www.tripadvisor.com/Attraction_Review-...              NaN
# 3  https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
# 4  https://www.tripadvisor.com/Attraction_Review-...        Car Tours
#
#     WlYyy 3                                              ySnDE  \
# 0       NaN                                                NaN
# 1    2 days  An absolute highlight from Cape Town! This 2 d...
# 2   4 hours  You may think you’re a fear-defying thrill lov...
# 3  6+ hours  Join us on a Full Day Cape Peninsula Private T...
# 4  6+ hours  Traverse the Cape peninsular in a small group ...
#
#              WlYyy 4                                     WlYyy 5  \
# 0                NaN                                         NaN
# 1  Free cancellation  92% of travelers recommend this experience
# 2  Free cancellation                                         NaN
# 3  Free cancellation  95% of travelers recommend this experience
# 4  Free cancellation  99% of travelers recommend this experience
#
#                                              cctrW 2 ccVGl  WlYyy 6  \
# 0                                                NaN   NaN      NaN
# 1  This number is based on the percentage of all ...  from  $367.88
# 2                                                NaN  from  $218.82
# 3  This number is based on the percentage of all ...  from  $120.83
# 4  This number is based on the percentage of all ...  from   $44.45
#
#      ccVGl 2    WlYyy 7                   dXxty
# 0        NaN        NaN                     NaN
# 1  per adult  More info                     NaN
# 2  per adult  More info  Taking safety measures
# 3  per adult  More info                     NaN
# 4  per adult  More info                     NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         393 non-null    object
#  1   cctrW         427 non-null    object
#  2   iPqaD         469 non-null    object
#  3   iPqaD href    375 non-null    object
#  4   FmrIP href    455 non-null    object
#  5   dugSS src     454 non-null    object
#  6   bUshh         455 non-null    object
#  7   cIVmB         455 non-null    float64
#  8   iPqaD href 2  454 non-null    object
#  9   WlYyy 2       396 non-null    object
#  10  WlYyy 3       472 non-null    object
#  11  ySnDE         449 non-null    object
#  12  WlYyy 4       428 non-null    object
#  13  WlYyy 5       146 non-null    object
#  14  cctrW 2       139 non-null    object
#  15  ccVGl         455 non-null    object
#  16  WlYyy 6       456 non-null    object
#  17  ccVGl 2       455 non-null    object
#  18  WlYyy 7       456 non-null    object
#  19  dXxty         244 non-null    object
# dtypes: float64(1), object(19)
# memory usage: 76.4+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy','cctrW','iPqaD href', 'FmrIP href','cIVmB','ySnDE', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 7', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Cape Town'
df['Country'] = 'South Africa'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 19

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                                Tour By  \
# 0                                    Clear all filters
# 1    By BokBus Garden Route Adventure Tours - Day T...
# 2                                   By Marine Dynamics
# 3                               By Kabura Travel Tours
# 4                               By Cape Archives Tours
# ..                                                 ...
# 483                                By Cape Falls Tours
# 484                                 By Local Knowledge
# 485                             By Baz Bus - Day Tours
# 486                           By Morkel Travel & Tours
# 487                                                NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 483  https://dynamic-media-cdn.tripadvisor.com/medi...
# 484  https://dynamic-media-cdn.tripadvisor.com/medi...
# 485  https://dynamic-media-cdn.tripadvisor.com/medi...
# 486  https://dynamic-media-cdn.tripadvisor.com/medi...
# 487                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1               2 Day Safari Experience from Cape Town
# 2         Shark Cage Diving and Viewing from Cape Town
# 3    Cape of Good Hope-Cape Point & Penguins Privat...
# 4    Cape of Good Hope and Penguins Full-Day Tour F...
# ..                                                 ...
# 483  Cape Town International Airport Transfers to a...
# 484       Peninsula Vibes: Boulders Beach & Cape Point
# 485               Table Mountain Hike with Local Guide
# 486                              Township Private Tour
# 487                                                NaN
#
#                                                   Link        Tour Type  \
# 0                                                  NaN              NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...              NaN
# 3    https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
# 4    https://www.tripadvisor.com/Attraction_Review-...        Car Tours
# ..                                                 ...              ...
# 483  https://www.tripadvisor.com/Attraction_Review-...              NaN
# 484  https://www.tripadvisor.com/Attraction_Review-...   Full-day Tours
# 485  https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 486  https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
# 487                                                NaN                1
#
#      Tour Duration       Cancellation Tour Price  Price Per       City  \
# 0              NaN                NaN        NaN        NaN  Cape Town
# 1           2 days  Free cancellation    $367.88  per adult  Cape Town
# 2          4 hours  Free cancellation    $218.82  per adult  Cape Town
# 3         6+ hours  Free cancellation    $120.83  per adult  Cape Town
# 4         6+ hours  Free cancellation     $44.45  per adult  Cape Town
# ..             ...                ...        ...        ...        ...
# 483  20–45 minutes  Free cancellation     $15.39  per adult  Cape Town
# 484      8–9 hours  Free cancellation    $109.41  per adult  Cape Town
# 485      2–6 hours  Free cancellation     $20.17  per adult  Cape Town
# 486      4–5 hours  Free cancellation     $41.96  per adult  Cape Town
# 487             16                 18        NaN        NaN  Cape Town
#
#           Country
# 0    South Africa
# 1    South Africa
# 2    South Africa
# 3    South Africa
# 4    South Africa
# ..            ...
# 483  South Africa
# 484  South Africa
# 485  South Africa
# 486  South Africa
# 487  South Africa
#
# [469 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image            34
# Tour Name        33
# Tour Type        92
# Tour Duration    16
# Tour Price       32
# Price Per        33
# Cancellation     60
# Tour By          19
# City              0
# Country           0
# Link             34
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 483  https://dynamic-media-cdn.tripadvisor.com/medi...
# 484  https://dynamic-media-cdn.tripadvisor.com/medi...
# 485  https://dynamic-media-cdn.tripadvisor.com/medi...
# 486  https://dynamic-media-cdn.tripadvisor.com/medi...
# 487                                                NaN
#
#                                              Tour Name        Tour Type  \
# 0                                                  NaN              NaN
# 1               2 Day Safari Experience from Cape Town  Adventure Tours
# 2         Shark Cage Diving and Viewing from Cape Town              NaN
# 3    Cape of Good Hope-Cape Point & Penguins Privat...        Bus Tours
# 4    Cape of Good Hope and Penguins Full-Day Tour F...        Car Tours
# ..                                                 ...              ...
# 483  Cape Town International Airport Transfers to a...              NaN
# 484       Peninsula Vibes: Boulders Beach & Cape Point   Full-day Tours
# 485               Table Mountain Hike with Local Guide  Adventure Tours
# 486                              Township Private Tour        Bus Tours
# 487                                                NaN                1
#
#      Tour Duration Tour Price  Price Per       Cancellation  \
# 0              NaN        NaN        NaN                NaN
# 1           2 days    $367.88  per adult  Free cancellation
# 2          4 hours    $218.82  per adult  Free cancellation
# 3         6+ hours    $120.83  per adult  Free cancellation
# 4         6+ hours     $44.45  per adult  Free cancellation
# ..             ...        ...        ...                ...
# 483  20–45 minutes     $15.39  per adult  Free cancellation
# 484      8–9 hours    $109.41  per adult  Free cancellation
# 485      2–6 hours     $20.17  per adult  Free cancellation
# 486      4–5 hours     $41.96  per adult  Free cancellation
# 487             16        NaN        NaN                 18
#
#                                                Tour By       City  \
# 0                                    Clear all filters  Cape Town
# 1    By BokBus Garden Route Adventure Tours - Day T...  Cape Town
# 2                                   By Marine Dynamics  Cape Town
# 3                               By Kabura Travel Tours  Cape Town
# 4                               By Cape Archives Tours  Cape Town
# ..                                                 ...        ...
# 483                                By Cape Falls Tours  Cape Town
# 484                                 By Local Knowledge  Cape Town
# 485                             By Baz Bus - Day Tours  Cape Town
# 486                           By Morkel Travel & Tours  Cape Town
# 487                                                NaN  Cape Town
#
#           Country                                               Link
# 0    South Africa                                                NaN
# 1    South Africa  https://www.tripadvisor.com/Attraction_Review-...
# 2    South Africa  https://www.tripadvisor.com/Attraction_Review-...
# 3    South Africa  https://www.tripadvisor.com/Attraction_Review-...
# 4    South Africa  https://www.tripadvisor.com/Attraction_Review-...
# ..            ...                                                ...
# 483  South Africa  https://www.tripadvisor.com/Attraction_Review-...
# 484  South Africa  https://www.tripadvisor.com/Attraction_Review-...
# 485  South Africa  https://www.tripadvisor.com/Attraction_Review-...
# 486  South Africa  https://www.tripadvisor.com/Attraction_Review-...
# 487  South Africa                                                NaN
#
# [488 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          454 non-null    object
#  1   Tour Name      455 non-null    object
#  2   Tour Type      396 non-null    object
#  3   Tour Duration  472 non-null    object
#  4   Tour Price     456 non-null    object
#  5   Price Per      455 non-null    object
#  6   Cancellation   428 non-null    object
#  7   Tour By        469 non-null    object
#  8   City           488 non-null    object
#  9   Country        488 non-null    object
#  10  Link           454 non-null    object
# dtypes: object(11)
# memory usage: 42.1+ KB

# %%
# Store the clean dataset
df.to_csv('Cape Townclean.csv')
