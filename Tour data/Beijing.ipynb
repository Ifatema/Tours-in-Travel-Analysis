# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Beijing.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 6', 'ccVGl 2',
#        'WlYyy 7'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                                WlYyy  \
# 0         3,000+ places sorted by traveler favorites
# 1                                                 38
# 2                                                243
# 3  Book risk-free with free cancellations on most...
# 4                                                  2
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3                                                NaN
# 4  Not sure? You can cancel this reservation up t...
#
#                               iPqaD  \
# 0                 Clear all filters
# 1             By Beijing Tour Guide
# 2  By The Trippest Mini Group Tours
# 3                               NaN
# 4          By Sunflower Tours China
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=T...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3                                                NaN
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3                                                NaN
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                NaN
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1  Private Great Wall Hiking from Jiankou to Muti...    1.0
# 2  Mini Group: Beijing Forbidden City Tour with G...    2.0
# 3                                                NaN    NaN
# 4                            Chaoyang Theatre Ticket    3.0
#
#                                         iPqaD href 2          WlYyy 2  \
# 0                                                NaN              NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 2  https://www.tripadvisor.com/Attraction_Review-...  Cable Car Tours
# 3                                                NaN       Cold feet?
# 4  https://www.tripadvisor.com/Attraction_Review-...         Theaters
#
#       WlYyy 3                                              ySnDE  \
# 0         NaN                                                NaN
# 1  9–10 hours  Exploring unrestored and untouched section of ...
# 2    6+ hours  Visit the Great Wall of China and Forbidden Ci...
# 3         NaN                                                NaN
# 4      1 hour  Head to the Chaoyang Theatre for the best Beij...
#
#              WlYyy 4                                      WlYyy 5  \
# 0                NaN                                          NaN
# 1  Free cancellation  100% of travelers recommend this experience
# 2  Free cancellation   98% of travelers recommend this experience
# 3                NaN                                          NaN
# 4  Free cancellation                                          NaN
#
#                                              cctrW 2 ccVGl  WlYyy 6  \
# 0                                                NaN   NaN      NaN
# 1  This number is based on the percentage of all ...  from  $218.00
# 2  This number is based on the percentage of all ...  from  $172.00
# 3                                                NaN   NaN      NaN
# 4                                                NaN  from   $45.00
#
#      ccVGl 2    WlYyy 7
# 0        NaN        NaN
# 1  per adult  More info
# 2  per adult  More info
# 3        NaN        NaN
# 4  per adult  More info

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         514 non-null    object
#  1   cctrW         522 non-null    object
#  2   iPqaD         528 non-null    object
#  3   iPqaD href    494 non-null    object
#  4   FmrIP href    511 non-null    object
#  5   dugSS src     511 non-null    object
#  6   bUshh         511 non-null    object
#  7   cIVmB         511 non-null    float64
#  8   iPqaD href 2  511 non-null    object
#  9   WlYyy 2       489 non-null    object
#  10  WlYyy 3       529 non-null    object
#  11  ySnDE         510 non-null    object
#  12  WlYyy 4       522 non-null    object
#  13  WlYyy 5       158 non-null    object
#  14  cctrW 2       156 non-null    object
#  15  ccVGl         511 non-null    object
#  16  WlYyy 6       512 non-null    object
#  17  ccVGl 2       511 non-null    object
#  18  WlYyy 7       512 non-null    object
# dtypes: float64(1), object(18)
# memory usage: 81.5+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW', 'iPqaD href', 'FmrIP href', 'cIVmB', 'ySnDE', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 7'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={ 'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Beijing'
df['Country'] = 'China'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# 17

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                      Tour By  \
# 0                          Clear all filters
# 1                      By Beijing Tour Guide
# 2           By The Trippest Mini Group Tours
# 3                                        NaN
# 4                   By Sunflower Tours China
# ..                                       ...
# 543                 By Encounter China Tours
# 544                 By Private Beijing Trips
# 545  By Private Forbidden City Walking Tours
# 546               By Our Beijing experiences
# 547                                      NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 543  https://dynamic-media-cdn.tripadvisor.com/medi...
# 544  https://dynamic-media-cdn.tripadvisor.com/medi...
# 545  https://dynamic-media-cdn.tripadvisor.com/medi...
# 546  https://dynamic-media-cdn.tripadvisor.com/medi...
# 547                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    Private Great Wall Hiking from Jiankou to Muti...
# 2    Mini Group: Beijing Forbidden City Tour with G...
# 3                                                  NaN
# 4                              Chaoyang Theatre Ticket
# ..                                                 ...
# 543  Private Tour Vehicle with Driver Service: Beij...
# 544  Small-Group Beijing Coach Day Tour: Badaling G...
# 545  Mutianyu Great Wall And Summer Palace Private ...
# 546                                   Imperial Beijing
# 547                                                NaN
#
#                                                   Link        Tour Type  \
# 0                                                  NaN              NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...  Cable Car Tours
# 3                                                  NaN       Cold feet?
# 4    https://www.tripadvisor.com/Attraction_Review-...         Theaters
# ..                                                 ...              ...
# 543  https://www.tripadvisor.com/Attraction_Review-...              NaN
# 544  https://www.tripadvisor.com/Attraction_Review-...   Full-day Tours
# 545  https://www.tripadvisor.com/Attraction_Review-...   Full-day Tours
# 546  https://www.tripadvisor.com/Attraction_Review-...     E-Bike Tours
# 547                                                NaN                1
#
#     Tour Duration       Cancellation Tour Price  Price Per     City Country
# 0             NaN                NaN        NaN        NaN  Beijing   China
# 1      9–10 hours  Free cancellation    $218.00  per adult  Beijing   China
# 2        6+ hours  Free cancellation    $172.00  per adult  Beijing   China
# 3             NaN                NaN        NaN        NaN  Beijing   China
# 4          1 hour  Free cancellation     $45.00  per adult  Beijing   China
# ..            ...                ...        ...        ...      ...     ...
# 543      6+ hours  Free cancellation    $120.00  per adult  Beijing   China
# 544     8–9 hours  Free cancellation     $53.00  per adult  Beijing   China
# 545     8–9 hours  Free cancellation    $200.00  per adult  Beijing   China
# 546     2–3 hours  Free cancellation     $63.47  per adult  Beijing   China
# 547            19                 21        NaN        NaN  Beijing   China
#
# [531 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image            37
# Tour Name        37
# Tour Type        59
# Tour Duration    19
# Tour Price       36
# Price Per        37
# Cancellation     26
# Tour By          20
# City              0
# Country           0
# Link             37
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 543  https://dynamic-media-cdn.tripadvisor.com/medi...
# 544  https://dynamic-media-cdn.tripadvisor.com/medi...
# 545  https://dynamic-media-cdn.tripadvisor.com/medi...
# 546  https://dynamic-media-cdn.tripadvisor.com/medi...
# 547                                                NaN
#
#                                              Tour Name        Tour Type  \
# 0                                                  NaN              NaN
# 1    Private Great Wall Hiking from Jiankou to Muti...  Adventure Tours
# 2    Mini Group: Beijing Forbidden City Tour with G...  Cable Car Tours
# 3                                                  NaN       Cold feet?
# 4                              Chaoyang Theatre Ticket         Theaters
# ..                                                 ...              ...
# 543  Private Tour Vehicle with Driver Service: Beij...              NaN
# 544  Small-Group Beijing Coach Day Tour: Badaling G...   Full-day Tours
# 545  Mutianyu Great Wall And Summer Palace Private ...   Full-day Tours
# 546                                   Imperial Beijing     E-Bike Tours
# 547                                                NaN                1
#
#     Tour Duration Tour Price  Price Per       Cancellation  \
# 0             NaN        NaN        NaN                NaN
# 1      9–10 hours    $218.00  per adult  Free cancellation
# 2        6+ hours    $172.00  per adult  Free cancellation
# 3             NaN        NaN        NaN                NaN
# 4          1 hour     $45.00  per adult  Free cancellation
# ..            ...        ...        ...                ...
# 543      6+ hours    $120.00  per adult  Free cancellation
# 544     8–9 hours     $53.00  per adult  Free cancellation
# 545     8–9 hours    $200.00  per adult  Free cancellation
# 546     2–3 hours     $63.47  per adult  Free cancellation
# 547            19        NaN        NaN                 21
#
#                                      Tour By     City Country  \
# 0                          Clear all filters  Beijing   China
# 1                      By Beijing Tour Guide  Beijing   China
# 2           By The Trippest Mini Group Tours  Beijing   China
# 3                                        NaN  Beijing   China
# 4                   By Sunflower Tours China  Beijing   China
# ..                                       ...      ...     ...
# 543                 By Encounter China Tours  Beijing   China
# 544                 By Private Beijing Trips  Beijing   China
# 545  By Private Forbidden City Walking Tours  Beijing   China
# 546               By Our Beijing experiences  Beijing   China
# 547                                      NaN  Beijing   China
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3                                                  NaN
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 543  https://www.tripadvisor.com/Attraction_Review-...
# 544  https://www.tripadvisor.com/Attraction_Review-...
# 545  https://www.tripadvisor.com/Attraction_Review-...
# 546  https://www.tripadvisor.com/Attraction_Review-...
# 547                                                NaN
#
# [548 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          511 non-null    object
#  1   Tour Name      511 non-null    object
#  2   Tour Type      489 non-null    object
#  3   Tour Duration  529 non-null    object
#  4   Tour Price     512 non-null    object
#  5   Price Per      511 non-null    object
#  6   Cancellation   522 non-null    object
#  7   Tour By        528 non-null    object
#  8   City           548 non-null    object
#  9   Country        548 non-null    object
#  10  Link           511 non-null    object
# dtypes: object(11)
# memory usage: 47.2+ KB

# %%
# Store the clean dataset
df.to_csv('Beijingclean.csv')
