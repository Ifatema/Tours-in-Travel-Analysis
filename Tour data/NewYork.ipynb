# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('NewYork.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'WlYyy 2', 'iPqaD href 2', 'WlYyy 3', 'WlYyy 4',
#        'WlYyy 5', 'WlYyy 6', 'ySnDE', 'ccVGl', 'WlYyy 8', 'ccVGl 2',
#        'WlYyy 9'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy  \
# 0  1,000+ places sorted by traveler favorites
# 1                                 BEST SELLER
# 2                                 BEST SELLER
# 3                         LIKELY TO SELL OUT*
# 4                                 BEST SELLER
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  This number is based on the percentage of all ...
# 2  This number is based on the percentage of all ...
# 3  This number is based on the percentage of all ...
# 4                                                NaN
#
#                           iPqaD  \
# 0             Clear all filters
# 1  By USA Guided Tours New York
# 2            By ExperienceFirst
# 3                     By HeliNY
# 4      By Empire State Building
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=U...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB WlYyy 2  \
# 0                                                NaN    NaN     NaN
# 1        New York in One Day Guided Sightseeing Tour    1.0   1,864
# 2  OPEN: Statue of Liberty & Ellis Island Tour: A...    2.0   1,592
# 3  New York Helicopter Tour: Ultimate Manhattan S...    3.0     242
# 4             Empire State Building Admission Ticket    4.0     807
#
#                                         iPqaD href 2               WlYyy 3  \
# 0                                                NaN                   NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...             Bus Tours
# 2  https://www.tripadvisor.com/Attraction_Review-...         Walking Tours
# 3  https://www.tripadvisor.com/Attraction_Review-...      Helicopter Tours
# 4  https://www.tripadvisor.com/Attraction_Review-...  Skyscrapers & Towers
#
#          WlYyy 4                 WlYyy 5            WlYyy 6  \
# 0            NaN                     NaN                NaN
# 1        6 hours  Taking safety measures  Free cancellation
# 2      3–5 hours  Taking safety measures  Free cancellation
# 3  17–20 minutes  Taking safety measures  Free cancellation
# 4     45 minutes  Taking safety measures  Free cancellation
#
#                                                ySnDE ccVGl  WlYyy 8  \
# 0                                                NaN   NaN      NaN
# 1  EXPERTLY-GUIDED\n\nGet accompanied by a licens...  from   $99.00
# 2  Visits to the Statue of Liberty National Monum...  from   $44.00
# 3  Seated in comfort, experience all the sights o...  from  $284.00
# 4  Soaring 1,454 feet above Midtown Manhattan fro...  from   $47.91
#
#      ccVGl 2    WlYyy 9
# 0        NaN        NaN
# 1  per adult  More info
# 2  per adult  More info
# 3  per adult  More info
# 4  per adult  More info

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         269 non-null    object
#  1   cctrW         283 non-null    object
#  2   iPqaD         1178 non-null   object
#  3   iPqaD href    720 non-null    object
#  4   FmrIP href    1173 non-null   object
#  5   dugSS src     1169 non-null   object
#  6   bUshh         1173 non-null   object
#  7   cIVmB         1173 non-null   float64
#  8   WlYyy 2       727 non-null    object
#  9   iPqaD href 2  1139 non-null   object
#  10  WlYyy 3       1076 non-null   object
#  11  WlYyy 4       1215 non-null   object
#  12  WlYyy 5       1124 non-null   object
#  13  WlYyy 6       707 non-null    object
#  14  ySnDE         1166 non-null   object
#  15  ccVGl         1173 non-null   object
#  16  WlYyy 8       1174 non-null   object
#  17  ccVGl 2       1173 non-null   object
#  18  WlYyy 9       1174 non-null   object
# dtypes: float64(1), object(18)
# memory usage: 186.9+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'dugSS src', 'cIVmB', 'WlYyy 2','WlYyy 5', 'ySnDE', 'ccVGl','WlYyy 9'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 3':'Tour Type', 'WlYyy 4':'Tour Duration', 'WlYyy 6':'Cancellation', 'WlYyy 8':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'NewYork'
df['Country'] = 'USA'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 59

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                               Tour By  \
# 0                   Clear all filters
# 1        By USA Guided Tours New York
# 2                  By ExperienceFirst
# 3                           By HeliNY
# 4            By Empire State Building
# ...                               ...
# 1253           By New York Helicopter
# 1254  By Attractions4Us New York City
# 1255           By TopView Sightseeing
# 1256                      By Broadway
# 1257                              NaN
#
#                                               Tour Name  \
# 0                                                   NaN
# 1           New York in One Day Guided Sightseeing Tour
# 2     OPEN: Statue of Liberty & Ellis Island Tour: A...
# 3     New York Helicopter Tour: Ultimate Manhattan S...
# 4                Empire State Building Admission Ticket
# ...                                                 ...
# 1253                              Grand Helicopter Tour
# 1254  Ground Zero 911 Memorial+One World Observatory...
# 1255       New York City Hop-On Hop-Off Bus Tour Uptown
# 1256                    Moulin Rouge on Broadway Ticket
# 1257                                                NaN
#
#                                                    Link             Tour Type  \
# 0                                                   NaN                   NaN
# 1     https://www.tripadvisor.com/Attraction_Review-...             Bus Tours
# 2     https://www.tripadvisor.com/Attraction_Review-...         Walking Tours
# 3     https://www.tripadvisor.com/Attraction_Review-...      Helicopter Tours
# 4     https://www.tripadvisor.com/Attraction_Review-...  Skyscrapers & Towers
# ...                                                 ...                   ...
# 1253  https://www.tripadvisor.com/Attraction_Review-...       Adventure Tours
# 1254  https://www.tripadvisor.com/Attraction_Review-...            City Tours
# 1255  https://www.tripadvisor.com/Attraction_Review-...        Hop on Hop Off
# 1256  https://www.tripadvisor.com/Attraction_Review-...              Theaters
# 1257                                                NaN                    45
#
#       Tour Duration       Cancellation Tour Price  Price Per     City Country
# 0               NaN                NaN        NaN        NaN  NewYork     USA
# 1           6 hours  Free cancellation     $99.00  per adult  NewYork     USA
# 2         3–5 hours  Free cancellation     $44.00  per adult  NewYork     USA
# 3     17–20 minutes  Free cancellation    $284.00  per adult  NewYork     USA
# 4        45 minutes  Free cancellation     $47.91  per adult  NewYork     USA
# ...             ...                ...        ...        ...      ...     ...
# 1253  20–25 minutes  Free cancellation    $255.00  per adult  NewYork     USA
# 1254      1–3 hours  Free cancellation     $59.99  per adult  NewYork     USA
# 1255        2 hours                NaN     $69.00  per adult  NewYork     USA
# 1256      2–3 hours                NaN    $102.57  per adult  NewYork     USA
# 1257            NaN                NaN        NaN        NaN  NewYork     USA
#
# [1199 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Tour Name         85
# Tour Type        182
# Tour Duration     43
# Tour Price        84
# Price Per         85
# Cancellation     551
# Tour By           80
# City               0
# Country            0
# Link             119
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                               Tour Name             Tour Type  \
# 0                                                   NaN                   NaN
# 1           New York in One Day Guided Sightseeing Tour             Bus Tours
# 2     OPEN: Statue of Liberty & Ellis Island Tour: A...         Walking Tours
# 3     New York Helicopter Tour: Ultimate Manhattan S...      Helicopter Tours
# 4                Empire State Building Admission Ticket  Skyscrapers & Towers
# ...                                                 ...                   ...
# 1253                              Grand Helicopter Tour       Adventure Tours
# 1254  Ground Zero 911 Memorial+One World Observatory...            City Tours
# 1255       New York City Hop-On Hop-Off Bus Tour Uptown        Hop on Hop Off
# 1256                    Moulin Rouge on Broadway Ticket              Theaters
# 1257                                                NaN                    45
#
#       Tour Duration Tour Price  Price Per       Cancellation  \
# 0               NaN        NaN        NaN                NaN
# 1           6 hours     $99.00  per adult  Free cancellation
# 2         3–5 hours     $44.00  per adult  Free cancellation
# 3     17–20 minutes    $284.00  per adult  Free cancellation
# 4        45 minutes     $47.91  per adult  Free cancellation
# ...             ...        ...        ...                ...
# 1253  20–25 minutes    $255.00  per adult  Free cancellation
# 1254      1–3 hours     $59.99  per adult  Free cancellation
# 1255        2 hours     $69.00  per adult                NaN
# 1256      2–3 hours    $102.57  per adult                NaN
# 1257            NaN        NaN        NaN                NaN
#
#                               Tour By     City Country  \
# 0                   Clear all filters  NewYork     USA
# 1        By USA Guided Tours New York  NewYork     USA
# 2                  By ExperienceFirst  NewYork     USA
# 3                           By HeliNY  NewYork     USA
# 4            By Empire State Building  NewYork     USA
# ...                               ...      ...     ...
# 1253           By New York Helicopter  NewYork     USA
# 1254  By Attractions4Us New York City  NewYork     USA
# 1255           By TopView Sightseeing  NewYork     USA
# 1256                      By Broadway  NewYork     USA
# 1257                              NaN  NewYork     USA
#
#                                                    Link
# 0                                                   NaN
# 1     https://www.tripadvisor.com/Attraction_Review-...
# 2     https://www.tripadvisor.com/Attraction_Review-...
# 3     https://www.tripadvisor.com/Attraction_Review-...
# 4     https://www.tripadvisor.com/Attraction_Review-...
# ...                                                 ...
# 1253  https://www.tripadvisor.com/Attraction_Review-...
# 1254  https://www.tripadvisor.com/Attraction_Review-...
# 1255  https://www.tripadvisor.com/Attraction_Review-...
# 1256  https://www.tripadvisor.com/Attraction_Review-...
# 1257                                                NaN
#
# [1258 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tour Name      1173 non-null   object
#  1   Tour Type      1076 non-null   object
#  2   Tour Duration  1215 non-null   object
#  3   Tour Price     1174 non-null   object
#  4   Price Per      1173 non-null   object
#  5   Cancellation   707 non-null    object
#  6   Tour By        1178 non-null   object
#  7   City           1258 non-null   object
#  8   Country        1258 non-null   object
#  9   Link           1139 non-null   object
# dtypes: object(10)
# memory usage: 98.4+ KB

# %% [markdown]
# **For the Cleaning:**
# - by: REMOVE Clear all filters
# - type: REMOVE num
# - duration: REMOVE num
# - canel: REMOVE other
# - price:$ --> float

# %%
# Store the clean dataset
df.to_csv('NewYorkclean.csv')
