# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Cairo.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 6', 'ccVGl 2',
#        'WlYyy 7', 'dXxty'],
#       dtype='object')

# %%
messy_df['WlYyy 6'].value_counts()
# Out:
# $40.00       20
# $20.00       20
# $35.00       18
# $25.00       17
# $50.00       13
#              ..
# $138.43       1
# $1,000.00     1
# $179.94       1
# $1,400.00     1
# $73.00        1
# Name: WlYyy 6, Length: 214, dtype: int64

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                                WlYyy  \
# 0         8,000+ places sorted by traveler favorites
# 1                                                459
# 2                                                100
# 3  Book risk-free with free cancellations on most...
# 4                                                532
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3                                                NaN
# 4  Not sure? You can cancel this reservation up t...
#
#                             iPqaD  \
# 0               Clear all filters
# 1          By Let's Explore Egypt
# 2              By Emo Tours Egypt
# 3                             NaN
# 4  By Pyramids Land Private Tours
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=a...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3                                                NaN
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3                                                NaN
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                NaN
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1  Private All Inclusive: Giza Pyramids, Sphinx, ...    1.0
# 2   Day Trip To Luxor From Cairo By Plane with Lunch    2.0
# 3                                                NaN    NaN
# 4  8-Hour Private Tour of the Pyramids, Egyptian ...    3.0
#
#                                         iPqaD href 2     WlYyy 2      WlYyy 3  \
# 0                                                NaN         NaN          NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...   Car Tours   8–10 hours
# 2  https://www.tripadvisor.com/Attraction_Review-...   Bus Tours  10–12 hours
# 3                                                NaN  Cold feet?          NaN
# 4  https://www.tripadvisor.com/Attraction_Review-...   Bus Tours   8–10 hours
#
#                                                ySnDE            WlYyy 4  \
# 0                                                NaN                NaN
# 1  Enjoy full Day to Giza Pyramids Sakkara plus M...  Free cancellation
# 2  If you are on budget and you would like to go ...  Free cancellation
# 3                                                NaN                NaN
# 4  On this private Cairo day tour several activit...  Free cancellation
#
#                                        WlYyy 5  \
# 0                                          NaN
# 1   98% of travelers recommend this experience
# 2  100% of travelers recommend this experience
# 3                                          NaN
# 4   99% of travelers recommend this experience
#
#                                              cctrW 2 ccVGl  WlYyy 6  \
# 0                                                NaN   NaN      NaN
# 1  This number is based on the percentage of all ...  from   $75.00
# 2  This number is based on the percentage of all ...  from  $320.00
# 3                                                NaN   NaN      NaN
# 4  This number is based on the percentage of all ...  from   $64.00
#
#      ccVGl 2    WlYyy 7 dXxty
# 0        NaN        NaN   NaN
# 1  per adult  More info   NaN
# 2  per adult  More info   NaN
# 3        NaN        NaN   NaN
# 4  per adult  More info   NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         406 non-null    object
#  1   cctrW         427 non-null    object
#  2   iPqaD         430 non-null    object
#  3   iPqaD href    389 non-null    object
#  4   FmrIP href    420 non-null    object
#  5   dugSS src     418 non-null    object
#  6   bUshh         420 non-null    object
#  7   cIVmB         420 non-null    float64
#  8   iPqaD href 2  416 non-null    object
#  9   WlYyy 2       402 non-null    object
#  10  WlYyy 3       435 non-null    object
#  11  ySnDE         416 non-null    object
#  12  WlYyy 4       426 non-null    object
#  13  WlYyy 5       193 non-null    object
#  14  cctrW 2       192 non-null    object
#  15  ccVGl         420 non-null    object
#  16  WlYyy 6       421 non-null    object
#  17  ccVGl 2       420 non-null    object
#  18  WlYyy 7       421 non-null    object
#  19  dXxty         216 non-null    object
# dtypes: float64(1), object(19)
# memory usage: 70.6+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'cIVmB', 'ySnDE', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 7', 'dXxty' ], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Cairo'
df['Country'] = 'Egypt'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 14

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                 Tour By  \
# 0                     Clear all filters
# 1                By Let's Explore Egypt
# 2                    By Emo Tours Egypt
# 3                                   NaN
# 4        By Pyramids Land Private Tours
# ..                                  ...
# 446  By Tours Egypt -day tours (101692)
# 447                       By Rimo Tours
# 448                By Egypt Royal Tours
# 449          By Hesham Egypt Tour Guide
# 450                                 NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 446  https://dynamic-media-cdn.tripadvisor.com/medi...
# 447  https://dynamic-media-cdn.tripadvisor.com/medi...
# 448  https://dynamic-media-cdn.tripadvisor.com/medi...
# 449  https://dynamic-media-cdn.tripadvisor.com/medi...
# 450                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    Private All Inclusive: Giza Pyramids, Sphinx, ...
# 2     Day Trip To Luxor From Cairo By Plane with Lunch
# 3                                                  NaN
# 4    8-Hour Private Tour of the Pyramids, Egyptian ...
# ..                                                 ...
# 446  Private Tour Giza pyramids, Sphinx and Egyptia...
# 447  Private Night Tour in the Pyramids Of Giza + T...
# 448                Giza Pyramids Tour With Camel Ride.
# 449  night-tour Nile dinner cruise with open buffet...
# 450                                                NaN
#
#                                                   Link   Tour Type  \
# 0                                                  NaN         NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...   Car Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...   Bus Tours
# 3                                                  NaN  Cold feet?
# 4    https://www.tripadvisor.com/Attraction_Review-...   Bus Tours
# ..                                                 ...         ...
# 446  https://www.tripadvisor.com/Attraction_Review-...   Bus Tours
# 447  https://www.tripadvisor.com/Attraction_Review-...   Bus Tours
# 448  https://www.tripadvisor.com/Attraction_Review-...   Bus Tours
# 449  https://www.tripadvisor.com/Attraction_Review-...   Bus Tours
# 450                                                NaN           1
#
#     Tour Duration       Cancellation Tour Price  Price Per   City Country
# 0             NaN                NaN        NaN        NaN  Cairo   Egypt
# 1      8–10 hours  Free cancellation     $75.00  per adult  Cairo   Egypt
# 2     10–12 hours  Free cancellation    $320.00  per adult  Cairo   Egypt
# 3             NaN                NaN        NaN        NaN  Cairo   Egypt
# 4      8–10 hours  Free cancellation     $64.00  per adult  Cairo   Egypt
# ..            ...                ...        ...        ...    ...     ...
# 446      6+ hours  Free cancellation     $26.50  per adult  Cairo   Egypt
# 447     4–7 hours  Free cancellation     $68.58  per group  Cairo   Egypt
# 448     4–5 hours  Free cancellation     $75.00  per adult  Cairo   Egypt
# 449       2 hours  Free cancellation     $38.00  per adult  Cairo   Egypt
# 450            17                 19        NaN        NaN  Cairo   Egypt
#
# [437 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image            33
# Tour Name        31
# Tour Type        49
# Tour Duration    16
# Tour Price       30
# Price Per        31
# Cancellation     25
# Tour By          21
# City              0
# Country           0
# Link             35
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3                                                  NaN
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 446  https://dynamic-media-cdn.tripadvisor.com/medi...
# 447  https://dynamic-media-cdn.tripadvisor.com/medi...
# 448  https://dynamic-media-cdn.tripadvisor.com/medi...
# 449  https://dynamic-media-cdn.tripadvisor.com/medi...
# 450                                                NaN
#
#                                              Tour Name   Tour Type  \
# 0                                                  NaN         NaN
# 1    Private All Inclusive: Giza Pyramids, Sphinx, ...   Car Tours
# 2     Day Trip To Luxor From Cairo By Plane with Lunch   Bus Tours
# 3                                                  NaN  Cold feet?
# 4    8-Hour Private Tour of the Pyramids, Egyptian ...   Bus Tours
# ..                                                 ...         ...
# 446  Private Tour Giza pyramids, Sphinx and Egyptia...   Bus Tours
# 447  Private Night Tour in the Pyramids Of Giza + T...   Bus Tours
# 448                Giza Pyramids Tour With Camel Ride.   Bus Tours
# 449  night-tour Nile dinner cruise with open buffet...   Bus Tours
# 450                                                NaN           1
#
#     Tour Duration Tour Price  Price Per       Cancellation  \
# 0             NaN        NaN        NaN                NaN
# 1      8–10 hours     $75.00  per adult  Free cancellation
# 2     10–12 hours    $320.00  per adult  Free cancellation
# 3             NaN        NaN        NaN                NaN
# 4      8–10 hours     $64.00  per adult  Free cancellation
# ..            ...        ...        ...                ...
# 446      6+ hours     $26.50  per adult  Free cancellation
# 447     4–7 hours     $68.58  per group  Free cancellation
# 448     4–5 hours     $75.00  per adult  Free cancellation
# 449       2 hours     $38.00  per adult  Free cancellation
# 450            17        NaN        NaN                 19
#
#                                 Tour By   City Country  \
# 0                     Clear all filters  Cairo   Egypt
# 1                By Let's Explore Egypt  Cairo   Egypt
# 2                    By Emo Tours Egypt  Cairo   Egypt
# 3                                   NaN  Cairo   Egypt
# 4        By Pyramids Land Private Tours  Cairo   Egypt
# ..                                  ...    ...     ...
# 446  By Tours Egypt -day tours (101692)  Cairo   Egypt
# 447                       By Rimo Tours  Cairo   Egypt
# 448                By Egypt Royal Tours  Cairo   Egypt
# 449          By Hesham Egypt Tour Guide  Cairo   Egypt
# 450                                 NaN  Cairo   Egypt
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3                                                  NaN
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 446  https://www.tripadvisor.com/Attraction_Review-...
# 447  https://www.tripadvisor.com/Attraction_Review-...
# 448  https://www.tripadvisor.com/Attraction_Review-...
# 449  https://www.tripadvisor.com/Attraction_Review-...
# 450                                                NaN
#
# [451 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          418 non-null    object
#  1   Tour Name      420 non-null    object
#  2   Tour Type      402 non-null    object
#  3   Tour Duration  435 non-null    object
#  4   Tour Price     421 non-null    object
#  5   Price Per      420 non-null    object
#  6   Cancellation   426 non-null    object
#  7   Tour By        430 non-null    object
#  8   City           451 non-null    object
#  9   Country        451 non-null    object
#  10  Link           416 non-null    object
# dtypes: object(11)
# memory usage: 38.9+ KB

# %%
# Store the clean dataset
df.to_csv('Cairoclean.csv')
