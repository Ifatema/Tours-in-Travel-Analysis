# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Muscat.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'ccVGl', 'WlYyy 6', 'ccVGl 2', 'WlYyy 7', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                      WlYyy  \
# 0  479 places sorted by traveler favorites
# 1                                       54
# 2                                       14
# 3                                       57
# 4                                       32
#
#                                                cctrW                    iPqaD  \
# 0  Tours, activities and experiences bookable on ...        Clear all filters
# 1  Not sure? You can cancel this reservation up t...   By Sunshine Tours Oman
# 2  Not sure? You can cancel this reservation up t...  By Demaniyat Adventures
# 3  Not sure? You can cancel this reservation up t...               By GidOman
# 4  Not sure? You can cancel this reservation up t...        By Gray Line Oman
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=b...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1  Full-Day Private Wahiba Sands Desert and Wadi ...    1.0
# 2                    Snorkeling at Dimaniyat Islands    2.0
# 3  Wadi Shab and Bimmah Sinkhole Private Full Day...    3.0
# 4       Discover the South and Wadi Shab from Muscat    4.0
#
#                                         iPqaD href 2          WlYyy 2  \
# 0                                                NaN              NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...        Car Tours
# 2  https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 3  https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 4  https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
#
#       WlYyy 3                                              ySnDE  \
# 0         NaN                                                NaN
# 1    6+ hours  Depart Muscat on the way, we make a short phot...
# 2   4–5 hours  Going on this tours with us, we will take you ...
# 3  8–10 hours  Wadi Shab is a very popular outdoor attraction...
# 4    6+ hours  Great Advertise day. OMAN's Wadi's are the cor...
#
#              WlYyy 4 ccVGl  WlYyy 6    ccVGl 2    WlYyy 7  \
# 0                NaN   NaN      NaN        NaN        NaN
# 1  Free cancellation  from  $194.00  per adult  More info
# 2  Free cancellation  from  $100.00  per adult  More info
# 3  Free cancellation  from  $180.00  per adult  More info
# 4  Free cancellation  from   $79.00  per adult  More info
#
#                     dXxty
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4  Taking safety measures

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         169 non-null    object
#  1   cctrW         369 non-null    object
#  2   iPqaD         384 non-null    object
#  3   iPqaD href    152 non-null    object
#  4   FmrIP href    374 non-null    object
#  5   dugSS src     371 non-null    object
#  6   bUshh         374 non-null    object
#  7   cIVmB         374 non-null    float64
#  8   iPqaD href 2  372 non-null    object
#  9   WlYyy 2       312 non-null    object
#  10  WlYyy 3       389 non-null    object
#  11  ySnDE         358 non-null    object
#  12  WlYyy 4       371 non-null    object
#  13  ccVGl         374 non-null    object
#  14  WlYyy 6       375 non-null    object
#  15  ccVGl 2       374 non-null    object
#  16  WlYyy 7       375 non-null    object
#  17  dXxty         173 non-null    object
# dtypes: float64(1), object(17)
# memory usage: 56.8+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'dugSS src', 'cIVmB','ySnDE','ccVGl', 'WlYyy 7', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Muscat'
df['Country'] = 'Oman'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 27

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                              Tour By  \
# 0                  Clear all filters
# 1             By Sunshine Tours Oman
# 2            By Demaniyat Adventures
# 3                         By GidOman
# 4                  By Gray Line Oman
# ..                               ...
# 398           By Extra Divers Qantab
# 399           By Extra Divers Qantab
# 400                  By Global Scuba
# 401  By Charm of Nature Tourism Oman
# 402                              NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    Full-Day Private Wahiba Sands Desert and Wadi ...
# 2                      Snorkeling at Dimaniyat Islands
# 3    Wadi Shab and Bimmah Sinkhole Private Full Day...
# 4         Discover the South and Wadi Shab from Muscat
# ..                                                 ...
# 398                                  Introductory Dive
# 399                           Snorkeling in Turtle bay
# 400  Scuba, Snorkeling, Boat tour, and Camping in D...
# 401             8 Days 7 Nights Customize Classic Tour
# 402                                                NaN
#
#                                                   Link        Tour Type  \
# 0                                                  NaN              NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...        Car Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 3    https://www.tripadvisor.com/Attraction_Review-...  Adventure Tours
# 4    https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
# ..                                                 ...              ...
# 398  https://www.tripadvisor.com/Attraction_Review-...              NaN
# 399  https://www.tripadvisor.com/Attraction_Review-...      Water Tours
# 400  https://www.tripadvisor.com/Attraction_Review-...              NaN
# 401  https://www.tripadvisor.com/Attraction_Review-...  Multi-day Tours
# 402                                                NaN                1
#
#     Tour Duration       Cancellation  Tour Price  Price Per    City Country
# 0             NaN                NaN         NaN        NaN  Muscat    Oman
# 1        6+ hours  Free cancellation     $194.00  per adult  Muscat    Oman
# 2       4–5 hours  Free cancellation     $100.00  per adult  Muscat    Oman
# 3      8–10 hours  Free cancellation     $180.00  per adult  Muscat    Oman
# 4        6+ hours  Free cancellation      $79.00  per adult  Muscat    Oman
# ..            ...                ...         ...        ...     ...     ...
# 398       3 hours  Free cancellation     $156.93  per adult  Muscat    Oman
# 399       2 hours  Free cancellation      $56.54  per adult  Muscat    Oman
# 400       4 hours  Free cancellation      $85.00  per adult  Muscat    Oman
# 401           NaN  Free cancellation  $12,490.67  per group  Muscat    Oman
# 402            15                NaN         NaN        NaN  Muscat    Oman
#
# [376 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Tour Name        29
# Tour Type        91
# Tour Duration    14
# Tour Price       28
# Price Per        29
# Cancellation     32
# Tour By          19
# City              0
# Country           0
# Link             31
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                              Tour Name        Tour Type  \
# 0                                                  NaN              NaN
# 1    Full-Day Private Wahiba Sands Desert and Wadi ...        Car Tours
# 2                      Snorkeling at Dimaniyat Islands  Adventure Tours
# 3    Wadi Shab and Bimmah Sinkhole Private Full Day...  Adventure Tours
# 4         Discover the South and Wadi Shab from Muscat        Bus Tours
# ..                                                 ...              ...
# 398                                  Introductory Dive              NaN
# 399                           Snorkeling in Turtle bay      Water Tours
# 400  Scuba, Snorkeling, Boat tour, and Camping in D...              NaN
# 401             8 Days 7 Nights Customize Classic Tour  Multi-day Tours
# 402                                                NaN                1
#
#     Tour Duration  Tour Price  Price Per       Cancellation  \
# 0             NaN         NaN        NaN                NaN
# 1        6+ hours     $194.00  per adult  Free cancellation
# 2       4–5 hours     $100.00  per adult  Free cancellation
# 3      8–10 hours     $180.00  per adult  Free cancellation
# 4        6+ hours      $79.00  per adult  Free cancellation
# ..            ...         ...        ...                ...
# 398       3 hours     $156.93  per adult  Free cancellation
# 399       2 hours      $56.54  per adult  Free cancellation
# 400       4 hours      $85.00  per adult  Free cancellation
# 401           NaN  $12,490.67  per group  Free cancellation
# 402            15         NaN        NaN                NaN
#
#                              Tour By    City Country  \
# 0                  Clear all filters  Muscat    Oman
# 1             By Sunshine Tours Oman  Muscat    Oman
# 2            By Demaniyat Adventures  Muscat    Oman
# 3                         By GidOman  Muscat    Oman
# 4                  By Gray Line Oman  Muscat    Oman
# ..                               ...     ...     ...
# 398           By Extra Divers Qantab  Muscat    Oman
# 399           By Extra Divers Qantab  Muscat    Oman
# 400                  By Global Scuba  Muscat    Oman
# 401  By Charm of Nature Tourism Oman  Muscat    Oman
# 402                              NaN  Muscat    Oman
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3    https://www.tripadvisor.com/Attraction_Review-...
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 398  https://www.tripadvisor.com/Attraction_Review-...
# 399  https://www.tripadvisor.com/Attraction_Review-...
# 400  https://www.tripadvisor.com/Attraction_Review-...
# 401  https://www.tripadvisor.com/Attraction_Review-...
# 402                                                NaN
#
# [403 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tour Name      374 non-null    object
#  1   Tour Type      312 non-null    object
#  2   Tour Duration  389 non-null    object
#  3   Tour Price     375 non-null    object
#  4   Price Per      374 non-null    object
#  5   Cancellation   371 non-null    object
#  6   Tour By        384 non-null    object
#  7   City           403 non-null    object
#  8   Country        403 non-null    object
#  9   Link           372 non-null    object
# dtypes: object(10)
# memory usage: 31.6+ KB

# %% [markdown]
# **For the Cleaning:**
# - type: REMOVE Q? & num
# - duration: REMOVE num & + & D M
# - canel: REMOVE other
# - price:$ --> float

# %%
# Store the clean dataset
df.to_csv('Muscatclean.csv')
