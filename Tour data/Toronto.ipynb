# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Toronto.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'WlYyy 5', 'cctrW 2', 'ccVGl', 'WlYyy 6', 'ccVGl 2',
#        'WlYyy 7', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                      WlYyy  \
# 0  322 places sorted by traveler favorites
# 1                                      984
# 2                                      168
# 3                                       41
# 4                                      323
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3  Not sure? You can cancel this reservation up t...
# 4  Not sure? You can cancel this reservation up t...
#
#                                iPqaD  \
# 0                  Clear all filters
# 1                By Niagara Day Tour
# 2        By Zoom Tours Niagara Falls
# 3     By Airlink Niagara Falls Tours
# 4  By Queen Tour Niagara Falls Tours
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=Y...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1                Niagara Falls Day Tour from Toronto    1.0
# 2  Niagara Falls Day and Evening Tour With Boat C...    2.0
# 3  Luxury Day Tour of Niagara Falls & Niagara Cru...    3.0
# 4  Niagara Falls Small-Group Day Tour from Toront...    4.0
#
#                                         iPqaD href 2         WlYyy 2  \
# 0                                                NaN             NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
# 2  https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
# 3  https://www.tripadvisor.com/Attraction_Review-...  Full-day Tours
# 4  https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
#
#       WlYyy 3                                              ySnDE  \
# 0         NaN                                                NaN
# 1  9–10 hours  Enjoy a day trip from Toronto to Niagara Falls...
# 2  9–10 hours  We offer Award winning Tours of Niagara Falls ...
# 3    6+ hours  Experience Niagara Falls on this 9.5-hour day ...
# 4    6+ hours  Enjoy a small-group tour of Niagara Falls with...
#
#              WlYyy 4                                     WlYyy 5  \
# 0                NaN                                         NaN
# 1  Free cancellation  97% of travelers recommend this experience
# 2  Free cancellation                                         NaN
# 3  Free cancellation                                         NaN
# 4  Free cancellation  93% of travelers recommend this experience
#
#                                              cctrW 2 ccVGl  WlYyy 6  \
# 0                                                NaN   NaN      NaN
# 1  This number is based on the percentage of all ...  from   $76.40
# 2                                                NaN  from  $152.16
# 3                                                NaN  from  $152.16
# 4  This number is based on the percentage of all ...  from   $82.05
#
#      ccVGl 2    WlYyy 7                   dXxty
# 0        NaN        NaN                     NaN
# 1  per adult  More info                     NaN
# 2  per adult  More info  Taking safety measures
# 3  per adult  More info  Taking safety measures
# 4  per adult  More info                     NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         119 non-null    object
#  1   cctrW         110 non-null    object
#  2   iPqaD         129 non-null    object
#  3   iPqaD href    112 non-null    object
#  4   FmrIP href    126 non-null    object
#  5   dugSS src     125 non-null    object
#  6   bUshh         126 non-null    object
#  7   cIVmB         126 non-null    float64
#  8   iPqaD href 2  125 non-null    object
#  9   WlYyy 2       123 non-null    object
#  10  WlYyy 3       132 non-null    object
#  11  ySnDE         125 non-null    object
#  12  WlYyy 4       111 non-null    object
#  13  WlYyy 5       34 non-null     object
#  14  cctrW 2       32 non-null     object
#  15  ccVGl         126 non-null    object
#  16  WlYyy 6       127 non-null    object
#  17  ccVGl 2       126 non-null    object
#  18  WlYyy 7       127 non-null    object
#  19  dXxty         67 non-null     object
# dtypes: float64(1), object(19)
# memory usage: 21.5+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href', 'cIVmB','ySnDE', 'WlYyy 5', 'cctrW 2', 'ccVGl','WlYyy 7', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image', 'iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Toronto'
df['Country'] = 'Canada'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 9

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                Tour By  \
# 0                    Clear all filters
# 1                  By Niagara Day Tour
# 2          By Zoom Tours Niagara Falls
# 3       By Airlink Niagara Falls Tours
# 4    By Queen Tour Niagara Falls Tours
# ..                                 ...
# 126                  By Toronto Yachts
# 127               By Toronto Fun Tours
# 128     By Airlink Niagara Falls Tours
# 129                                NaN
# 136                                NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 126  https://dynamic-media-cdn.tripadvisor.com/medi...
# 127  https://dynamic-media-cdn.tripadvisor.com/medi...
# 128  https://dynamic-media-cdn.tripadvisor.com/medi...
# 129                                                NaN
# 136                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1                  Niagara Falls Day Tour from Toronto
# 2    Niagara Falls Day and Evening Tour With Boat C...
# 3    Luxury Day Tour of Niagara Falls & Niagara Cru...
# 4    Niagara Falls Small-Group Day Tour from Toront...
# ..                                                 ...
# 126       VIP Luxury Yacht Charter for up to 16 Guests
# 127  Niagara Falls and Niagara-on-the-Lake (Private...
# 128         Private Tour of Niagara Falls from Toronto
# 129                                                NaN
# 136                                                NaN
#
#                                                   Link       Tour Type  \
# 0                                                  NaN             NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
# 3    https://www.tripadvisor.com/Attraction_Review-...  Full-day Tours
# 4    https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
# ..                                                 ...             ...
# 126  https://www.tripadvisor.com/Attraction_Review-...  Half-day Tours
# 127  https://www.tripadvisor.com/Attraction_Review-...  Full-day Tours
# 128  https://www.tripadvisor.com/Attraction_Review-...       Bus Tours
# 129                                                NaN               1
# 136                                                NaN               1
#
#     Tour Duration       Cancellation Tour Price  Price Per     City Country
# 0             NaN                NaN        NaN        NaN  Toronto  Canada
# 1      9–10 hours  Free cancellation     $76.40  per adult  Toronto  Canada
# 2      9–10 hours  Free cancellation    $152.16  per adult  Toronto  Canada
# 3        6+ hours  Free cancellation    $152.16  per adult  Toronto  Canada
# 4        6+ hours  Free cancellation     $82.05  per adult  Toronto  Canada
# ..            ...                ...        ...        ...      ...     ...
# 126       4 hours                NaN  $1,771.21  per group  Toronto  Canada
# 127      6+ hours  Free cancellation    $598.99  per adult  Toronto  Canada
# 128      6+ hours  Free cancellation    $297.08  per adult  Toronto  Canada
# 129             4                  6        NaN        NaN  Toronto  Canada
# 136             5                  7        NaN        NaN  Toronto  Canada
#
# [128 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image            12
# Tour Name        11
# Tour Type        14
# Tour Duration     5
# Tour Price       10
# Price Per        11
# Cancellation     26
# Tour By           8
# City              0
# Country           0
# Link             12
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 132  https://dynamic-media-cdn.tripadvisor.com/medi...
# 133  https://dynamic-media-cdn.tripadvisor.com/medi...
# 134  https://dynamic-media-cdn.tripadvisor.com/medi...
# 135  https://dynamic-media-cdn.tripadvisor.com/medi...
# 136                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1                  Niagara Falls Day Tour from Toronto
# 2    Niagara Falls Day and Evening Tour With Boat C...
# 3    Luxury Day Tour of Niagara Falls & Niagara Cru...
# 4    Niagara Falls Small-Group Day Tour from Toront...
# ..                                                 ...
# 132  West Queen West: Uncover the cultural heart of...
# 133  Scavenger Hunt Adventure in Toronto by Operati...
# 134  Financial District and City Halls: An audio to...
# 135                               Toronto Walking Tour
# 136                                                NaN
#
#                        Tour Type  Tour Duration Tour Price  Price Per  \
# 0                            NaN            NaN        NaN        NaN
# 1                      Bus Tours     9–10 hours     $76.40  per adult
# 2                      Bus Tours     9–10 hours    $152.16  per adult
# 3                 Full-day Tours       6+ hours    $152.16  per adult
# 4                      Bus Tours       6+ hours     $82.05  per adult
# ..                           ...            ...        ...        ...
# 132                   City Tours  50–75 minutes      $5.20  per adult
# 133  Self-guided Tours & Rentals        2 hours     $11.27  per adult
# 134                Walking Tours  30–45 minutes      $5.20  per adult
# 135                Walking Tours   2–30 minutes     $25.84  per adult
# 136                            1              5        NaN        NaN
#
#           Cancellation                                            Tour By  \
# 0                  NaN                                  Clear all filters
# 1    Free cancellation                                By Niagara Day Tour
# 2    Free cancellation                        By Zoom Tours Niagara Falls
# 3    Free cancellation                     By Airlink Niagara Falls Tours
# 4    Free cancellation                  By Queen Tour Niagara Falls Tours
# ..                 ...                                                ...
# 132                NaN                                By VoiceMap Toronto
# 133  Free cancellation  By Operation City Quest Scavenger Hunt of Toronto
# 134                NaN                                By VoiceMap Toronto
# 135  Free cancellation                            By Toronto Walking Tour
# 136                  7                                                NaN
#
#         City Country                                               Link
# 0    Toronto  Canada                                                NaN
# 1    Toronto  Canada  https://www.tripadvisor.com/Attraction_Review-...
# 2    Toronto  Canada  https://www.tripadvisor.com/Attraction_Review-...
# 3    Toronto  Canada  https://www.tripadvisor.com/Attraction_Review-...
# 4    Toronto  Canada  https://www.tripadvisor.com/Attraction_Review-...
# ..       ...     ...                                                ...
# 132  Toronto  Canada  https://www.tripadvisor.com/Attraction_Review-...
# 133  Toronto  Canada  https://www.tripadvisor.com/Attraction_Review-...
# 134  Toronto  Canada  https://www.tripadvisor.com/Attraction_Review-...
# 135  Toronto  Canada  https://www.tripadvisor.com/Attraction_Review-...
# 136  Toronto  Canada                                                NaN
#
# [137 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          125 non-null    object
#  1   Tour Name      126 non-null    object
#  2   Tour Type      123 non-null    object
#  3   Tour Duration  132 non-null    object
#  4   Tour Price     127 non-null    object
#  5   Price Per      126 non-null    object
#  6   Cancellation   111 non-null    object
#  7   Tour By        129 non-null    object
#  8   City           137 non-null    object
#  9   Country        137 non-null    object
#  10  Link           125 non-null    object
# dtypes: object(11)
# memory usage: 11.9+ KB

# %%
# Store the clean dataset
df.to_csv('Torontoclean.csv')
