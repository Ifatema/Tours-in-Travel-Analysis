# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Buenos Aires.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src', 'bUshh',
#        'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE', 'dXxty',
#        'ccVGl', 'WlYyy 5', 'ccVGl 2', 'WlYyy 6', 'WlYyy 7', 'cctrW 2'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                         WlYyy                  iPqaD  \
# 0  1,000+ places sorted by traveler favorites      Clear all filters
# 1                                          11     By Signature Tours
# 2                                         186  By Tours Buenos Aires
# 3                                         107     By Signature Tours
# 4                                          31  By www.depasseios.com
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=Q...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# ...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552 entries, 0 to 551
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         431 non-null    object
#  1   iPqaD         531 non-null    object
#  2   iPqaD href    408 non-null    object
#  3   FmrIP href    515 non-null    object
#  4   dugSS src     514 non-null    object
#  5   bUshh         515 non-null    object
#  6   cIVmB         515 non-null    float64
#  7   iPqaD href 2  514 non-null    object
#  8   WlYyy 2       438 non-null    object
#  9   WlYyy 3       533 non-null    object
#  10  ySnDE         512 non-null    object
#  11  dXxty         381 non-null    object
#  12  ccVGl         515 non-null    object
#  13  WlYyy 5       516 non-null    object
#  14  ccVGl 2       515 non-null    object
#  15  WlYyy 6       516 non-null    object
#  16  WlYyy 7       480 non-null    object
#  17  cctrW 2       479 non-null    object
# ...

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'iPqaD href', 'FmrIP href',  'cIVmB', 'ySnDE', 'dXxty', 'ccVGl', 'WlYyy 6', 'cctrW 2'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 7':'Cancellation', 'WlYyy 5':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Buenos Aires'
df['Country'] = 'Argentina'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 22

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                       Tour By  \
# 0           Clear all filters
# 1          By Signature Tours
# 2       By Tours Buenos Aires
# 3          By Signature Tours
# 4       By www.depasseios.com
# ..                        ...
# 547  By Grupo Summa Argentina
# 548        By Signature Tours
# 549        By Signature Tours
# 550   By Buenos Aires Touring
# 551                       NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 547  https://dynamic-media-cdn.tripadvisor.com/medi...
# 548  https://dynamic-media-cdn.tripadvisor.com/medi...
# 549  https://dynamic-media-cdn.tripadvisor.com/medi...
# ...

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Tour Price', 'Price Per', 'Cancellation', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image             38
# Tour Name         37
# Tour Type        114
# Tour Duration     19
# Tour Price        36
# Price Per         37
# Cancellation      72
# Tour By           21
# City               0
# Country            0
# Link              38
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 547  https://dynamic-media-cdn.tripadvisor.com/medi...
# 548  https://dynamic-media-cdn.tripadvisor.com/medi...
# 549  https://dynamic-media-cdn.tripadvisor.com/medi...
# 550  https://dynamic-media-cdn.tripadvisor.com/medi...
# 551                                                NaN
#
#                                              Tour Name        Tour Type  \
# 0                                                  NaN              NaN
# 1    Private Day at Iguazu Falls from Buenos Aires ...  Adventure Tours
# 2    Gaucho Day Tour Ranch in San Antonio de Areco ...        Bus Tours
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552 entries, 0 to 551
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          514 non-null    object
#  1   Tour Name      515 non-null    object
#  2   Tour Type      438 non-null    object
#  3   Tour Duration  533 non-null    object
#  4   Tour Price     516 non-null    object
#  5   Price Per      515 non-null    object
#  6   Cancellation   480 non-null    object
#  7   Tour By        531 non-null    object
#  8   City           552 non-null    object
#  9   Country        552 non-null    object
#  10  Link           514 non-null    object
# dtypes: object(11)
# memory usage: 47.6+ KB

# %%
# Store the clean dataset
df.to_csv('Buenos Airesclean.csv')
