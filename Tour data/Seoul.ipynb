# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Seoul.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'iPqaD href', 'FmrIP href', 'dugSS src',
#        'bUshh', 'cIVmB', 'iPqaD href 2', 'WlYyy 2', 'WlYyy 3', 'ySnDE',
#        'WlYyy 4', 'ccVGl', 'WlYyy 6', 'ccVGl 2', 'WlYyy 7', 'dXxty'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                      WlYyy  \
# 0  674 places sorted by traveler favorites
# 1                                      104
# 2                                       19
# 3                                      180
# 4                                       14
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3  Not sure? You can cancel this reservation up t...
# 4  Not sure? You can cancel this reservation up t...
#
#                                       iPqaD  \
# 0                         Clear all filters
# 1                             By VIP TRAVEL
# 2  By Withlocals.com Private Tours in Seoul
# 3                  By Hello K Cooking Class
# 4                         By Outdoors Korea
#
#                                           iPqaD href  \
# 0  https://www.tripadvisor.com/ClientLink?value=Z...
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                           FmrIP href  \
# 0                                                NaN
# 1  https://www.tripadvisor.com/AttractionProductR...
# 2  https://www.tripadvisor.com/AttractionProductR...
# 3  https://www.tripadvisor.com/AttractionProductR...
# 4  https://www.tripadvisor.com/AttractionProductR...
#
#                                            dugSS src  \
# 0                                                NaN
# 1  https://dynamic-media-cdn.tripadvisor.com/medi...
# 2  https://dynamic-media-cdn.tripadvisor.com/medi...
# 3  https://dynamic-media-cdn.tripadvisor.com/medi...
# 4  https://dynamic-media-cdn.tripadvisor.com/medi...
#
#                                                bUshh  cIVmB  \
# 0                                                NaN    NaN
# 1  Best Half Day DMZ Tour from Seoul (No Forced S...    1.0
# 2  Highlights & Hidden Gems With Locals: Best of ...    2.0
# 3  Korean Cooking Class with Full-Course Meal & L...    3.0
# 4  Private Tour Nami Island with Petite France or...    4.0
#
#                                         iPqaD href 2          WlYyy 2  \
# 0                                                NaN              NaN
# 1  https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
# 2  https://www.tripadvisor.com/Attraction_Review-...       City Tours
# 3  https://www.tripadvisor.com/Attraction_Review-...  Cooking Classes
# 4  https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
#
#      WlYyy 3                                              ySnDE  \
# 0        NaN                                                NaN
# 1    6 hours  Your experience while visiting the DMZ depends...
# 2    3 hours  This is not just another city tour; this is th...
# 3    3 hours  Do you take a deep interest in authentic Korea...
# 4  8–9 hours  We bring you to Nami Island and Petite France ...
#
#              WlYyy 4 ccVGl  WlYyy 6    ccVGl 2    WlYyy 7 dXxty
# 0                NaN   NaN      NaN        NaN        NaN   NaN
# 1  Free cancellation  from   $77.00  per adult  More info   NaN
# 2  Free cancellation  from   $67.88  per adult  More info   NaN
# 3  Free cancellation  from   $70.00  per adult  More info   NaN
# 4  Free cancellation  from  $128.00  per adult  More info   NaN

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         226 non-null    object
#  1   cctrW         234 non-null    object
#  2   iPqaD         235 non-null    object
#  3   iPqaD href    216 non-null    object
#  4   FmrIP href    240 non-null    object
#  5   dugSS src     240 non-null    object
#  6   bUshh         240 non-null    object
#  7   cIVmB         240 non-null    float64
#  8   iPqaD href 2  227 non-null    object
#  9   WlYyy 2       227 non-null    object
#  10  WlYyy 3       249 non-null    object
#  11  ySnDE         240 non-null    object
#  12  WlYyy 4       234 non-null    object
#  13  ccVGl         240 non-null    object
#  14  WlYyy 6       241 non-null    object
#  15  ccVGl 2       240 non-null    object
#  16  WlYyy 7       241 non-null    object
#  17  dXxty         115 non-null    object
# dtypes: float64(1), object(17)
# memory usage: 36.4+ KB

# %%
# making a cop of the data to clean it
df = messy_df.copy()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW','iPqaD href', 'FmrIP href',  'cIVmB', 'ySnDE','ccVGl','WlYyy 7', 'dXxty'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'dugSS src':'Image','iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 2':'Tour Type', 'WlYyy 3':'Tour Duration', 'WlYyy 4':'Cancellation', 'WlYyy 6':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Seoul'
df['Country'] = 'South Korea'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 7

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                       Tour By  \
# 0                           Clear all filters
# 1                               By VIP TRAVEL
# 2    By Withlocals.com Private Tours in Seoul
# 3                    By Hello K Cooking Class
# 4                           By Outdoors Korea
# ..                                        ...
# 253                          By 절권도 트레이닝 스튜디오
# 254            By Cosmo. Jin Tour - Day Tours
# 255        By Busan Mate - English Small Tour
# 256                            By K-VAN KOREA
# 257                                       NaN
#
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 253  https://dynamic-media-cdn.tripadvisor.com/medi...
# 254  https://dynamic-media-cdn.tripadvisor.com/medi...
# 255  https://dynamic-media-cdn.tripadvisor.com/medi...
# 256  https://dynamic-media-cdn.tripadvisor.com/medi...
# 257                                                NaN
#
#                                              Tour Name  \
# 0                                                  NaN
# 1    Best Half Day DMZ Tour from Seoul (No Forced S...
# 2    Highlights & Hidden Gems With Locals: Best of ...
# 3    Korean Cooking Class with Full-Course Meal & L...
# 4    Private Tour Nami Island with Petite France or...
# ..                                                 ...
# 253                 Bruce Lee Jeet Kune Do Training~!!
# 254  Hollywood Stars favorite sightseeing location,...
# 255  [Seoul Live Virtual Tour with OraeGage] Yongsa...
# 256  Private Airport Transfer: Gimpo Airport to Seo...
# 257                                                NaN
#
#                                                   Link        Tour Type  \
# 0                                                  NaN              NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
# 2    https://www.tripadvisor.com/Attraction_Review-...       City Tours
# 3    https://www.tripadvisor.com/Attraction_Review-...  Cooking Classes
# 4    https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
# ..                                                 ...              ...
# 253  https://www.tripadvisor.com/Attraction_Review-...   Sports Lessons
# 254  https://www.tripadvisor.com/Attraction_Review-...        Bus Tours
# 255  https://www.tripadvisor.com/Attraction_Review-...   Full-day Tours
# 256  https://www.tripadvisor.com/Attraction_Review-...              NaN
# 257                                                NaN                1
#
#     Tour Duration       Cancellation Tour Price  Price Per   City      Country
# 0             NaN                NaN        NaN        NaN  Seoul  South Korea
# 1         6 hours  Free cancellation     $77.00  per adult  Seoul  South Korea
# 2         3 hours  Free cancellation     $67.88  per adult  Seoul  South Korea
# 3         3 hours  Free cancellation     $70.00  per adult  Seoul  South Korea
# 4       8–9 hours  Free cancellation    $128.00  per adult  Seoul  South Korea
# ..            ...                ...        ...        ...    ...          ...
# 253     1–2 hours  Free cancellation     $71.80  per adult  Seoul  South Korea
# 254       4 hours  Free cancellation     $38.47  per adult  Seoul  South Korea
# 255        1 hour  Free cancellation     $10.00  per adult  Seoul  South Korea
# 256     1–2 hours  Free cancellation     $80.00  per group  Seoul  South Korea
# 257             8                 10        NaN        NaN  Seoul  South Korea
#
# [251 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Tour By', 'Image', 'Tour Name', 'Link', 'Tour Type', 'Tour Duration',
#        'Cancellation', 'Tour Price', 'Price Per', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Image','Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Image            18
# Tour Name        18
# Tour Type        31
# Tour Duration     9
# Tour Price       17
# Price Per        18
# Cancellation     24
# Tour By          23
# City              0
# Country           0
# Link             31
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                                  Image  \
# 0                                                  NaN
# 1    https://dynamic-media-cdn.tripadvisor.com/medi...
# 2    https://dynamic-media-cdn.tripadvisor.com/medi...
# 3    https://dynamic-media-cdn.tripadvisor.com/medi...
# 4    https://dynamic-media-cdn.tripadvisor.com/medi...
# ..                                                 ...
# 253  https://dynamic-media-cdn.tripadvisor.com/medi...
# 254  https://dynamic-media-cdn.tripadvisor.com/medi...
# 255  https://dynamic-media-cdn.tripadvisor.com/medi...
# 256  https://dynamic-media-cdn.tripadvisor.com/medi...
# 257                                                NaN
#
#                                              Tour Name        Tour Type  \
# 0                                                  NaN              NaN
# 1    Best Half Day DMZ Tour from Seoul (No Forced S...        Bus Tours
# 2    Highlights & Hidden Gems With Locals: Best of ...       City Tours
# 3    Korean Cooking Class with Full-Course Meal & L...  Cooking Classes
# 4    Private Tour Nami Island with Petite France or...        Bus Tours
# ..                                                 ...              ...
# 253                 Bruce Lee Jeet Kune Do Training~!!   Sports Lessons
# 254  Hollywood Stars favorite sightseeing location,...        Bus Tours
# 255  [Seoul Live Virtual Tour with OraeGage] Yongsa...   Full-day Tours
# 256  Private Airport Transfer: Gimpo Airport to Seo...              NaN
# 257                                                NaN                1
#
#     Tour Duration Tour Price  Price Per       Cancellation  \
# 0             NaN        NaN        NaN                NaN
# 1         6 hours     $77.00  per adult  Free cancellation
# 2         3 hours     $67.88  per adult  Free cancellation
# 3         3 hours     $70.00  per adult  Free cancellation
# 4       8–9 hours    $128.00  per adult  Free cancellation
# ..            ...        ...        ...                ...
# 253     1–2 hours     $71.80  per adult  Free cancellation
# 254       4 hours     $38.47  per adult  Free cancellation
# 255        1 hour     $10.00  per adult  Free cancellation
# 256     1–2 hours     $80.00  per group  Free cancellation
# 257             8        NaN        NaN                 10
#
#                                       Tour By   City      Country  \
# 0                           Clear all filters  Seoul  South Korea
# 1                               By VIP TRAVEL  Seoul  South Korea
# 2    By Withlocals.com Private Tours in Seoul  Seoul  South Korea
# 3                    By Hello K Cooking Class  Seoul  South Korea
# 4                           By Outdoors Korea  Seoul  South Korea
# ..                                        ...    ...          ...
# 253                          By 절권도 트레이닝 스튜디오  Seoul  South Korea
# 254            By Cosmo. Jin Tour - Day Tours  Seoul  South Korea
# 255        By Busan Mate - English Small Tour  Seoul  South Korea
# 256                            By K-VAN KOREA  Seoul  South Korea
# 257                                       NaN  Seoul  South Korea
#
#                                                   Link
# 0                                                  NaN
# 1    https://www.tripadvisor.com/Attraction_Review-...
# 2    https://www.tripadvisor.com/Attraction_Review-...
# 3    https://www.tripadvisor.com/Attraction_Review-...
# 4    https://www.tripadvisor.com/Attraction_Review-...
# ..                                                 ...
# 253  https://www.tripadvisor.com/Attraction_Review-...
# 254  https://www.tripadvisor.com/Attraction_Review-...
# 255  https://www.tripadvisor.com/Attraction_Review-...
# 256  https://www.tripadvisor.com/Attraction_Review-...
# 257                                                NaN
#
# [258 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Image          240 non-null    object
#  1   Tour Name      240 non-null    object
#  2   Tour Type      227 non-null    object
#  3   Tour Duration  249 non-null    object
#  4   Tour Price     241 non-null    object
#  5   Price Per      240 non-null    object
#  6   Cancellation   234 non-null    object
#  7   Tour By        235 non-null    object
#  8   City           258 non-null    object
#  9   Country        258 non-null    object
#  10  Link           227 non-null    object
# dtypes: object(11)
# memory usage: 22.3+ KB

# %%
# Store the clean dataset
df.to_csv('Seoulclean.csv')
