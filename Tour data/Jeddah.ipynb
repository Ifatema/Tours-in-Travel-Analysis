# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataframe
messy_df = pd.read_csv('Jeddah.csv')

# %%
messy_df.columns
# Out:
# Index(['WlYyy', 'cctrW', 'iPqaD', 'FmrIP href', 'dugSS src', 'bUshh', 'cIVmB',
#        'iPqaD href 2', 'WlYyy 2', 'ySnDE', 'dXxty', 'WlYyy 3', 'ccVGl',
#        'WlYyy 4', 'ccVGl 2', 'WlYyy 5', 'WlYyy 6'],
#       dtype='object')

# %%
# take a look of the first 5 rows in the data
messy_df.head()
# Out:
#                                     WlYyy  \
# 0  61 places sorted by traveler favorites
# 1                                       4
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#                                                cctrW  \
# 0  Tours, activities and experiences bookable on ...
# 1  Not sure? You can cancel this reservation up t...
# 2  Not sure? You can cancel this reservation up t...
# 3  Not sure? You can cancel this reservation up t...
# 4  Not sure? You can cancel this reservation up t...
#
#                                       iPqaD  \
# 0                         Clear all filters
# 1  By Al-Harbi Transport for Umrah and Hajj
# 2                           By Hosam Kandil
# 3                        By 88 Destinations
# 4                By Basma Transport & Tours
#
#                                           FmrIP href  \
# 0                                                NaN
# ...

# %%
# check the datatype & non-null count
messy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   WlYyy         14 non-null     object
#  1   cctrW         60 non-null     object
#  2   iPqaD         57 non-null     object
#  3   FmrIP href    60 non-null     object
#  4   dugSS src     60 non-null     object
#  5   bUshh         60 non-null     object
#  6   cIVmB         60 non-null     float64
#  7   iPqaD href 2  55 non-null     object
#  8   WlYyy 2       64 non-null     object
#  9   ySnDE         59 non-null     object
#  10  dXxty         54 non-null     object
#  11  WlYyy 3       62 non-null     object
#  12  ccVGl         60 non-null     object
#  13  WlYyy 4       60 non-null     object
#  14  ccVGl 2       60 non-null     object
#  15  WlYyy 5       60 non-null     object
#  16  WlYyy 6       26 non-null     object
# dtypes: float64(1), object(16)
# ...

# %%
# making a cop of the data to clean it
df = messy_df.copy()

# %%
# dropping the unnecessary columns
df.drop(['WlYyy', 'cctrW', 'FmrIP href', 'dugSS src','cIVmB', 'ySnDE', 'dXxty','WlYyy 5'], axis=1 , inplace=True)

# %%
# renaming the columns
df.rename(columns={'iPqaD':'Tour By', 'bUshh':'Tour Name', 'iPqaD href 2':'Link', 'WlYyy 6':'Tour Type', 'WlYyy 2':'Tour Duration', 'WlYyy 3':'Cancellation', 'WlYyy 4':'Tour Price', 'ccVGl 2':'Price Per'}, inplace=True)

# %%
# adding new columns
df['City'] = 'Jeddah'
df['Country'] = 'Saudi Arabia'

# %%
# check the total duplicated rows
sum(df.duplicated())
# Out:
# 1

# %%
# drop the duplicated rows
df.drop_duplicates()
# Out:
#                                      Tour By  \
# 0                          Clear all filters
# 1   By Al-Harbi Transport for Umrah and Hajj
# 2                            By Hosam Kandil
# 3                         By 88 Destinations
# 4                 By Basma Transport & Tours
# ..                                       ...
# 62      By PROFi DRIVER Jeddah, Saudi Arabia
# 63                     By MYTRIP Saudi Tours
# 64                                       NaN
# 65      By PROFi DRIVER Jeddah, Saudi Arabia
# 66                                       NaN
#
#                                             Tour Name  \
# 0                                                 NaN
# 1   Jeddah Airport to Makkah (any Mecca hotel) Pri...
# 2   Jeddah City tour history sightseeing in center...
# 3                     Jeddah Old Town Tour (Al Balad)
# 4   Jeddah Hotel to Jeddah Airport Private Departu...
# ..                                                ...
# ...

# %%
df.columns
# Out:
# Index(['Tour By', 'Tour Name', 'Link', 'Tour Duration', 'Cancellation',
#        'ccVGl', 'Tour Price', 'Price Per', 'Tour Type', 'City', 'Country'],
#       dtype='object')

# %%
# Reorfer the columns
df = df[['Tour Name', 'Tour Type', 'Tour Duration', 'Tour Price', 'Price Per', 'Cancellation','Tour By', 'City', 'Country', 'Link']]

# %%
#checking for total null values
df.isnull().sum()
# Out:
# Tour Name         7
# Tour Type        41
# Tour Duration     3
# Tour Price        7
# Price Per         7
# Cancellation      5
# Tour By          10
# City              0
# Country           0
# Link             12
# dtype: int64

# %%
# reset the index
df.reset_index(drop=True)
# Out:
#                                             Tour Name            Tour Type  \
# 0                                                 NaN                  NaN
# 1   Jeddah Airport to Makkah (any Mecca hotel) Pri...                  NaN
# 2   Jeddah City tour history sightseeing in center...  Ports of Call Tours
# 3                     Jeddah Old Town Tour (Al Balad)            Bus Tours
# 4   Jeddah Hotel to Jeddah Airport Private Departu...                  NaN
# ..                                                ...                  ...
# 62  Jeddah Airport Transfers: Jeddah to King Abdul...                  NaN
# 63  Jeddah – King Abdullah Economic City (2 days t...            Bus Tours
# 64  Jeddah Airport To Makkah Hotel : Arrival Transfer                  NaN
# 65  Departure Private Transfers: Jeddah to King Ab...                  NaN
# 66                                                NaN                  NaN
#
#     Tour Duration Tour Price  Price Per       Cancellation  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tour Name      60 non-null     object
#  1   Tour Type      26 non-null     object
#  2   Tour Duration  64 non-null     object
#  3   Tour Price     60 non-null     object
#  4   Price Per      60 non-null     object
#  5   Cancellation   62 non-null     object
#  6   Tour By        57 non-null     object
#  7   City           67 non-null     object
#  8   Country        67 non-null     object
#  9   Link           55 non-null     object
# dtypes: object(10)
# memory usage: 5.4+ KB

# %% [markdown]
# **For the Cleaning:**
# - by: REMOVE Clear all filters
# - type: REMOVE
# - duration: REMOVE Q? & num, + & H M D
# - canel: REMOVE other
# - price:$ --> float

# %%
# Store the clean dataset
df.to_csv('Jeddahclean.csv')
